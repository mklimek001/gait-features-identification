# %%
datasets = {
    "mocap": "datasets/mocap/dataset_v3.json",
    
    "openpose": "datasets/openpose/dataset_openpose_triangulated_v2.json",
    
    "mediapipe" : "datasets/mediapipe/dataset_v4_triangulated.json",
    
    "hrnet": "datasets/mmpose/dataset_hrnet_triangulated.json",
    "rtmpose": "datasets/mmpose/dataset_rtmpose_triangulated.json",
    "vitpose": "datasets/mmpose/dataset_vitpose_triangulated.json",
    
    "movenet_lightning": "datasets/movenet/dataset_lightning_triangulated.json",
    "movenet_thunder": "datasets/movenet/dataset_thunder_triangulated.json",

    "yolo_v26": "datasets/yolo/dataset_v3_yolo26.json",
    # "yolo_v11": "datasets/yolo/dataset_v2.json",
    "yolo_v11": "datasets/yolo/dataset_v2_triangulated_v3.json",
}

# %%
import json

with open(datasets['mocap'], 'r') as file:
    mocap_dataset = json.load(file) 

print(sequences := list(mocap_dataset.keys()))
print(joints := ['lfoot', 'rfoot', 'ltibia', 'rtibia', 
                 'lfemur', 'rfemur', 'lhumerus', 'rhumerus', 
                 'lradius', 'rradius', 'lwrist', 'rwrist'])
# Out:
# ['p1s1', 'p1s2', 'p1s3', 'p1s4', 'p2s1', 'p2s2', 'p2s3', 'p2s4', 'p3s1', 'p3s2', 'p3s3', 'p3s4', 'p4s1', 'p4s2', 'p4s3', 'p4s4', 'p5s1', 'p5s2', 'p5s3', 'p5s4', 'p6s1', 'p6s2', 'p6s3', 'p6s4', 'p7s1', 'p7s2', 'p7s3', 'p7s4', 'p8s1', 'p8s2', 'p8s3', 'p8s4', 'p9s1', 'p9s2', 'p9s3', 'p9s4', 'p10s1', 'p10s2', 'p10s3', 'p10s4', 'p11s1', 'p11s2', 'p11s3', 'p11s4', 'p12s1', 'p12s2', 'p12s3', 'p12s4', 'p13s1', 'p13s2', 'p13s3', 'p13s4', 'p14s1', 'p14s2', 'p14s3', 'p14s4', 'p15s1', 'p15s2', 'p15s3', 'p15s4', 'p16s1', 'p16s2', 'p16s3', 'p16s4', 'p17s1', 'p17s2', 'p17s3', 'p17s4', 'p18s1', 'p18s2', 'p18s3', 'p18s4', 'p19s1', 'p19s2', 'p19s3', 'p19s4', 'p20s1', 'p20s2', 'p20s3', 'p20s4', 'p21s1', 'p21s2', 'p21s3', 'p21s4', 'p22s1', 'p22s2', 'p22s3', 'p22s4', 'p23s1', 'p23s2', 'p23s3', 'p23s4', 'p24s1', 'p24s2', 'p24s3', 'p24s4', 'p25s1', 'p25s2', 'p25s3', 'p25s4', 'p26s1', 'p26s2', 'p26s3', 'p26s4', 'p26s5', 'p26s6', 'p26s7', 'p26s8', 'p27s1', 'p27s2', 'p27s3', 'p27s4', 'p27s5', 'p27s6', 'p27s7', 'p27s8', 'p28s1', 'p28s2', 'p28s3', 'p28s4', 'p28s5', 'p28s6', 'p28s7', 'p28s8', 'p29s1', 'p29s2', 'p29s3', 'p29s4', 'p29s5', 'p29s6', 'p29s7', 'p29s8', 'p30s1', 'p30s2', 'p30s3', 'p30s4', 'p30s5', 'p30s6', 'p30s7', 'p30s8', 'p31s1', 'p31s2', 'p31s3', 'p31s4', 'p31s5', 'p31s6', 'p31s7', 'p31s8', 'p32s1', 'p32s2', 'p32s3', 'p32s4']
# ['lfoot', 'rfoot', 'ltibia', 'rtibia', 'lfemur', 'rfemur', 'lhumerus', 'rhumerus', 'lradius', 'rradius', 'lwrist', 'rwrist']

# %%
list(datasets.keys())[1:]
# Out:
# ['openpose',
#  'mediapipe',
#  'hrnet',
#  'rtmpose',
#  'vitpose',
#  'movenet_lightning',
#  'movenet_thunder',
#  'yolo_v26',
#  'yolo_v11']

# %%
import numpy as np

SCALE_MULTIPLIER = 255

triang_ds_to_compare = list(datasets.keys())[1:]

errors = {aprox_type: {joint_key: [] for joint_key in joints} for aprox_type in triang_ds_to_compare}
mean_errors = {aprox_type: {} for aprox_type in triang_ds_to_compare}

for dataset_name in triang_ds_to_compare:
    print(f"  {dataset_name}")
    with open(datasets[dataset_name], 'r') as file:
        dataset_triang = json.load(file)
    for i, sequence_key in enumerate(sequences):
        for frame_mocap, frame_triang in zip(mocap_dataset[sequence_key], dataset_triang[sequence_key]):
            for joint_key in joints:
                errors[dataset_name][joint_key].append(np.linalg.norm(np.array(frame_mocap[joint_key]) - np.array(frame_triang[joint_key])[[1, 2, 0]]))

for aprox_type in triang_ds_to_compare:
    for joint_key in joints:
        temp_errors = errors[aprox_type][joint_key]
        mean_error = SCALE_MULTIPLIER * sum(temp_errors)/len(temp_errors)
        mean_errors[aprox_type][joint_key] = mean_error

mean_errors
# Out:
#   openpose
#   mediapipe
#   hrnet
#   rtmpose
#   vitpose
#   movenet_lightning
#   movenet_thunder
#   yolo_v26
#   yolo_v11
# {'openpose': {'lfoot': 73.20233393061181,
#   'rfoot': 68.53264900414257,
#   'ltibia': 70.11044200913297,
#   'rtibia': 66.51739834919942,
#   'lfemur': 82.88112905987867,
#   'rfemur': 84.83742158677012,
#   'lhumerus': 76.32090514404571,
#   'rhumerus': 72.94694235722838,
#   'lradius': 62.22570513741882,
#   'rradius': 59.79883747811727,
#   'lwrist': 93.6796979351055,
#   'rwrist': 90.50018086985672},
#  'mediapipe': {'lfoot': 142.61259776671997,
#   'rfoot': 139.19718047867366,
#   'ltibia': 127.69958605549337,
#   'rtibia': 129.55742249089866,
#   'lfemur': 140.45300052030947,
#   'rfemur': 149.5959058740688,
#   'lhumerus': 138.4607697944698,
#   'rhumerus': 163.417412423713,
#   'lradius': 111.9721314140035,
#   'rradius': 132.47591375675293,
#   'lwrist': 162.33181131634453,
#   'rwrist': 177.63935194186666},
#  'hrnet': {'lfoot': 65.03924201688729,
#   'rfoot': 76.9800819059755,
#   'ltibia': 72.50313132654055,
#   'rtibia': 68.03286797394321,
#   'lfemur': 83.46679075835462,
#   'rfemur': 84.03590746186322,
#   'lhumerus': 80.82344465039104,
#   'rhumerus': 78.46079284505974,
#   'lradius': 61.48014992045251,
#   'rradius': 59.080077046598326,
#   'lwrist': 106.54825040525309,
#   'rwrist': 105.0132038758239},
#  'rtmpose': {'lfoot': 59.29358336436523,
#   'rfoot': 60.23747402722826,
#   'ltibia': 70.9418184837837,
#   'rtibia': 65.98672393879141,
#   'lfemur': 87.18414572481218,
#   'rfemur': 86.82125616512198,
#   'lhumerus': 81.39377386061797,
#   'rhumerus': 77.96656829624551,
#   'lradius': 62.823073338263995,
#   'rradius': 61.123161083947636,
#   'lwrist': 111.60201260584499,
#   'rwrist': 109.22435932621883},
#  'vitpose': {'lfoot': 57.35445640355943,
#   'rfoot': 68.29414334961704,
#   'ltibia': 68.43384265661496,
#   'rtibia': 64.48030099318663,
#   'lfemur': 82.94676615756251,
#   'rfemur': 83.72055991028591,
#   'lhumerus': 80.00359441743757,
#   'rhumerus': 77.41376152021788,
#   'lradius': 60.48019318687847,
#   'rradius': 58.146841196058986,
#   'lwrist': 106.78603839132266,
#   'rwrist': 104.48617414898001},
#  'movenet_lightning': {'lfoot': 693.8798255346055,
#   'rfoot': 926.4892279437013,
#   'ltibia': 648.0049175380666,
#   'rtibia': 663.7503382345191,
#   'lfemur': 733.3838342874731,
#   'rfemur': 1089.7323389470992,
#   'lhumerus': 408.25451297288294,
#   'rhumerus': 451.8512512852912,
#   'lradius': 778.2492548104885,
#   'rradius': 621.9079224106704,
#   'lwrist': 1066.8951363433198,
#   'rwrist': 1507.452954932088},
#  'movenet_thunder': {'lfoot': 695.6201355445978,
#   'rfoot': 6596.481072282183,
#   'ltibia': 592.3316451182752,
#   'rtibia': 292.9228438475086,
#   'lfemur': 240.51603912579037,
#   'rfemur': 326.68595239554236,
#   'lhumerus': 207.11560645210486,
#   'rhumerus': 217.9305946953798,
#   'lradius': 241.45588054450332,
#   'rradius': 237.24825397684378,
#   'lwrist': 310.069975842728,
#   'rwrist': 356.7421028894637},
#  'yolo_v26': {'lfoot': 57.15094822902575,
#   'rfoot': 56.25208402181772,
#   'ltibia': 68.6626996422711,
#   'rtibia': 63.559211829351604,
#   'lfemur': 82.77720840366557,
#   'rfemur': 83.40636338145171,
#   'lhumerus': 76.06381805772297,
#   'rhumerus': 73.27847887745266,
#   'lradius': 60.922933676593765,
#   'rradius': 57.96002319380715,
#   'lwrist': 99.79795489176992,
#   'rwrist': 99.2045232267862},
#  'yolo_v11': {'lfoot': 60.65051258303923,
#   'rfoot': 61.13725486993843,
#   'ltibia': 74.56302890572763,
#   'rtibia': 69.51854311693079,
#   'lfemur': 85.04990711559448,
#   'rfemur': 86.84276452428507,
#   'lhumerus': 79.17367401096767,
#   'rhumerus': 76.43529086158455,
#   'lradius': 56.64576525254797,
#   'rradius': 55.14319886822645,
#   'lwrist': 95.63643818896108,
#   'rwrist': 93.30813089313253}}

# %%
for estimator in ['joint name'] + triang_ds_to_compare:
    print("\\textbf{", estimator.replace('_', ''), "}", end="  &  ")
print("\\\\")

for joint in joints:
    print("\\textbf{", joint, "}", end=" & ")
    for estimator in triang_ds_to_compare:
        print(round(mean_errors[estimator][joint], 2), end="   &   ")
    print("\\\\")
# Out:
# \textbf{ joint name }  &  \textbf{ openpose }  &  \textbf{ mediapipe }  &  \textbf{ hrnet }  &  \textbf{ rtmpose }  &  \textbf{ vitpose }  &  \textbf{ movenetlightning }  &  \textbf{ movenetthunder }  &  \textbf{ yolov26 }  &  \textbf{ yolov11 }  &  \\
# \textbf{ lfoot } & 73.2   &   142.61   &   65.04   &   59.29   &   57.35   &   693.88   &   695.62   &   57.15   &   60.65   &   \\
# \textbf{ rfoot } & 68.53   &   139.2   &   76.98   &   60.24   &   68.29   &   926.49   &   6596.48   &   56.25   &   61.14   &   \\
# \textbf{ ltibia } & 70.11   &   127.7   &   72.5   &   70.94   &   68.43   &   648.0   &   592.33   &   68.66   &   74.56   &   \\
# \textbf{ rtibia } & 66.52   &   129.56   &   68.03   &   65.99   &   64.48   &   663.75   &   292.92   &   63.56   &   69.52   &   \\
# \textbf{ lfemur } & 82.88   &   140.45   &   83.47   &   87.18   &   82.95   &   733.38   &   240.52   &   82.78   &   85.05   &   \\
# \textbf{ rfemur } & 84.84   &   149.6   &   84.04   &   86.82   &   83.72   &   1089.73   &   326.69   &   83.41   &   86.84   &   \\
# \textbf{ lhumerus } & 76.32   &   138.46   &   80.82   &   81.39   &   80.0   &   408.25   &   207.12   &   76.06   &   79.17   &   \\
# \textbf{ rhumerus } & 72.95   &   163.42   &   78.46   &   77.97   &   77.41   &   451.85   &   217.93   &   73.28   &   76.44   &   \\
# \textbf{ lradius } & 62.23   &   111.97   &   61.48   &   62.82   &   60.48   &   778.25   &   241.46   &   60.92   &   56.65   &   \\
# \textbf{ rradius } & 59.8   &   132.48   &   59.08   &   61.12   &   58.15   &   621.91   &   237.25   &   57.96   &   55.14   &   \\
# \textbf{ lwrist } & 93.68   &   162.33   &   106.55   &   111.6   &   106.79   &   1066.9   &   310.07   &   99.8   &   95.64   &   \\
# \textbf{ rwrist } & 90.5   &   177.64   &   105.01   &   109.22   &   104.49   &   1507.45   &   356.74   &   99.2   &   93.31   &   \\

# %%
total_frames = len(errors['yolo_v26']['rfoot'])
bigger_than_k = {aprox_type: {} for aprox_type in triang_ds_to_compare}
k = 150

for aprox_type in triang_ds_to_compare:
    for joint_key in joints:
        bigger_than_k[aprox_type][joint_key] = 100*len([error for error in errors[aprox_type][joint_key] if error*SCALE_MULTIPLIER > k])/total_frames

for estimator in ['joint name'] + triang_ds_to_compare:
    print("\\textbf{", estimator.replace('_', ''), "}", end="  &  ")
print("\\\\")

for joint in joints:
    print("\\textbf{", joint, "}", end=" & ")
    for estimator in triang_ds_to_compare:
        print(round(bigger_than_k[estimator][joint], 2), end="   &   ")
    print("\\\\")
# Out:
# \textbf{ joint name }  &  \textbf{ openpose }  &  \textbf{ mediapipe }  &  \textbf{ hrnet }  &  \textbf{ rtmpose }  &  \textbf{ vitpose }  &  \textbf{ movenetlightning }  &  \textbf{ movenetthunder }  &  \textbf{ yolov26 }  &  \textbf{ yolov11 }  &  \\
# \textbf{ lfoot } & 3.55   &   13.29   &   3.64   &   2.13   &   2.33   &   70.68   &   50.79   &   2.01   &   3.35   &   \\
# \textbf{ rfoot } & 3.43   &   13.88   &   3.49   &   2.12   &   2.47   &   72.2   &   51.55   &   2.12   &   3.05   &   \\
# \textbf{ ltibia } & 4.77   &   11.85   &   5.43   &   4.24   &   4.19   &   76.23   &   48.08   &   3.78   &   5.17   &   \\
# \textbf{ rtibia } & 3.89   &   11.52   &   3.99   &   2.92   &   3.13   &   74.86   &   47.08   &   2.78   &   3.57   &   \\
# \textbf{ lfemur } & 6.99   &   12.19   &   7.01   &   7.99   &   7.06   &   54.3   &   36.57   &   6.79   &   7.13   &   \\
# \textbf{ rfemur } & 7.15   &   12.98   &   7.25   &   8.0   &   7.51   &   56.43   &   36.32   &   6.76   &   7.45   &   \\
# \textbf{ lhumerus } & 3.54   &   6.77   &   3.57   &   3.83   &   3.64   &   68.51   &   46.03   &   2.74   &   2.9   &   \\
# \textbf{ rhumerus } & 4.0   &   7.04   &   4.17   &   4.33   &   4.19   &   65.85   &   46.34   &   3.41   &   3.34   &   \\
# \textbf{ lradius } & 5.18   &   7.9   &   5.11   &   5.75   &   5.22   &   85.19   &   60.36   &   4.79   &   4.65   &   \\
# \textbf{ rradius } & 3.98   &   6.94   &   4.35   &   4.75   &   4.19   &   87.25   &   56.2   &   3.95   &   2.46   &   \\
# \textbf{ lwrist } & 6.59   &   13.44   &   9.4   &   10.81   &   8.65   &   93.05   &   73.65   &   6.61   &   5.74   &   \\
# \textbf{ rwrist } & 5.05   &   11.01   &   8.89   &   9.39   &   7.99   &   92.67   &   67.69   &   6.25   &   3.94   &   \\

# %%
total_frames = len(errors['yolo_v26']['rfoot'])
bigger_than_k = {aprox_type: {} for aprox_type in triang_ds_to_compare}
k = 1000

for aprox_type in triang_ds_to_compare:
    for joint_key in joints:
        bigger_than_k[aprox_type][joint_key] = 100*len([error for error in errors[aprox_type][joint_key] if error*SCALE_MULTIPLIER > k])/total_frames

for estimator in ['joint name'] + triang_ds_to_compare:
    print("\\textbf{", estimator.replace('_', ''), "}", end="  &  ")
print("\\\\")

for joint in joints:
    print("\\textbf{", joint, "}", end=" & ")
    for estimator in triang_ds_to_compare:
        print(round(bigger_than_k[estimator][joint], 2), end="   &   ")
    print("\\\\")
# Out:
# \textbf{ joint name }  &  \textbf{ openpose }  &  \textbf{ mediapipe }  &  \textbf{ hrnet }  &  \textbf{ rtmpose }  &  \textbf{ vitpose }  &  \textbf{ movenetlightning }  &  \textbf{ movenetthunder }  &  \textbf{ yolov26 }  &  \textbf{ yolov11 }  &  \\
# \textbf{ lfoot } & 0.06   &   1.08   &   0.07   &   0.06   &   0.02   &   4.21   &   1.93   &   0.01   &   0.01   &   \\
# \textbf{ rfoot } & 0.1   &   0.83   &   0.11   &   0.13   &   0.03   &   4.16   &   1.87   &   0.01   &   0.03   &   \\
# \textbf{ ltibia } & 0.0   &   0.84   &   0.0   &   0.15   &   0.0   &   3.61   &   1.52   &   0.0   &   0.0   &   \\
# \textbf{ rtibia } & 0.0   &   0.77   &   0.0   &   0.19   &   0.0   &   3.65   &   1.5   &   0.0   &   0.0   &   \\
# \textbf{ lfemur } & 0.0   &   0.84   &   0.04   &   0.34   &   0.0   &   3.54   &   1.32   &   0.0   &   0.0   &   \\
# \textbf{ rfemur } & 0.0   &   0.84   &   0.0   &   0.21   &   0.0   &   3.22   &   1.24   &   0.0   &   0.0   &   \\
# \textbf{ lhumerus } & 0.0   &   0.84   &   0.0   &   0.26   &   0.0   &   3.45   &   1.28   &   0.0   &   0.0   &   \\
# \textbf{ rhumerus } & 0.0   &   0.84   &   0.0   &   0.06   &   0.0   &   3.15   &   1.03   &   0.0   &   0.0   &   \\
# \textbf{ lradius } & 0.0   &   0.84   &   0.0   &   0.21   &   0.0   &   4.06   &   1.41   &   0.0   &   0.0   &   \\
# \textbf{ rradius } & 0.0   &   0.84   &   0.07   &   0.26   &   0.02   &   3.44   &   1.22   &   0.0   &   0.04   &   \\
# \textbf{ lwrist } & 0.0   &   0.87   &   0.0   &   0.0   &   0.02   &   3.83   &   1.4   &   0.0   &   0.0   &   \\
# \textbf{ rwrist } & 0.0   &   0.86   &   0.0   &   0.34   &   0.02   &   3.75   &   1.33   &   0.0   &   0.02   &   \\
