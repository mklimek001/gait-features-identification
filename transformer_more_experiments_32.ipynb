# %%
import logging
from utils.cross_validation_siamese_raw_multiple_datasets import CrossValidationSiameseMultipleDs
from utils.cross_validation_siamese_raw import TrainingParameters

# %%
transformer_parameters = TrainingParameters(
    learning_rate = 1e-4,
    batch_size = 32,
    n_epochs = 200,
)

# %%
cv = CrossValidationSiameseMultipleDs(
    log_level = logging.INFO,
    logger_name = f'transformer_updated_adam_{transformer_parameters.learning_rate}_yolo26_butterworth',
)

cv.perform_training_with_rank_classification_and_multiple_datasets(
    n_folds = 4,
    selected_datasets = 'yolo_v26', 
    # ['mocap', 'yolo_v26', 'vitpose', 'openpose'], None to use all available 
    test_dataset_type = 'yolo_v26',
    diff_dataset_usage = "MIX_ALL",
    siamese_nn_type = "transformerupdated",
    optimizer_type = "adam",
    learning_rate = transformer_parameters.learning_rate,
    batch_size = transformer_parameters.batch_size,
    n_epochs = transformer_parameters.n_epochs,
    embedding_size = 32,
    tsne_perplexity = 20,
    show_plot = True, 
    use_butterworth_smoothed = True,
    early_stop_patience = 5,
)
# Out:
# 2026-05-27 21:08:59,011 - transformer_updated_adam_0.0001_yolo26_butterworth - INFO - [Iteration 1/4]
# 2026-05-27 21:09:02,613 - transformer_updated_adam_0.0001_yolo26_butterworth - INFO - Train dataset size: 2560
# 2026-05-27 21:09:02,615 - transformer_updated_adam_0.0001_yolo26_butterworth - INFO - Test dataset size: 1746
# 2026-05-27 21:09:02,616 - transformer_updated_adam_0.0001_yolo26_butterworth - INFO - Using device: cuda
# 2026-05-27 21:09:03,323 - transformer_updated_adam_0.0001_yolo26_butterworth - INFO - Epoch 1, Train Loss: 0.33118869215250013
# 2026-05-27 21:09:03,885 - transformer_updated_adam_0.0001_yolo26_butterworth - INFO - Epoch 2, Train Loss: 0.2632074598222971
# 2026-05-27 21:09:04,451 - transformer_updated_adam_0.0001_yolo26_butterworth - INFO - Epoch 3, Train Loss: 0.24358990415930748
# 2026-05-27 21:09:05,016 - transformer_updated_adam_0.0001_yolo26_butterworth - INFO - Epoch 4, Train Loss: 0.2315069565549493
# ...

# %%
cv = CrossValidationSiameseMultipleDs(
    log_level = logging.INFO,
    logger_name = f'transformer_adam_{transformer_parameters.learning_rate}_yolo26_butterworth',
)

cv.perform_training_with_rank_classification_and_multiple_datasets(
    n_folds = 4,
    selected_datasets = 'yolo_v26', 
    # ['mocap', 'yolo_v26', 'vitpose', 'openpose'], None to use all available 
    test_dataset_type = 'yolo_v26',
    diff_dataset_usage = "MIX_ALL",
    siamese_nn_type = "transformer",
    optimizer_type = "adam",
    learning_rate = transformer_parameters.learning_rate,
    batch_size = transformer_parameters.batch_size,
    n_epochs = transformer_parameters.n_epochs,
    embedding_size = 32,
    tsne_perplexity = 20,
    show_plot = True, 
    use_butterworth_smoothed = True,
    early_stop_patience = 5,
)
# Out:
# 2026-05-26 10:33:32,722 - transformer_adam_0.0001_yolo26_butterworth - INFO - [Iteration 1/4]
# 2026-05-26 10:33:36,098 - transformer_adam_0.0001_yolo26_butterworth - INFO - Train dataset size: 2560
# 2026-05-26 10:33:36,099 - transformer_adam_0.0001_yolo26_butterworth - INFO - Test dataset size: 1746
# 2026-05-26 10:33:36,100 - transformer_adam_0.0001_yolo26_butterworth - INFO - Using device: cuda
# 2026-05-26 10:33:37,130 - transformer_adam_0.0001_yolo26_butterworth - INFO - Epoch 1, Train Loss: 0.26980619989335536
# 2026-05-26 10:33:38,176 - transformer_adam_0.0001_yolo26_butterworth - INFO - Epoch 2, Train Loss: 0.25619589984416963
# 2026-05-26 10:33:39,231 - transformer_adam_0.0001_yolo26_butterworth - INFO - Epoch 3, Train Loss: 0.2470063528046012
# 2026-05-26 10:33:40,237 - transformer_adam_0.0001_yolo26_butterworth - INFO - Epoch 4, Train Loss: 0.2377153092995286
# ...

# %%
cv = CrossValidationSiameseMultipleDs(
    log_level = logging.INFO,
    logger_name = f'transformer_adam_{transformer_parameters.learning_rate}_yolo26',
)

cv.perform_training_with_rank_classification_and_multiple_datasets(
    n_folds = 4,
    selected_datasets = 'yolo_v26', 
    # ['mocap', 'yolo_v26', 'vitpose', 'openpose'], None to use all available 
    test_dataset_type = 'yolo_v26',
    diff_dataset_usage = "MIX_ALL",
    siamese_nn_type = "transformer",
    optimizer_type = "adam",
    learning_rate = transformer_parameters.learning_rate,
    batch_size = transformer_parameters.batch_size,
    n_epochs = transformer_parameters.n_epochs,
    embedding_size = 32,
    tsne_perplexity = 20,
    show_plot = True, 
    use_butterworth_smoothed = False,
    early_stop_patience = 5,
)
# Out:
# 2026-05-26 10:07:15,204 - transformer_adam_0.0001_yolo26 - INFO - [Iteration 1/4]
# 2026-05-26 10:07:18,658 - transformer_adam_0.0001_yolo26 - INFO - Train dataset size: 3046
# 2026-05-26 10:07:18,658 - transformer_adam_0.0001_yolo26 - INFO - Test dataset size: 2240
# 2026-05-26 10:07:18,659 - transformer_adam_0.0001_yolo26 - INFO - Using device: cuda
# 2026-05-26 10:07:20,427 - transformer_adam_0.0001_yolo26 - INFO - Epoch 1, Train Loss: 0.25560110264147323
# 2026-05-26 10:07:22,303 - transformer_adam_0.0001_yolo26 - INFO - Epoch 2, Train Loss: 0.24707489910845956
# 2026-05-26 10:07:24,276 - transformer_adam_0.0001_yolo26 - INFO - Epoch 3, Train Loss: 0.2396367200029393
# 2026-05-26 10:07:26,255 - transformer_adam_0.0001_yolo26 - INFO - Epoch 4, Train Loss: 0.22943142087509236
# 2026-05-26 10:07:28,017 - transformer_adam_0.0001_yolo26 - INFO - Epoch 5, Train Loss: 0.218053144402802
# ...

# %%
cv = CrossValidationSiameseMultipleDs(
    log_level = logging.INFO,
    logger_name = f'transformer_adam_{transformer_parameters.learning_rate}_mocap_butterworth',
)

cv.perform_training_with_rank_classification_and_multiple_datasets(
    n_folds = 4,
    selected_datasets = 'mocap', 
    test_dataset_type = 'mocap',
    diff_dataset_usage = "MIX_ALL",
    siamese_nn_type = "transformer",
    optimizer_type = "adam",
    learning_rate = transformer_parameters.learning_rate,
    batch_size = transformer_parameters.batch_size,
    n_epochs = transformer_parameters.n_epochs,
    embedding_size = 32,
    tsne_perplexity = 20,
    show_plot = True, 
    use_butterworth_smoothed = True,
    early_stop_patience = 5,
)
# Out:
# 2026-05-26 10:15:59,939 - transformer_adam_0.0001_mocap_butterworth - INFO - [Iteration 1/4]
# 2026-05-26 10:16:03,410 - transformer_adam_0.0001_mocap_butterworth - INFO - Train dataset size: 2680
# 2026-05-26 10:16:03,411 - transformer_adam_0.0001_mocap_butterworth - INFO - Test dataset size: 1820
# 2026-05-26 10:16:03,412 - transformer_adam_0.0001_mocap_butterworth - INFO - Using device: cuda
# 2026-05-26 10:16:05,028 - transformer_adam_0.0001_mocap_butterworth - INFO - Epoch 1, Train Loss: 0.2696304880082607
# 2026-05-26 10:16:06,766 - transformer_adam_0.0001_mocap_butterworth - INFO - Epoch 2, Train Loss: 0.2383498710890611
# 2026-05-26 10:16:08,252 - transformer_adam_0.0001_mocap_butterworth - INFO - Epoch 3, Train Loss: 0.23295123786443755
# 2026-05-26 10:16:09,788 - transformer_adam_0.0001_mocap_butterworth - INFO - Epoch 4, Train Loss: 0.218479522282169
# 2026-05-26 10:16:11,383 - transformer_adam_0.0001_mocap_butterworth - INFO - Epoch 5, Train Loss: 0.2074852248742467
# ...

# %%
cv = CrossValidationSiameseMultipleDs(
    log_level = logging.INFO,
    logger_name = f'transformer_adam_{transformer_parameters.learning_rate}_mocap',
)

cv.perform_training_with_rank_classification_and_multiple_datasets(
    n_folds = 4,
    selected_datasets = 'mocap', 
    test_dataset_type = 'mocap',
    diff_dataset_usage = "MIX_ALL",
    siamese_nn_type = "transformer",
    optimizer_type = "adam",
    learning_rate = transformer_parameters.learning_rate,
    batch_size = transformer_parameters.batch_size,
    n_epochs = transformer_parameters.n_epochs,
    embedding_size = 32,
    tsne_perplexity = 20,
    show_plot = True, 
    use_butterworth_smoothed = False,
    early_stop_patience = 5,
)
# Out:
# 2026-05-26 10:24:50,513 - transformer_adam_0.0001_mocap - INFO - [Iteration 1/4]
# 2026-05-26 10:24:53,928 - transformer_adam_0.0001_mocap - INFO - Train dataset size: 3042
# 2026-05-26 10:24:53,929 - transformer_adam_0.0001_mocap - INFO - Test dataset size: 2206
# 2026-05-26 10:24:53,930 - transformer_adam_0.0001_mocap - INFO - Using device: cuda
# 2026-05-26 10:24:55,186 - transformer_adam_0.0001_mocap - INFO - Epoch 1, Train Loss: 0.2999968725877504
# 2026-05-26 10:24:56,288 - transformer_adam_0.0001_mocap - INFO - Epoch 2, Train Loss: 0.24225087851906815
# 2026-05-26 10:24:57,376 - transformer_adam_0.0001_mocap - INFO - Epoch 3, Train Loss: 0.2290188797439138
# 2026-05-26 10:24:58,499 - transformer_adam_0.0001_mocap - INFO - Epoch 4, Train Loss: 0.22135453267643848
# 2026-05-26 10:24:59,644 - transformer_adam_0.0001_mocap - INFO - Epoch 5, Train Loss: 0.20658154971897602
# 2026-05-26 10:25:00,821 - transformer_adam_0.0001_mocap - INFO - Epoch 6, Train Loss: 0.18864512288322052
# ...
