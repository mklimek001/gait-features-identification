# %%
import json
import logging
from utils.cross_validation_siamese_raw import CrossValidationSiameseRaw
from utils.gait_parameters_extractor import CoordinatesIdx
from utils.cross_validation_siamese_raw import CrossValidationSiameseRaw
from utils.gait_parameters_extractor import CoordinatesIdx
from pathlib import Path


with open("./datasets/mocap/dataset_mocap_cycles_split.json", "r") as file:
    mocap_cycles = json.load(file)

with open("./datasets/yolo/dataset_yolo26_triang_cycles_split.json", "r") as file:
    yolo_cycles = json.load(file)

with open("./datasets/yolo/dataset_yolo26_triang_best_cameras_cycles_split.json", "r") as file:
    yolo_best_cams_cycles = json.load(file)

with open("./datasets/yolo/dataset_yolo26_triang_cycles_split_butterworth.json", "r") as file:
    yolo_cycles_smoothed = json.load(file)

with open("./datasets/yolo/dataset_yolo26_triang_best_cameras_cycles_split_butterworth.json", "r") as file:
    yolo_best_cams_cycles_smoothed = json.load(file)

# %%
cv = CrossValidationSiameseRaw(
    sequence_cycles=mocap_cycles, 
    coordinates_idx=CoordinatesIdx(2, 0, 1), 
    log_level=logging.INFO,
    logger_name = 'mocap',
)
cv.count_participants_samples()
cv.perform_training(
    n_folds = 4,
    siamese_nn_type = "conv1d",
    learning_rate = 1e-4,
    batch_size = 32,
    n_epochs = 10,
    threshold = 0.5,
    show_plot = True, 
    csv_file_path = Path('results/predictions_cv/mocap_cycles_conv1d.csv'),
)
# Out:
# 2026-02-01 21:49:21,225 - mocap - INFO - Preparing cycles and participant labels...
# 2026-02-01 21:49:37,621 - mocap - INFO - [Iteration 1/4]
# 2026-02-01 21:49:37,700 - mocap - INFO - Train dataset size: 3022
# 2026-02-01 21:49:37,702 - mocap - INFO - Test dataset size: 2314
# 2026-02-01 21:49:43,226 - mocap - INFO - Epoch 1, Train Loss: 0.4217224945167178
# 2026-02-01 21:49:44,885 - mocap - INFO - Epoch 2, Train Loss: 0.024757574611392462
# 2026-02-01 21:49:46,459 - mocap - INFO - Epoch 3, Train Loss: 0.017974269958703142
# 2026-02-01 21:49:48,053 - mocap - INFO - Epoch 4, Train Loss: 0.011768522802250166
# 2026-02-01 21:49:49,677 - mocap - INFO - Epoch 5, Train Loss: 0.010102875925306428
# 2026-02-01 21:49:51,331 - mocap - INFO - Epoch 6, Train Loss: 0.008765048349864388
# 2026-02-01 21:49:52,998 - mocap - INFO - Epoch 7, Train Loss: 0.005714671014759101
# 2026-02-01 21:49:54,764 - mocap - INFO - Epoch 8, Train Loss: 0.007842821071512605
# 2026-02-01 21:49:56,507 - mocap - INFO - Epoch 9, Train Loss: 0.006380629426750698
# 2026-02-01 21:49:58,181 - mocap - INFO - Epoch 10, Train Loss: 0.005610383094876613
# 2026-02-01 21:50:00,078 - mocap - INFO - Accuracy: 0.9956784788245462
# 2026-02-01 21:50:00,079 - mocap - INFO - Precision: 0.9914310197086547
# 2026-02-01 21:50:00,080 - mocap - INFO - Recall: 1.0
# 2026-02-01 21:50:00,083 - mocap - INFO - Confusion matrix:
#         True  False
# True   1157      0
# False    10   1147
# 2026-02-01 21:50:00,366 - mocap - INFO - [Iteration 2/4]
# 2026-02-01 21:50:00,428 - mocap - INFO - Train dataset size: 4452
# 2026-02-01 21:50:00,430 - mocap - INFO - Test dataset size: 884
# 2026-02-01 21:50:02,789 - mocap - INFO - Epoch 1, Train Loss: 0.3675396042875946
# 2026-02-01 21:50:05,221 - mocap - INFO - Epoch 2, Train Loss: 0.02244395851822836
# 2026-02-01 21:50:07,828 - mocap - INFO - Epoch 3, Train Loss: 0.014040787910510387
# 2026-02-01 21:50:10,567 - mocap - INFO - Epoch 4, Train Loss: 0.009969932773882258
# 2026-02-01 21:50:13,308 - mocap - INFO - Epoch 5, Train Loss: 0.008040855818295053
# 2026-02-01 21:50:17,144 - mocap - INFO - Epoch 6, Train Loss: 0.009145467050672908
# 2026-02-01 21:50:20,169 - mocap - INFO - Epoch 7, Train Loss: 0.005222994725253167
# 2026-02-01 21:50:22,975 - mocap - INFO - Epoch 8, Train Loss: 0.007605791677321706
# 2026-02-01 21:50:26,543 - mocap - INFO - Epoch 9, Train Loss: 0.004308088548714295
# 2026-02-01 21:50:29,117 - mocap - INFO - Epoch 10, Train Loss: 0.0070700366694446916
# 2026-02-01 21:50:30,063 - mocap - INFO - Accuracy: 0.994343891402715
# 2026-02-01 21:50:30,064 - mocap - INFO - Precision: 0.9888143176733781
# 2026-02-01 21:50:30,065 - mocap - INFO - Recall: 1.0
# 2026-02-01 21:50:30,069 - mocap - INFO - Confusion matrix:
#         True  False
# True    442      0
# False     5    437
# 2026-02-01 21:50:30,406 - mocap - INFO - [Iteration 3/4]
# 2026-02-01 21:50:30,496 - mocap - INFO - Train dataset size: 4034
# 2026-02-01 21:50:30,497 - mocap - INFO - Test dataset size: 1302
# 2026-02-01 21:50:32,813 - mocap - INFO - Epoch 1, Train Loss: 0.49740716782728517
# 2026-02-01 21:50:35,125 - mocap - INFO - Epoch 2, Train Loss: 0.023585335553191075
# 2026-02-01 21:50:37,338 - mocap - INFO - Epoch 3, Train Loss: 0.016748623599804294
# 2026-02-01 21:50:39,156 - mocap - INFO - Epoch 4, Train Loss: 0.012310539106435077
# 2026-02-01 21:50:41,356 - mocap - INFO - Epoch 5, Train Loss: 0.011034396555876052
# 2026-02-01 21:50:43,669 - mocap - INFO - Epoch 6, Train Loss: 0.008223156723391823
# 2026-02-01 21:50:45,966 - mocap - INFO - Epoch 7, Train Loss: 0.007190914721939508
# 2026-02-01 21:50:48,251 - mocap - INFO - Epoch 8, Train Loss: 0.006248295549156628
# 2026-02-01 21:50:50,555 - mocap - INFO - Epoch 9, Train Loss: 0.005103406858883475
# 2026-02-01 21:50:52,763 - mocap - INFO - Epoch 10, Train Loss: 0.004488390808976365
# 2026-02-01 21:50:54,137 - mocap - INFO - Accuracy: 0.9984639016897081
# 2026-02-01 21:50:54,139 - mocap - INFO - Precision: 0.9984639016897081
# 2026-02-01 21:50:54,139 - mocap - INFO - Recall: 0.9984639016897081
# 2026-02-01 21:50:54,144 - mocap - INFO - Confusion matrix:
#         True  False
# True    650      1
# False     1    650
# 2026-02-01 21:50:54,476 - mocap - INFO - [Iteration 4/4]
# 2026-02-01 21:50:54,584 - mocap - INFO - Train dataset size: 4500
# 2026-02-01 21:50:54,585 - mocap - INFO - Test dataset size: 836
# 2026-02-01 21:50:57,246 - mocap - INFO - Epoch 1, Train Loss: 0.5552168377866664
# 2026-02-01 21:50:59,823 - mocap - INFO - Epoch 2, Train Loss: 0.024377801620685462
# 2026-02-01 21:51:02,391 - mocap - INFO - Epoch 3, Train Loss: 0.01718211837826257
# 2026-02-01 21:51:04,871 - mocap - INFO - Epoch 4, Train Loss: 0.013182784940928538
# 2026-02-01 21:51:06,945 - mocap - INFO - Epoch 5, Train Loss: 0.009907401047138404
# 2026-02-01 21:51:09,456 - mocap - INFO - Epoch 6, Train Loss: 0.008259694296734553
# 2026-02-01 21:51:11,944 - mocap - INFO - Epoch 7, Train Loss: 0.005951384696713153
# 2026-02-01 21:51:14,470 - mocap - INFO - Epoch 8, Train Loss: 0.005912879647039775
# 2026-02-01 21:51:17,145 - mocap - INFO - Epoch 9, Train Loss: 0.0061291719048700115
# 2026-02-01 21:51:19,676 - mocap - INFO - Epoch 10, Train Loss: 0.0061132613060077825
# 2026-02-01 21:51:20,546 - mocap - INFO - Accuracy: 1.0
# 2026-02-01 21:51:20,548 - mocap - INFO - Precision: 1.0
# 2026-02-01 21:51:20,548 - mocap - INFO - Recall: 1.0
# 2026-02-01 21:51:20,553 - mocap - INFO - Confusion matrix:
#         True  False
# True    418      0
# False     0    418
# 2026-02-01 21:51:20,889 - mocap - INFO - Results will be saved to WindowsPath('results/predictions_cv/mocap_cycles_conv1d.csv')
# 2026-02-01 21:51:20,909 - mocap - INFO -
#
# 2026-02-01 21:51:20,910 - mocap - INFO - Combined evaluation
# 2026-02-01 21:51:20,911 - mocap - INFO - **************************************************
# 2026-02-01 21:51:21,245 - mocap - INFO - Area under ROC curve: 0.9999567307800372
# 2026-02-01 21:51:21,266 - mocap - INFO - Accuracy: 0.9968140929535232
# 2026-02-01 21:51:21,267 - mocap - INFO - Precision: 0.9940365262765561
# 2026-02-01 21:51:21,268 - mocap - INFO - Recall: 0.9996251874062968
# 2026-02-01 21:51:21,274 - mocap - INFO - Confusion matrix:
#         True  False
# True   2667      1
# False    16   2652
# 2026-02-01 21:51:21,533 - mocap - INFO - & accuracy & precision &  recall  &   auroc
# 2026-02-01 21:51:21,534 - mocap - INFO - & 99.68    & 99.40     & 99.96     & 100.00
# (0.9968140929535232,
#  0.9940365262765561,
#  0.9996251874062968,
#  0.9999567307800372)

# %%
cv = CrossValidationSiameseRaw(
    sequence_cycles=mocap_cycles, 
    coordinates_idx=CoordinatesIdx(2, 0, 1), 
    log_level=logging.INFO,
    logger_name = 'mocap',
)
cv.count_participants_samples()
cv.perform_training(
    n_folds = 4,
    siamese_nn_type = "lstm",
    learning_rate = 1e-4,
    batch_size = 32,
    n_epochs = 10,
    threshold = 0.5,
    show_plot = True, 
    csv_file_path = Path('results/predictions_cv/mocap_cycles_lstm.csv'),
)
# Out:
# 2026-02-01 21:51:21,573 - mocap - INFO - Preparing cycles and participant labels...
# 2026-02-01 21:51:36,406 - mocap - INFO - [Iteration 1/4]
# 2026-02-01 21:51:36,461 - mocap - INFO - Train dataset size: 3022
# 2026-02-01 21:51:36,462 - mocap - INFO - Test dataset size: 2314
# 2026-02-01 21:51:37,854 - mocap - INFO - Epoch 1, Train Loss: 0.3090056962088535
# 2026-02-01 21:51:39,403 - mocap - INFO - Epoch 2, Train Loss: 0.18462169970336714
# 2026-02-01 21:51:40,962 - mocap - INFO - Epoch 3, Train Loss: 0.11573823580616399
# 2026-02-01 21:51:42,519 - mocap - INFO - Epoch 4, Train Loss: 0.08576435842796376
# 2026-02-01 21:51:44,016 - mocap - INFO - Epoch 5, Train Loss: 0.07120461201197223
# 2026-02-01 21:51:46,027 - mocap - INFO - Epoch 6, Train Loss: 0.057556103679694624
# 2026-02-01 21:51:48,291 - mocap - INFO - Epoch 7, Train Loss: 0.04509624172198145
# 2026-02-01 21:51:50,475 - mocap - INFO - Epoch 8, Train Loss: 0.03504930138097782
# 2026-02-01 21:51:52,845 - mocap - INFO - Epoch 9, Train Loss: 0.03006997658920131
# 2026-02-01 21:51:55,005 - mocap - INFO - Epoch 10, Train Loss: 0.025433090691895862
# 2026-02-01 21:51:58,811 - mocap - INFO - Accuracy: 0.9066551426101987
# 2026-02-01 21:51:58,813 - mocap - INFO - Precision: 0.842680262199563
# 2026-02-01 21:51:58,814 - mocap - INFO - Recall: 1.0
# 2026-02-01 21:51:58,820 - mocap - INFO - Confusion matrix:
#         True  False
# True   1157      0
# False   216    941
# 2026-02-01 21:51:59,157 - mocap - INFO - [Iteration 2/4]
# 2026-02-01 21:51:59,253 - mocap - INFO - Train dataset size: 4452
# 2026-02-01 21:51:59,255 - mocap - INFO - Test dataset size: 884
# 2026-02-01 21:52:02,416 - mocap - INFO - Epoch 1, Train Loss: 0.2312341922628028
# 2026-02-01 21:52:05,688 - mocap - INFO - Epoch 2, Train Loss: 0.09614466958280121
# 2026-02-01 21:52:08,776 - mocap - INFO - Epoch 3, Train Loss: 0.05051613463354962
# 2026-02-01 21:52:12,037 - mocap - INFO - Epoch 4, Train Loss: 0.03617098287546209
# 2026-02-01 21:52:14,438 - mocap - INFO - Epoch 5, Train Loss: 0.03085494433928813
# 2026-02-01 21:52:17,827 - mocap - INFO - Epoch 6, Train Loss: 0.0258742310821877
# 2026-02-01 21:52:20,958 - mocap - INFO - Epoch 7, Train Loss: 0.021361290710046887
# 2026-02-01 21:52:24,231 - mocap - INFO - Epoch 8, Train Loss: 0.0179456106786217
# 2026-02-01 21:52:27,206 - mocap - INFO - Epoch 9, Train Loss: 0.019208692303592605
# 2026-02-01 21:52:29,585 - mocap - INFO - Epoch 10, Train Loss: 0.014851954136975109
# 2026-02-01 21:52:31,438 - mocap - INFO - Accuracy: 0.9536199095022625
# 2026-02-01 21:52:31,440 - mocap - INFO - Precision: 0.9151138716356108
# 2026-02-01 21:52:31,441 - mocap - INFO - Recall: 1.0
# 2026-02-01 21:52:31,445 - mocap - INFO - Confusion matrix:
#         True  False
# True    442      0
# False    41    401
# 2026-02-01 21:52:31,781 - mocap - INFO - [Iteration 3/4]
# 2026-02-01 21:52:31,854 - mocap - INFO - Train dataset size: 4034
# 2026-02-01 21:52:31,855 - mocap - INFO - Test dataset size: 1302
# 2026-02-01 21:52:34,869 - mocap - INFO - Epoch 1, Train Loss: 0.22049686488673442
# 2026-02-01 21:52:37,751 - mocap - INFO - Epoch 2, Train Loss: 0.09993344257901034
# 2026-02-01 21:52:40,891 - mocap - INFO - Epoch 3, Train Loss: 0.06122303627959386
# 2026-02-01 21:52:43,741 - mocap - INFO - Epoch 4, Train Loss: 0.04490087660007531
# 2026-02-01 21:52:45,872 - mocap - INFO - Epoch 5, Train Loss: 0.03799321019919369
# 2026-02-01 21:52:48,708 - mocap - INFO - Epoch 6, Train Loss: 0.02895534586337373
# 2026-02-01 21:52:51,511 - mocap - INFO - Epoch 7, Train Loss: 0.026187003417835225
# 2026-02-01 21:52:54,389 - mocap - INFO - Epoch 8, Train Loss: 0.02079932724939674
# 2026-02-01 21:52:57,247 - mocap - INFO - Epoch 9, Train Loss: 0.017270954582458874
# 2026-02-01 21:53:00,117 - mocap - INFO - Epoch 10, Train Loss: 0.016686293237849953
# 2026-02-01 21:53:02,655 - mocap - INFO - Accuracy: 0.9946236559139785
# 2026-02-01 21:53:02,657 - mocap - INFO - Precision: 0.9893617021276596
# 2026-02-01 21:53:02,658 - mocap - INFO - Recall: 1.0
# 2026-02-01 21:53:02,663 - mocap - INFO - Confusion matrix:
#         True  False
# True    651      0
# False     7    644
# 2026-02-01 21:53:02,964 - mocap - INFO - [Iteration 4/4]
# 2026-02-01 21:53:03,030 - mocap - INFO - Train dataset size: 4500
# 2026-02-01 21:53:03,032 - mocap - INFO - Test dataset size: 836
# 2026-02-01 21:53:05,698 - mocap - INFO - Epoch 1, Train Loss: 0.24069761992134947
# 2026-02-01 21:53:08,405 - mocap - INFO - Epoch 2, Train Loss: 0.08666975698466842
# 2026-02-01 21:53:12,103 - mocap - INFO - Epoch 3, Train Loss: 0.05438430984471495
# 2026-02-01 21:53:16,164 - mocap - INFO - Epoch 4, Train Loss: 0.04317844347988672
# 2026-02-01 21:53:19,995 - mocap - INFO - Epoch 5, Train Loss: 0.033478004471497964
# 2026-02-01 21:53:23,995 - mocap - INFO - Epoch 6, Train Loss: 0.02833632741400853
# 2026-02-01 21:53:27,052 - mocap - INFO - Epoch 7, Train Loss: 0.02660797969669315
# 2026-02-01 21:53:30,190 - mocap - INFO - Epoch 8, Train Loss: 0.02351508642454361
# 2026-02-01 21:53:33,422 - mocap - INFO - Epoch 9, Train Loss: 0.019973319245119255
# 2026-02-01 21:53:35,994 - mocap - INFO - Epoch 10, Train Loss: 0.022001844493949665
# 2026-02-01 21:53:37,123 - mocap - INFO - Accuracy: 0.9820574162679426
# 2026-02-01 21:53:37,125 - mocap - INFO - Precision: 0.9653579676674365
# 2026-02-01 21:53:37,125 - mocap - INFO - Recall: 1.0
# 2026-02-01 21:53:37,130 - mocap - INFO - Confusion matrix:
#         True  False
# True    418      0
# False    15    403
# 2026-02-01 21:53:37,477 - mocap - INFO - Results will be saved to WindowsPath('results/predictions_cv/mocap_cycles_lstm.csv')
# 2026-02-01 21:53:37,501 - mocap - INFO -
#
# 2026-02-01 21:53:37,504 - mocap - INFO - Combined evaluation
# 2026-02-01 21:53:37,504 - mocap - INFO - **************************************************
# 2026-02-01 21:53:37,835 - mocap - INFO - Area under ROC curve: 0.9960084144584379
# 2026-02-01 21:53:37,862 - mocap - INFO - Accuracy: 0.9477136431784108
# 2026-02-01 21:53:37,863 - mocap - INFO - Precision: 0.9053274516457415
# 2026-02-01 21:53:37,864 - mocap - INFO - Recall: 1.0
# 2026-02-01 21:53:37,872 - mocap - INFO - Confusion matrix:
#         True  False
# True   2668      0
# False   279   2389
# 2026-02-01 21:53:38,133 - mocap - INFO - & accuracy & precision &  recall  &   auroc
# 2026-02-01 21:53:38,134 - mocap - INFO - & 94.77    & 90.53     & 100.00     & 99.60
# (0.9477136431784108, 0.9053274516457415, 1.0, 0.9960084144584379)

# %%
cv = CrossValidationSiameseRaw(
    sequence_cycles=yolo_cycles, 
    coordinates_idx=CoordinatesIdx(0, 1, 2), 
    log_level=logging.INFO,
    logger_name = 'yolo',
)
cv.count_participants_samples()
cv.perform_training(
    n_folds = 4,
    siamese_nn_type = "conv1d",
    learning_rate = 1e-3,
    batch_size = 32,
    n_epochs = 15,
    threshold = 0.5,
    show_plot = True, 
    csv_file_path = Path('results/predictions_cv/yolo_cycles_conv1d.csv'),
)
# Out:
# 2026-02-01 21:53:38,155 - yolo - INFO - Preparing cycles and participant labels...
# 2026-02-01 21:53:52,316 - yolo - INFO - [Iteration 1/4]
# 2026-02-01 21:53:52,371 - yolo - INFO - Train dataset size: 1944
# 2026-02-01 21:53:52,373 - yolo - INFO - Test dataset size: 1722
# 2026-02-01 21:53:53,492 - yolo - INFO - Epoch 1, Train Loss: 0.4581533639584897
# 2026-02-01 21:53:54,574 - yolo - INFO - Epoch 2, Train Loss: 0.032895895850951554
# 2026-02-01 21:53:55,631 - yolo - INFO - Epoch 3, Train Loss: 0.028120289022316697
# 2026-02-01 21:53:56,588 - yolo - INFO - Epoch 4, Train Loss: 0.017720450647175312
# 2026-02-01 21:53:57,417 - yolo - INFO - Epoch 5, Train Loss: 0.010238032589559673
# 2026-02-01 21:53:58,449 - yolo - INFO - Epoch 6, Train Loss: 0.015022805685818683
# 2026-02-01 21:53:59,536 - yolo - INFO - Epoch 7, Train Loss: 0.014344211973127772
# 2026-02-01 21:54:00,751 - yolo - INFO - Epoch 8, Train Loss: 0.015161302551382878
# 2026-02-01 21:54:02,076 - yolo - INFO - Epoch 9, Train Loss: 0.010155435781315213
# 2026-02-01 21:54:03,284 - yolo - INFO - Epoch 10, Train Loss: 0.009353563647534027
# 2026-02-01 21:54:04,511 - yolo - INFO - Epoch 11, Train Loss: 0.009921835414821008
# 2026-02-01 21:54:05,718 - yolo - INFO - Epoch 12, Train Loss: 0.00621789581615661
# 2026-02-01 21:54:06,920 - yolo - INFO - Epoch 13, Train Loss: 0.010304673727540696
# 2026-02-01 21:54:08,259 - yolo - INFO - Epoch 14, Train Loss: 0.009558818656111473
# 2026-02-01 21:54:09,669 - yolo - INFO - Epoch 15, Train Loss: 0.010064667113674958
# 2026-02-01 21:54:11,604 - yolo - INFO - Accuracy: 0.9878048780487805
# 2026-02-01 21:54:11,605 - yolo - INFO - Precision: 0.9761904761904762
# 2026-02-01 21:54:11,606 - yolo - INFO - Recall: 1.0
# 2026-02-01 21:54:11,612 - yolo - INFO - Confusion matrix:
#         True  False
# True    861      0
# False    21    840
# 2026-02-01 21:54:11,931 - yolo - INFO - [Iteration 2/4]
# 2026-02-01 21:54:11,976 - yolo - INFO - Train dataset size: 3126
# 2026-02-01 21:54:11,978 - yolo - INFO - Test dataset size: 540
# 2026-02-01 21:54:13,731 - yolo - INFO - Epoch 1, Train Loss: 0.38969783321479146
# 2026-02-01 21:54:15,449 - yolo - INFO - Epoch 2, Train Loss: 0.03065478813131245
# 2026-02-01 21:54:17,143 - yolo - INFO - Epoch 3, Train Loss: 0.03226507763017197
# 2026-02-01 21:54:18,831 - yolo - INFO - Epoch 4, Train Loss: 0.01613426744006574
# 2026-02-01 21:54:20,676 - yolo - INFO - Epoch 5, Train Loss: 0.015797787597783063
# 2026-02-01 21:54:22,353 - yolo - INFO - Epoch 6, Train Loss: 0.011442410526797175
# 2026-02-01 21:54:24,044 - yolo - INFO - Epoch 7, Train Loss: 0.011929581205512643
# 2026-02-01 21:54:25,868 - yolo - INFO - Epoch 8, Train Loss: 0.008146184565480418
# 2026-02-01 21:54:27,638 - yolo - INFO - Epoch 9, Train Loss: 0.0104744452365427
# 2026-02-01 21:54:29,467 - yolo - INFO - Epoch 10, Train Loss: 0.010842966343447263
# 2026-02-01 21:54:30,909 - yolo - INFO - Epoch 11, Train Loss: 0.010846697129024079
# 2026-02-01 21:54:32,332 - yolo - INFO - Epoch 12, Train Loss: 0.008419599716684647
# 2026-02-01 21:54:33,625 - yolo - INFO - Epoch 13, Train Loss: 0.005788400984839632
# 2026-02-01 21:54:34,855 - yolo - INFO - Epoch 14, Train Loss: 0.00535718676793313
# 2026-02-01 21:54:36,034 - yolo - INFO - Epoch 15, Train Loss: 0.004476978938328102
# 2026-02-01 21:54:36,416 - yolo - INFO - Accuracy: 1.0
# 2026-02-01 21:54:36,418 - yolo - INFO - Precision: 1.0
# 2026-02-01 21:54:36,418 - yolo - INFO - Recall: 1.0
# 2026-02-01 21:54:36,421 - yolo - INFO - Confusion matrix:
#         True  False
# True    270      0
# False     0    270
# 2026-02-01 21:54:36,871 - yolo - INFO - [Iteration 3/4]
# 2026-02-01 21:54:36,912 - yolo - INFO - Train dataset size: 2786
# 2026-02-01 21:54:36,913 - yolo - INFO - Test dataset size: 880
# 2026-02-01 21:54:38,003 - yolo - INFO - Epoch 1, Train Loss: 0.3487352207303047
# 2026-02-01 21:54:39,102 - yolo - INFO - Epoch 2, Train Loss: 0.026363045437557794
# 2026-02-01 21:54:40,212 - yolo - INFO - Epoch 3, Train Loss: 0.023244640699968757
# 2026-02-01 21:54:41,278 - yolo - INFO - Epoch 4, Train Loss: 0.013381565431535075
# 2026-02-01 21:54:42,420 - yolo - INFO - Epoch 5, Train Loss: 0.014403230722316286
# 2026-02-01 21:54:43,498 - yolo - INFO - Epoch 6, Train Loss: 0.01810740421272137
# 2026-02-01 21:54:44,585 - yolo - INFO - Epoch 7, Train Loss: 0.013681206047873606
# 2026-02-01 21:54:45,627 - yolo - INFO - Epoch 8, Train Loss: 0.007341270764961585
# 2026-02-01 21:54:46,674 - yolo - INFO - Epoch 9, Train Loss: 0.007973637388204224
# 2026-02-01 21:54:47,711 - yolo - INFO - Epoch 10, Train Loss: 0.008606475810996595
# 2026-02-01 21:54:48,847 - yolo - INFO - Epoch 11, Train Loss: 0.00619180157743606
# 2026-02-01 21:54:49,964 - yolo - INFO - Epoch 12, Train Loss: 0.008345067870157602
# 2026-02-01 21:54:51,070 - yolo - INFO - Epoch 13, Train Loss: 0.007260665191014678
# 2026-02-01 21:54:52,111 - yolo - INFO - Epoch 14, Train Loss: 0.004759757735882886
# 2026-02-01 21:54:53,193 - yolo - INFO - Epoch 15, Train Loss: 0.0050667933564082805
# 2026-02-01 21:54:53,853 - yolo - INFO - Accuracy: 0.95
# 2026-02-01 21:54:53,855 - yolo - INFO - Precision: 0.9974874371859297
# 2026-02-01 21:54:53,855 - yolo - INFO - Recall: 0.9022727272727272
# 2026-02-01 21:54:53,859 - yolo - INFO - Confusion matrix:
#         True  False
# True    397     43
# False     1    439
# 2026-02-01 21:54:54,095 - yolo - INFO - [Iteration 4/4]
# 2026-02-01 21:54:54,137 - yolo - INFO - Train dataset size: 3142
# 2026-02-01 21:54:54,138 - yolo - INFO - Test dataset size: 524
# 2026-02-01 21:54:55,324 - yolo - INFO - Epoch 1, Train Loss: 0.38276201172383745
# 2026-02-01 21:54:56,532 - yolo - INFO - Epoch 2, Train Loss: 0.03764184098690748
# 2026-02-01 21:54:57,801 - yolo - INFO - Epoch 3, Train Loss: 0.03238415834729118
# 2026-02-01 21:54:58,954 - yolo - INFO - Epoch 4, Train Loss: 0.023056680296613563
# 2026-02-01 21:55:00,265 - yolo - INFO - Epoch 5, Train Loss: 0.023369935331772073
# 2026-02-01 21:55:01,580 - yolo - INFO - Epoch 6, Train Loss: 0.01750540808595792
# 2026-02-01 21:55:02,781 - yolo - INFO - Epoch 7, Train Loss: 0.018458447891823722
# 2026-02-01 21:55:04,004 - yolo - INFO - Epoch 8, Train Loss: 0.012250133576059733
# 2026-02-01 21:55:05,259 - yolo - INFO - Epoch 9, Train Loss: 0.010773149652952197
# 2026-02-01 21:55:06,414 - yolo - INFO - Epoch 10, Train Loss: 0.01143108798905906
# 2026-02-01 21:55:07,639 - yolo - INFO - Epoch 11, Train Loss: 0.014172181382427236
# 2026-02-01 21:55:08,876 - yolo - INFO - Epoch 12, Train Loss: 0.009241542515504842
# 2026-02-01 21:55:10,092 - yolo - INFO - Epoch 13, Train Loss: 0.010597989206540991
# 2026-02-01 21:55:11,422 - yolo - INFO - Epoch 14, Train Loss: 0.009218739646703306
# 2026-02-01 21:55:12,638 - yolo - INFO - Epoch 15, Train Loss: 0.007310766943100125
# 2026-02-01 21:55:13,016 - yolo - INFO - Accuracy: 0.9980916030534351
# 2026-02-01 21:55:13,018 - yolo - INFO - Precision: 0.9961977186311787
# 2026-02-01 21:55:13,018 - yolo - INFO - Recall: 1.0
# 2026-02-01 21:55:13,021 - yolo - INFO - Confusion matrix:
#         True  False
# True    262      0
# False     1    261
# 2026-02-01 21:55:13,233 - yolo - INFO - Results will be saved to WindowsPath('results/predictions_cv/yolo_cycles_conv1d.csv')
# 2026-02-01 21:55:13,243 - yolo - INFO -
#
# 2026-02-01 21:55:13,244 - yolo - INFO - Combined evaluation
# 2026-02-01 21:55:13,245 - yolo - INFO - **************************************************
# 2026-02-01 21:55:13,508 - yolo - INFO - Area under ROC curve: 0.9981941367705897
# 2026-02-01 21:55:13,522 - yolo - INFO - Accuracy: 0.9819967266775778
# 2026-02-01 21:55:13,523 - yolo - INFO - Precision: 0.9873138444567016
# 2026-02-01 21:55:13,523 - yolo - INFO - Recall: 0.9765411893071467
# 2026-02-01 21:55:13,527 - yolo - INFO - Confusion matrix:
#         True  False
# True   1790     43
# False    23   1810
# 2026-02-01 21:55:13,756 - yolo - INFO - & accuracy & precision &  recall  &   auroc
# 2026-02-01 21:55:13,757 - yolo - INFO - & 98.20    & 98.73     & 97.65     & 99.82
# (0.9819967266775778,
#  0.9873138444567016,
#  0.9765411893071467,
#  0.9981941367705897)

# %%
cv = CrossValidationSiameseRaw(
    sequence_cycles=yolo_cycles, 
    coordinates_idx=CoordinatesIdx(0, 1, 2), 
    log_level=logging.INFO,
    logger_name = 'yolo',
)
cv.count_participants_samples()
cv.perform_training(
    n_folds = 4,
    siamese_nn_type = "lstm",
    learning_rate = 1e-4,
    batch_size = 32,
    n_epochs = 15,
    threshold = 0.5,
    show_plot = True,  
    csv_file_path = Path('results/predictions_cv/yolo_cycles_lstm.csv'),
)
# Out:
# 2026-02-01 23:09:43,978 - yolo - INFO - Preparing cycles and participant labels...
# 2026-02-01 23:10:04,158 - yolo - INFO - [Iteration 1/4]
# 2026-02-01 23:10:04,235 - yolo - INFO - Train dataset size: 1944
# 2026-02-01 23:10:04,237 - yolo - INFO - Test dataset size: 1722
# 2026-02-01 23:10:07,011 - yolo - INFO - Epoch 1, Train Loss: 0.3118499747065247
# 2026-02-01 23:10:09,991 - yolo - INFO - Epoch 2, Train Loss: 0.23244096192180133
# 2026-02-01 23:10:12,722 - yolo - INFO - Epoch 3, Train Loss: 0.19175294725621334
# 2026-02-01 23:10:15,416 - yolo - INFO - Epoch 4, Train Loss: 0.18833264659662716
# 2026-02-01 23:10:17,961 - yolo - INFO - Epoch 5, Train Loss: 0.16528937293857823
# 2026-02-01 23:10:20,547 - yolo - INFO - Epoch 6, Train Loss: 0.1418031297746252
# 2026-02-01 23:10:22,872 - yolo - INFO - Epoch 7, Train Loss: 0.12036030800616154
# 2026-02-01 23:10:25,060 - yolo - INFO - Epoch 8, Train Loss: 0.10034597701713686
# 2026-02-01 23:10:27,612 - yolo - INFO - Epoch 9, Train Loss: 0.09676764410783033
# 2026-02-01 23:10:29,881 - yolo - INFO - Epoch 10, Train Loss: 0.07992792941752028
# 2026-02-01 23:10:32,375 - yolo - INFO - Epoch 11, Train Loss: 0.07186341774268229
# 2026-02-01 23:10:34,696 - yolo - INFO - Epoch 12, Train Loss: 0.06590863179842957
# 2026-02-01 23:10:36,962 - yolo - INFO - Epoch 13, Train Loss: 0.06055596162427644
# 2026-02-01 23:10:39,585 - yolo - INFO - Epoch 14, Train Loss: 0.05827758253597822
# 2026-02-01 23:10:41,817 - yolo - INFO - Epoch 15, Train Loss: 0.05411646151762517
# 2026-02-01 23:10:52,047 - yolo - INFO - Accuracy: 0.8977932636469221
# 2026-02-01 23:10:52,049 - yolo - INFO - Precision: 0.8302796528447445
# 2026-02-01 23:10:52,050 - yolo - INFO - Recall: 1.0
# 2026-02-01 23:10:52,056 - yolo - INFO - Confusion matrix:
#         True  False
# True    861      0
# False   176    685
# 2026-02-01 23:10:52,463 - yolo - INFO - [Iteration 2/4]
# 2026-02-01 23:10:52,544 - yolo - INFO - Train dataset size: 3126
# 2026-02-01 23:10:52,546 - yolo - INFO - Test dataset size: 540
# 2026-02-01 23:10:59,376 - yolo - INFO - Epoch 1, Train Loss: 0.31323817691632677
# 2026-02-01 23:11:04,770 - yolo - INFO - Epoch 2, Train Loss: 0.1915300975800777
# 2026-02-01 23:11:11,591 - yolo - INFO - Epoch 3, Train Loss: 0.10638700087307668
# 2026-02-01 23:11:17,161 - yolo - INFO - Epoch 4, Train Loss: 0.059020202397844015
# 2026-02-01 23:11:19,569 - yolo - INFO - Epoch 5, Train Loss: 0.044835119023538976
# 2026-02-01 23:11:21,582 - yolo - INFO - Epoch 6, Train Loss: 0.03879234860461129
# 2026-02-01 23:11:23,821 - yolo - INFO - Epoch 7, Train Loss: 0.0371192092437069
# 2026-02-01 23:11:25,823 - yolo - INFO - Epoch 8, Train Loss: 0.03233688552768863
# 2026-02-01 23:11:27,882 - yolo - INFO - Epoch 9, Train Loss: 0.0303578406705388
# 2026-02-01 23:11:30,076 - yolo - INFO - Epoch 10, Train Loss: 0.029497850073349416
# 2026-02-01 23:11:32,187 - yolo - INFO - Epoch 11, Train Loss: 0.024783123769246195
# 2026-02-01 23:11:34,559 - yolo - INFO - Epoch 12, Train Loss: 0.023173673349261587
# 2026-02-01 23:11:36,602 - yolo - INFO - Epoch 13, Train Loss: 0.026039955001894613
# 2026-02-01 23:11:38,814 - yolo - INFO - Epoch 14, Train Loss: 0.024607932522930965
# 2026-02-01 23:11:40,974 - yolo - INFO - Epoch 15, Train Loss: 0.027590039383372938
# 2026-02-01 23:11:41,943 - yolo - INFO - Accuracy: 0.8944444444444445
# 2026-02-01 23:11:41,944 - yolo - INFO - Precision: 0.8256880733944955
# 2026-02-01 23:11:41,945 - yolo - INFO - Recall: 1.0
# 2026-02-01 23:11:41,949 - yolo - INFO - Confusion matrix:
#         True  False
# True    270      0
# False    57    213
# 2026-02-01 23:11:42,258 - yolo - INFO - [Iteration 3/4]
# 2026-02-01 23:11:42,306 - yolo - INFO - Train dataset size: 2786
# 2026-02-01 23:11:42,307 - yolo - INFO - Test dataset size: 880
# 2026-02-01 23:11:44,566 - yolo - INFO - Epoch 1, Train Loss: 0.2757098101587458
# 2026-02-01 23:11:45,972 - yolo - INFO - Epoch 2, Train Loss: 0.18369590093127705
# 2026-02-01 23:11:47,346 - yolo - INFO - Epoch 3, Train Loss: 0.12468619788573547
# 2026-02-01 23:11:48,702 - yolo - INFO - Epoch 4, Train Loss: 0.09342756518162787
# 2026-02-01 23:11:49,999 - yolo - INFO - Epoch 5, Train Loss: 0.07739570023576645
# 2026-02-01 23:11:51,343 - yolo - INFO - Epoch 6, Train Loss: 0.06174375453900376
# 2026-02-01 23:11:52,750 - yolo - INFO - Epoch 7, Train Loss: 0.06079834913411601
# 2026-02-01 23:11:54,122 - yolo - INFO - Epoch 8, Train Loss: 0.054506045670925894
# 2026-02-01 23:11:55,435 - yolo - INFO - Epoch 9, Train Loss: 0.04655702230097218
# 2026-02-01 23:11:56,840 - yolo - INFO - Epoch 10, Train Loss: 0.04517648789227347
# 2026-02-01 23:11:58,418 - yolo - INFO - Epoch 11, Train Loss: 0.0396260127785023
# 2026-02-01 23:11:59,737 - yolo - INFO - Epoch 12, Train Loss: 0.03682386383033273
# 2026-02-01 23:12:01,060 - yolo - INFO - Epoch 13, Train Loss: 0.038321315056898377
# 2026-02-01 23:12:02,540 - yolo - INFO - Epoch 14, Train Loss: 0.03557591802779247
# 2026-02-01 23:12:04,679 - yolo - INFO - Epoch 15, Train Loss: 0.029982656875455923
# 2026-02-01 23:12:06,474 - yolo - INFO - Accuracy: 0.9329545454545455
# 2026-02-01 23:12:06,476 - yolo - INFO - Precision: 0.9186813186813186
# 2026-02-01 23:12:06,477 - yolo - INFO - Recall: 0.95
# 2026-02-01 23:12:06,481 - yolo - INFO - Confusion matrix:
#         True  False
# True    418     22
# False    37    403
# 2026-02-01 23:12:06,825 - yolo - INFO - [Iteration 4/4]
# 2026-02-01 23:12:06,885 - yolo - INFO - Train dataset size: 3142
# 2026-02-01 23:12:06,886 - yolo - INFO - Test dataset size: 524
# 2026-02-01 23:12:09,292 - yolo - INFO - Epoch 1, Train Loss: 0.2830008983311027
# 2026-02-01 23:12:11,433 - yolo - INFO - Epoch 2, Train Loss: 0.16982176802074067
# 2026-02-01 23:12:13,537 - yolo - INFO - Epoch 3, Train Loss: 0.10328303510793532
# 2026-02-01 23:12:15,927 - yolo - INFO - Epoch 4, Train Loss: 0.06882297992706299
# 2026-02-01 23:12:18,219 - yolo - INFO - Epoch 5, Train Loss: 0.05232499421320178
# 2026-02-01 23:12:20,291 - yolo - INFO - Epoch 6, Train Loss: 0.04801270278227149
# 2026-02-01 23:12:22,578 - yolo - INFO - Epoch 7, Train Loss: 0.04644557399995098
# 2026-02-01 23:12:24,753 - yolo - INFO - Epoch 8, Train Loss: 0.038454427195694106
# 2026-02-01 23:12:27,012 - yolo - INFO - Epoch 9, Train Loss: 0.03656976140160678
# 2026-02-01 23:12:29,233 - yolo - INFO - Epoch 10, Train Loss: 0.03329669595037521
# 2026-02-01 23:12:31,332 - yolo - INFO - Epoch 11, Train Loss: 0.030655037009655828
# 2026-02-01 23:12:33,225 - yolo - INFO - Epoch 12, Train Loss: 0.03247562657590165
# 2026-02-01 23:12:34,988 - yolo - INFO - Epoch 13, Train Loss: 0.03153977571337512
# 2026-02-01 23:12:37,279 - yolo - INFO - Epoch 14, Train Loss: 0.029389526323424748
# 2026-02-01 23:12:39,808 - yolo - INFO - Epoch 15, Train Loss: 0.026502197133283122
# 2026-02-01 23:12:40,765 - yolo - INFO - Accuracy: 0.9694656488549618
# 2026-02-01 23:12:40,767 - yolo - INFO - Precision: 0.9424460431654677
# 2026-02-01 23:12:40,768 - yolo - INFO - Recall: 1.0
# 2026-02-01 23:12:40,772 - yolo - INFO - Confusion matrix:
#         True  False
# True    262      0
# False    16    246
# 2026-02-01 23:12:41,109 - yolo - INFO - Results will be saved to WindowsPath('results/predictions_cv/yolo_cycles_lstm.csv')
# 2026-02-01 23:12:41,123 - yolo - INFO -
#
# 2026-02-01 23:12:41,125 - yolo - INFO - Combined evaluation
# 2026-02-01 23:12:41,126 - yolo - INFO - **************************************************
# 2026-02-01 23:12:41,451 - yolo - INFO - Area under ROC curve: 0.9729229150129661
# 2026-02-01 23:12:41,468 - yolo - INFO - Accuracy: 0.9159847244953628
# 2026-02-01 23:12:41,469 - yolo - INFO - Precision: 0.8636146876490224
# 2026-02-01 23:12:41,470 - yolo - INFO - Recall: 0.9879978177850518
# 2026-02-01 23:12:41,477 - yolo - INFO - Confusion matrix:
#         True  False
# True   1811     22
# False   286   1547
# 2026-02-01 23:12:41,765 - yolo - INFO - & accuracy & precision &  recall  &   auroc
# 2026-02-01 23:12:41,766 - yolo - INFO - & 91.60    & 86.36     & 98.80     & 97.29
# (0.9159847244953628,
#  0.8636146876490224,
#  0.9879978177850518,
#  0.9729229150129661)

# %%
cv = CrossValidationSiameseRaw(
    sequence_cycles=yolo_best_cams_cycles, 
    coordinates_idx=CoordinatesIdx(0, 1, 2),
    log_level=logging.INFO,
    logger_name = 'yolo_best_cameras',
)
cv.count_participants_samples()
cv.perform_training(
    n_folds = 4,
    siamese_nn_type = "conv1d",
    learning_rate = 1e-3,
    batch_size = 32,
    n_epochs = 10,
    threshold = 0.5,
    show_plot = True, 
    csv_file_path = Path('results/predictions_cv/yolo_best_cams_cycles_conv1d.csv'),
)
# Out:
# 2026-02-01 21:56:43,584 - yolo_best_cameras - INFO - Preparing cycles and participant labels...
# 2026-02-01 21:56:54,877 - yolo_best_cameras - INFO - [Iteration 1/4]
# 2026-02-01 21:56:54,916 - yolo_best_cameras - INFO - Train dataset size: 2276
# 2026-02-01 21:56:54,917 - yolo_best_cameras - INFO - Test dataset size: 1710
# 2026-02-01 21:56:55,787 - yolo_best_cameras - INFO - Epoch 1, Train Loss: 0.6707272610834075
# 2026-02-01 21:56:56,655 - yolo_best_cameras - INFO - Epoch 2, Train Loss: 0.06074211451535424
# 2026-02-01 21:56:57,638 - yolo_best_cameras - INFO - Epoch 3, Train Loss: 0.038185935637253955
# 2026-02-01 21:56:58,583 - yolo_best_cameras - INFO - Epoch 4, Train Loss: 0.03578051394369039
# 2026-02-01 21:56:59,421 - yolo_best_cameras - INFO - Epoch 5, Train Loss: 0.031239721458405256
# 2026-02-01 21:57:00,496 - yolo_best_cameras - INFO - Epoch 6, Train Loss: 0.029903012289044757
# 2026-02-01 21:57:01,419 - yolo_best_cameras - INFO - Epoch 7, Train Loss: 0.023681990252549037
# 2026-02-01 21:57:02,315 - yolo_best_cameras - INFO - Epoch 8, Train Loss: 0.02539513491339878
# 2026-02-01 21:57:03,225 - yolo_best_cameras - INFO - Epoch 9, Train Loss: 0.019716232614074316
# 2026-02-01 21:57:04,166 - yolo_best_cameras - INFO - Epoch 10, Train Loss: 0.019145935230577987
# 2026-02-01 21:57:05,356 - yolo_best_cameras - INFO - Accuracy: 0.9888888888888889
# 2026-02-01 21:57:05,357 - yolo_best_cameras - INFO - Precision: 0.9782608695652174
# 2026-02-01 21:57:05,357 - yolo_best_cameras - INFO - Recall: 1.0
# 2026-02-01 21:57:05,361 - yolo_best_cameras - INFO - Confusion matrix:
#         True  False
# True    855      0
# False    19    836
# 2026-02-01 21:57:05,617 - yolo_best_cameras - INFO - [Iteration 2/4]
# 2026-02-01 21:57:05,660 - yolo_best_cameras - INFO - Train dataset size: 3416
# 2026-02-01 21:57:05,661 - yolo_best_cameras - INFO - Test dataset size: 570
# 2026-02-01 21:57:06,886 - yolo_best_cameras - INFO - Epoch 1, Train Loss: 0.5076750550314645
# 2026-02-01 21:57:08,175 - yolo_best_cameras - INFO - Epoch 2, Train Loss: 0.046017268237388026
# 2026-02-01 21:57:09,517 - yolo_best_cameras - INFO - Epoch 3, Train Loss: 0.04036392277611472
# 2026-02-01 21:57:11,719 - yolo_best_cameras - INFO - Epoch 4, Train Loss: 0.0338211862857793
# 2026-02-01 21:57:13,045 - yolo_best_cameras - INFO - Epoch 5, Train Loss: 0.025270498414288894
# 2026-02-01 21:57:14,325 - yolo_best_cameras - INFO - Epoch 6, Train Loss: 0.022416341797422582
# 2026-02-01 21:57:15,721 - yolo_best_cameras - INFO - Epoch 7, Train Loss: 0.018052737785625123
# 2026-02-01 21:57:17,055 - yolo_best_cameras - INFO - Epoch 8, Train Loss: 0.016943832972548277
# 2026-02-01 21:57:18,364 - yolo_best_cameras - INFO - Epoch 9, Train Loss: 0.010652236261831545
# 2026-02-01 21:57:19,633 - yolo_best_cameras - INFO - Epoch 10, Train Loss: 0.010449776819811385
# 2026-02-01 21:57:20,066 - yolo_best_cameras - INFO - Accuracy: 0.9964912280701754
# 2026-02-01 21:57:20,067 - yolo_best_cameras - INFO - Precision: 0.9930313588850174
# 2026-02-01 21:57:20,068 - yolo_best_cameras - INFO - Recall: 1.0
# 2026-02-01 21:57:20,071 - yolo_best_cameras - INFO - Confusion matrix:
#         True  False
# True    285      0
# False     2    283
# 2026-02-01 21:57:20,307 - yolo_best_cameras - INFO - [Iteration 3/4]
# 2026-02-01 21:57:20,350 - yolo_best_cameras - INFO - Train dataset size: 2792
# 2026-02-01 21:57:20,351 - yolo_best_cameras - INFO - Test dataset size: 1194
# 2026-02-01 21:57:21,417 - yolo_best_cameras - INFO - Epoch 1, Train Loss: 0.346134845670101
# 2026-02-01 21:57:22,563 - yolo_best_cameras - INFO - Epoch 2, Train Loss: 0.03301586805504154
# 2026-02-01 21:57:23,668 - yolo_best_cameras - INFO - Epoch 3, Train Loss: 0.021259045355360617
# 2026-02-01 21:57:24,785 - yolo_best_cameras - INFO - Epoch 4, Train Loss: 0.014620753036896613
# 2026-02-01 21:57:25,910 - yolo_best_cameras - INFO - Epoch 5, Train Loss: 0.01397848199121654
# 2026-02-01 21:57:26,983 - yolo_best_cameras - INFO - Epoch 6, Train Loss: 0.010065397213276645
# 2026-02-01 21:57:28,034 - yolo_best_cameras - INFO - Epoch 7, Train Loss: 0.004406802842409393
# 2026-02-01 21:57:29,082 - yolo_best_cameras - INFO - Epoch 8, Train Loss: 0.00771150830934692
# 2026-02-01 21:57:30,137 - yolo_best_cameras - INFO - Epoch 9, Train Loss: 0.006153388433052565
# 2026-02-01 21:57:31,220 - yolo_best_cameras - INFO - Epoch 10, Train Loss: 0.00469939467174382
# 2026-02-01 21:57:32,115 - yolo_best_cameras - INFO - Accuracy: 0.8542713567839196
# 2026-02-01 21:57:32,116 - yolo_best_cameras - INFO - Precision: 0.9953161592505855
# 2026-02-01 21:57:32,117 - yolo_best_cameras - INFO - Recall: 0.711892797319933
# 2026-02-01 21:57:32,121 - yolo_best_cameras - INFO - Confusion matrix:
#         True  False
# True    425    172
# False     2    595
# 2026-02-01 21:57:32,327 - yolo_best_cameras - INFO - [Iteration 4/4]
# 2026-02-01 21:57:32,369 - yolo_best_cameras - INFO - Train dataset size: 3474
# 2026-02-01 21:57:32,371 - yolo_best_cameras - INFO - Test dataset size: 512
# 2026-02-01 21:57:33,696 - yolo_best_cameras - INFO - Epoch 1, Train Loss: 0.3058840665248556
# 2026-02-01 21:57:34,993 - yolo_best_cameras - INFO - Epoch 2, Train Loss: 0.05053901638186306
# 2026-02-01 21:57:36,312 - yolo_best_cameras - INFO - Epoch 3, Train Loss: 0.03602590730601768
# 2026-02-01 21:57:37,699 - yolo_best_cameras - INFO - Epoch 4, Train Loss: 0.026359844730671392
# 2026-02-01 21:57:38,984 - yolo_best_cameras - INFO - Epoch 5, Train Loss: 0.023952749207479144
# 2026-02-01 21:57:40,346 - yolo_best_cameras - INFO - Epoch 6, Train Loss: 0.018228767038143558
# 2026-02-01 21:57:41,679 - yolo_best_cameras - INFO - Epoch 7, Train Loss: 0.01585950848962599
# 2026-02-01 21:57:43,153 - yolo_best_cameras - INFO - Epoch 8, Train Loss: 0.01625866733423067
# 2026-02-01 21:57:44,531 - yolo_best_cameras - INFO - Epoch 9, Train Loss: 0.01193114927619559
# 2026-02-01 21:57:45,887 - yolo_best_cameras - INFO - Epoch 10, Train Loss: 0.012162189917861048
# 2026-02-01 21:57:46,290 - yolo_best_cameras - INFO - Accuracy: 0.994140625
# 2026-02-01 21:57:46,292 - yolo_best_cameras - INFO - Precision: 0.9884169884169884
# 2026-02-01 21:57:46,292 - yolo_best_cameras - INFO - Recall: 1.0
# 2026-02-01 21:57:46,295 - yolo_best_cameras - INFO - Confusion matrix:
#         True  False
# True    256      0
# False     3    253
# 2026-02-01 21:57:46,501 - yolo_best_cameras - INFO - Results will be saved to WindowsPath('results/predictions_cv/yolo_best_cams_cycles_conv1d.csv')
# 2026-02-01 21:57:46,512 - yolo_best_cameras - INFO -
#
# 2026-02-01 21:57:46,513 - yolo_best_cameras - INFO - Combined evaluation
# 2026-02-01 21:57:46,514 - yolo_best_cameras - INFO - **************************************************
# 2026-02-01 21:57:46,767 - yolo_best_cameras - INFO - Area under ROC curve: 0.974187251969953
# 2026-02-01 21:57:46,781 - yolo_best_cameras - INFO - Accuracy: 0.9503261414952333
# 2026-02-01 21:57:46,781 - yolo_best_cameras - INFO - Precision: 0.9859231185706551
# 2026-02-01 21:57:46,782 - yolo_best_cameras - INFO - Recall: 0.9136979427997993
# 2026-02-01 21:57:46,786 - yolo_best_cameras - INFO - Confusion matrix:
#         True  False
# True   1821    172
# False    26   1967
# 2026-02-01 21:57:47,000 - yolo_best_cameras - INFO - & accuracy & precision &  recall  &   auroc
# 2026-02-01 21:57:47,000 - yolo_best_cameras - INFO - & 95.03    & 98.59     & 91.37     & 97.42
# (0.9503261414952333, 0.9859231185706551, 0.9136979427997993, 0.974187251969953)

# %%
cv = CrossValidationSiameseRaw(
    sequence_cycles=yolo_best_cams_cycles, 
    coordinates_idx=CoordinatesIdx(0, 1, 2), 
    log_level=logging.INFO,
    logger_name = 'yolo_best_cameras',
)
cv.count_participants_samples()
cv.perform_training(
    n_folds = 4,
    siamese_nn_type = "lstm",
    learning_rate = 1e-4,
    batch_size = 32,
    n_epochs = 15,
    threshold = 0.5,
    show_plot = True, 
    csv_file_path = Path('results/predictions_cv/yolo_best_cams_cycles_lstm.csv'),
)
# Out:
# 2026-02-01 23:05:38,212 - yolo_best_cameras - INFO - Preparing cycles and participant labels...
# 2026-02-01 23:06:00,135 - yolo_best_cameras - INFO - [Iteration 1/4]
# 2026-02-01 23:06:00,211 - yolo_best_cameras - INFO - Train dataset size: 2276
# 2026-02-01 23:06:00,213 - yolo_best_cameras - INFO - Test dataset size: 1710
# 2026-02-01 23:06:03,260 - yolo_best_cameras - INFO - Epoch 1, Train Loss: 0.2824633266362879
# 2026-02-01 23:06:06,494 - yolo_best_cameras - INFO - Epoch 2, Train Loss: 0.19900536040465036
# 2026-02-01 23:06:09,444 - yolo_best_cameras - INFO - Epoch 3, Train Loss: 0.1543238523364481
# 2026-02-01 23:06:12,492 - yolo_best_cameras - INFO - Epoch 4, Train Loss: 0.13219823491656119
# 2026-02-01 23:06:14,969 - yolo_best_cameras - INFO - Epoch 5, Train Loss: 0.11158921181534727
# 2026-02-01 23:06:16,917 - yolo_best_cameras - INFO - Epoch 6, Train Loss: 0.09790169395920303
# 2026-02-01 23:06:18,860 - yolo_best_cameras - INFO - Epoch 7, Train Loss: 0.08985389551768701
# 2026-02-01 23:06:20,587 - yolo_best_cameras - INFO - Epoch 8, Train Loss: 0.07185089733037683
# 2026-02-01 23:06:22,305 - yolo_best_cameras - INFO - Epoch 9, Train Loss: 0.06026827895806895
# 2026-02-01 23:06:24,234 - yolo_best_cameras - INFO - Epoch 10, Train Loss: 0.050203480317981705
# 2026-02-01 23:06:26,029 - yolo_best_cameras - INFO - Epoch 11, Train Loss: 0.03906510880268696
# 2026-02-01 23:06:27,788 - yolo_best_cameras - INFO - Epoch 12, Train Loss: 0.03420419763359758
# 2026-02-01 23:06:29,653 - yolo_best_cameras - INFO - Epoch 13, Train Loss: 0.029634377201242994
# 2026-02-01 23:06:31,629 - yolo_best_cameras - INFO - Epoch 14, Train Loss: 0.0249194879628097
# 2026-02-01 23:06:33,373 - yolo_best_cameras - INFO - Epoch 15, Train Loss: 0.022838639671034697
# 2026-02-01 23:06:36,696 - yolo_best_cameras - INFO - Accuracy: 0.9508771929824561
# 2026-02-01 23:06:36,697 - yolo_best_cameras - INFO - Precision: 0.9105431309904153
# 2026-02-01 23:06:36,698 - yolo_best_cameras - INFO - Recall: 1.0
# 2026-02-01 23:06:36,702 - yolo_best_cameras - INFO - Confusion matrix:
#         True  False
# True    855      0
# False    84    771
# 2026-02-01 23:06:36,975 - yolo_best_cameras - INFO - [Iteration 2/4]
# 2026-02-01 23:06:37,026 - yolo_best_cameras - INFO - Train dataset size: 3416
# 2026-02-01 23:06:37,027 - yolo_best_cameras - INFO - Test dataset size: 570
# 2026-02-01 23:06:39,417 - yolo_best_cameras - INFO - Epoch 1, Train Loss: 0.28951363000914315
# 2026-02-01 23:06:42,373 - yolo_best_cameras - INFO - Epoch 2, Train Loss: 0.15677948929717608
# 2026-02-01 23:06:47,027 - yolo_best_cameras - INFO - Epoch 3, Train Loss: 0.09206381092004687
# 2026-02-01 23:06:51,387 - yolo_best_cameras - INFO - Epoch 4, Train Loss: 0.064436808698506
# 2026-02-01 23:06:56,018 - yolo_best_cameras - INFO - Epoch 5, Train Loss: 0.05191619833496129
# 2026-02-01 23:07:00,352 - yolo_best_cameras - INFO - Epoch 6, Train Loss: 0.04828214574883753
# 2026-02-01 23:07:04,845 - yolo_best_cameras - INFO - Epoch 7, Train Loss: 0.040613669475592744
# 2026-02-01 23:07:09,720 - yolo_best_cameras - INFO - Epoch 8, Train Loss: 0.033492435605447984
# 2026-02-01 23:07:14,260 - yolo_best_cameras - INFO - Epoch 9, Train Loss: 0.027831684667443003
# 2026-02-01 23:07:19,300 - yolo_best_cameras - INFO - Epoch 10, Train Loss: 0.034125850126843583
# 2026-02-01 23:07:23,960 - yolo_best_cameras - INFO - Epoch 11, Train Loss: 0.02717887786016843
# 2026-02-01 23:07:28,906 - yolo_best_cameras - INFO - Epoch 12, Train Loss: 0.024522601130688302
# 2026-02-01 23:07:33,656 - yolo_best_cameras - INFO - Epoch 13, Train Loss: 0.02098705571701872
# 2026-02-01 23:07:36,489 - yolo_best_cameras - INFO - Epoch 14, Train Loss: 0.01942385773818557
# 2026-02-01 23:07:40,224 - yolo_best_cameras - INFO - Epoch 15, Train Loss: 0.017993472821174937
# 2026-02-01 23:07:43,158 - yolo_best_cameras - INFO - Accuracy: 0.856140350877193
# 2026-02-01 23:07:43,160 - yolo_best_cameras - INFO - Precision: 0.776566757493188
# 2026-02-01 23:07:43,161 - yolo_best_cameras - INFO - Recall: 1.0
# 2026-02-01 23:07:43,166 - yolo_best_cameras - INFO - Confusion matrix:
#         True  False
# True    285      0
# False    82    203
# 2026-02-01 23:07:43,528 - yolo_best_cameras - INFO - [Iteration 3/4]
# 2026-02-01 23:07:43,617 - yolo_best_cameras - INFO - Train dataset size: 2792
# 2026-02-01 23:07:43,620 - yolo_best_cameras - INFO - Test dataset size: 1194
# 2026-02-01 23:07:47,265 - yolo_best_cameras - INFO - Epoch 1, Train Loss: 0.2584664514288306
# 2026-02-01 23:07:51,002 - yolo_best_cameras - INFO - Epoch 2, Train Loss: 0.15564987444403497
# 2026-02-01 23:07:54,292 - yolo_best_cameras - INFO - Epoch 3, Train Loss: 0.11980914523486387
# 2026-02-01 23:07:56,996 - yolo_best_cameras - INFO - Epoch 4, Train Loss: 0.09667299755594948
# 2026-02-01 23:07:59,232 - yolo_best_cameras - INFO - Epoch 5, Train Loss: 0.07866153785620224
# 2026-02-01 23:08:01,409 - yolo_best_cameras - INFO - Epoch 6, Train Loss: 0.057321215577592906
# 2026-02-01 23:08:03,748 - yolo_best_cameras - INFO - Epoch 7, Train Loss: 0.045872311065481466
# 2026-02-01 23:08:06,138 - yolo_best_cameras - INFO - Epoch 8, Train Loss: 0.03882415933449837
# 2026-02-01 23:08:08,716 - yolo_best_cameras - INFO - Epoch 9, Train Loss: 0.03563426016956906
# 2026-02-01 23:08:11,196 - yolo_best_cameras - INFO - Epoch 10, Train Loss: 0.03233120931227776
# 2026-02-01 23:08:13,494 - yolo_best_cameras - INFO - Epoch 11, Train Loss: 0.03003588858568533
# 2026-02-01 23:08:15,850 - yolo_best_cameras - INFO - Epoch 12, Train Loss: 0.024693818130551583
# 2026-02-01 23:08:18,528 - yolo_best_cameras - INFO - Epoch 13, Train Loss: 0.02362104371952062
# 2026-02-01 23:08:21,877 - yolo_best_cameras - INFO - Epoch 14, Train Loss: 0.02262646811273457
# 2026-02-01 23:08:25,475 - yolo_best_cameras - INFO - Epoch 15, Train Loss: 0.021790402348745953
# 2026-02-01 23:08:32,242 - yolo_best_cameras - INFO - Accuracy: 0.9396984924623115
# 2026-02-01 23:08:32,244 - yolo_best_cameras - INFO - Precision: 0.9597197898423818
# 2026-02-01 23:08:32,245 - yolo_best_cameras - INFO - Recall: 0.9179229480737019
# 2026-02-01 23:08:32,250 - yolo_best_cameras - INFO - Confusion matrix:
#         True  False
# True    548     49
# False    23    574
# 2026-02-01 23:08:32,616 - yolo_best_cameras - INFO - [Iteration 4/4]
# 2026-02-01 23:08:32,714 - yolo_best_cameras - INFO - Train dataset size: 3474
# 2026-02-01 23:08:32,716 - yolo_best_cameras - INFO - Test dataset size: 512
# 2026-02-01 23:08:37,534 - yolo_best_cameras - INFO - Epoch 1, Train Loss: 0.2511711817815763
# 2026-02-01 23:08:42,327 - yolo_best_cameras - INFO - Epoch 2, Train Loss: 0.14678832772401496
# 2026-02-01 23:08:45,909 - yolo_best_cameras - INFO - Epoch 3, Train Loss: 0.11210965583904074
# 2026-02-01 23:08:50,278 - yolo_best_cameras - INFO - Epoch 4, Train Loss: 0.08876961681547516
# 2026-02-01 23:08:54,763 - yolo_best_cameras - INFO - Epoch 5, Train Loss: 0.07159659731278725
# 2026-02-01 23:08:59,580 - yolo_best_cameras - INFO - Epoch 6, Train Loss: 0.06259237523746053
# 2026-02-01 23:09:03,996 - yolo_best_cameras - INFO - Epoch 7, Train Loss: 0.053240148675277696
# 2026-02-01 23:09:06,991 - yolo_best_cameras - INFO - Epoch 8, Train Loss: 0.042895124524558355
# 2026-02-01 23:09:11,610 - yolo_best_cameras - INFO - Epoch 9, Train Loss: 0.03742083281688734
# 2026-02-01 23:09:16,101 - yolo_best_cameras - INFO - Epoch 10, Train Loss: 0.0353349432383382
# 2026-02-01 23:09:20,599 - yolo_best_cameras - INFO - Epoch 11, Train Loss: 0.02998599615118919
# 2026-02-01 23:09:24,956 - yolo_best_cameras - INFO - Epoch 12, Train Loss: 0.02801056597552715
# 2026-02-01 23:09:29,773 - yolo_best_cameras - INFO - Epoch 13, Train Loss: 0.02815340863489503
# 2026-02-01 23:09:34,933 - yolo_best_cameras - INFO - Epoch 14, Train Loss: 0.02478530501878453
# 2026-02-01 23:09:40,016 - yolo_best_cameras - INFO - Epoch 15, Train Loss: 0.02224419706441257
# 2026-02-01 23:09:42,592 - yolo_best_cameras - INFO - Accuracy: 0.984375
# 2026-02-01 23:09:42,593 - yolo_best_cameras - INFO - Precision: 0.9696969696969697
# 2026-02-01 23:09:42,594 - yolo_best_cameras - INFO - Recall: 1.0
# 2026-02-01 23:09:42,599 - yolo_best_cameras - INFO - Confusion matrix:
#         True  False
# True    256      0
# False     8    248
# 2026-02-01 23:09:42,981 - yolo_best_cameras - INFO - Results will be saved to WindowsPath('results/predictions_cv/yolo_best_cams_cycles_lstm.csv')
# 2026-02-01 23:09:43,002 - yolo_best_cameras - INFO -
#
# 2026-02-01 23:09:43,004 - yolo_best_cameras - INFO - Combined evaluation
# 2026-02-01 23:09:43,006 - yolo_best_cameras - INFO - **************************************************
# 2026-02-01 23:09:43,485 - yolo_best_cameras - INFO - Area under ROC curve: 0.9903676918386455
# 2026-02-01 23:09:43,513 - yolo_best_cameras - INFO - Accuracy: 0.9382839939789263
# 2026-02-01 23:09:43,515 - yolo_best_cameras - INFO - Precision: 0.9079869219990658
# 2026-02-01 23:09:43,516 - yolo_best_cameras - INFO - Recall: 0.9754139488208731
# 2026-02-01 23:09:43,524 - yolo_best_cameras - INFO - Confusion matrix:
#         True  False
# True   1944     49
# False   197   1796
# 2026-02-01 23:09:43,934 - yolo_best_cameras - INFO - & accuracy & precision &  recall  &   auroc
# 2026-02-01 23:09:43,935 - yolo_best_cameras - INFO - & 93.83    & 90.80     & 97.54     & 99.04
# (0.9382839939789263,
#  0.9079869219990658,
#  0.9754139488208731,
#  0.9903676918386455)

# %%
cv = CrossValidationSiameseRaw(
    sequence_cycles=yolo_cycles_smoothed, 
    coordinates_idx=CoordinatesIdx(0, 1, 2), 
    log_level=logging.INFO,
    logger_name = 'yolo_smoothed',
)
cv.count_participants_samples()
cv.perform_training(
    n_folds = 4,
    siamese_nn_type = "conv1d",
    learning_rate = 1e-3,
    batch_size = 32,
    n_epochs = 10,
    threshold = 0.5,
    show_plot = True, 
    csv_file_path = Path('results/predictions_cv/yolo_cycles_smoothed_conv1d.csv'),
)
# Out:
# 2026-02-01 21:59:24,569 - yolo_smoothed - INFO - Preparing cycles and participant labels...
# 2026-02-01 21:59:34,577 - yolo_smoothed - INFO - [Iteration 1/4]
# 2026-02-01 21:59:34,610 - yolo_smoothed - INFO - Train dataset size: 1642
# 2026-02-01 21:59:34,611 - yolo_smoothed - INFO - Test dataset size: 1470
# 2026-02-01 21:59:35,320 - yolo_smoothed - INFO - Epoch 1, Train Loss: 1.0284678198827
# 2026-02-01 21:59:35,988 - yolo_smoothed - INFO - Epoch 2, Train Loss: 0.05096655935407258
# 2026-02-01 21:59:36,600 - yolo_smoothed - INFO - Epoch 3, Train Loss: 0.04322601672118673
# 2026-02-01 21:59:37,239 - yolo_smoothed - INFO - Epoch 4, Train Loss: 0.03712272631505934
# 2026-02-01 21:59:37,847 - yolo_smoothed - INFO - Epoch 5, Train Loss: 0.034851004405377
# 2026-02-01 21:59:38,485 - yolo_smoothed - INFO - Epoch 6, Train Loss: 0.027820771237692006
# 2026-02-01 21:59:39,121 - yolo_smoothed - INFO - Epoch 7, Train Loss: 0.02581279008434369
# 2026-02-01 21:59:39,730 - yolo_smoothed - INFO - Epoch 8, Train Loss: 0.02654187082169721
# 2026-02-01 21:59:40,343 - yolo_smoothed - INFO - Epoch 9, Train Loss: 0.021010963362641633
# 2026-02-01 21:59:41,012 - yolo_smoothed - INFO - Epoch 10, Train Loss: 0.0233637464855117
# 2026-02-01 21:59:42,022 - yolo_smoothed - INFO - Accuracy: 0.9768707482993197
# 2026-02-01 21:59:42,023 - yolo_smoothed - INFO - Precision: 0.971736204576043
# 2026-02-01 21:59:42,023 - yolo_smoothed - INFO - Recall: 0.9823129251700681
# 2026-02-01 21:59:42,027 - yolo_smoothed - INFO - Confusion matrix:
#         True  False
# True    722     13
# False    21    714
# 2026-02-01 21:59:42,251 - yolo_smoothed - INFO - [Iteration 2/4]
# 2026-02-01 21:59:42,287 - yolo_smoothed - INFO - Train dataset size: 2634
# 2026-02-01 21:59:42,288 - yolo_smoothed - INFO - Test dataset size: 478
# 2026-02-01 21:59:43,289 - yolo_smoothed - INFO - Epoch 1, Train Loss: 0.2699548755828516
# 2026-02-01 21:59:44,334 - yolo_smoothed - INFO - Epoch 2, Train Loss: 0.04356179462678461
# 2026-02-01 21:59:45,364 - yolo_smoothed - INFO - Epoch 3, Train Loss: 0.0363795393853482
# 2026-02-01 21:59:46,422 - yolo_smoothed - INFO - Epoch 4, Train Loss: 0.025086724558418774
# 2026-02-01 21:59:47,478 - yolo_smoothed - INFO - Epoch 5, Train Loss: 0.017972992500290275
# 2026-02-01 21:59:48,519 - yolo_smoothed - INFO - Epoch 6, Train Loss: 0.015624358660979084
# 2026-02-01 21:59:49,529 - yolo_smoothed - INFO - Epoch 7, Train Loss: 0.01746751773676061
# 2026-02-01 21:59:50,499 - yolo_smoothed - INFO - Epoch 8, Train Loss: 0.03660097547683371
# 2026-02-01 21:59:51,487 - yolo_smoothed - INFO - Epoch 9, Train Loss: 0.017107739040336335
# 2026-02-01 21:59:52,588 - yolo_smoothed - INFO - Epoch 10, Train Loss: 0.022022092153868043
# 2026-02-01 21:59:52,928 - yolo_smoothed - INFO - Accuracy: 0.9456066945606695
# 2026-02-01 21:59:52,929 - yolo_smoothed - INFO - Precision: 0.9018867924528302
# 2026-02-01 21:59:52,929 - yolo_smoothed - INFO - Recall: 1.0
# 2026-02-01 21:59:52,932 - yolo_smoothed - INFO - Confusion matrix:
#         True  False
# True    239      0
# False    26    213
# 2026-02-01 21:59:53,146 - yolo_smoothed - INFO - [Iteration 3/4]
# 2026-02-01 21:59:53,179 - yolo_smoothed - INFO - Train dataset size: 2384
# 2026-02-01 21:59:53,180 - yolo_smoothed - INFO - Test dataset size: 728
# 2026-02-01 21:59:54,028 - yolo_smoothed - INFO - Epoch 1, Train Loss: 0.4776948042958975
# 2026-02-01 21:59:54,929 - yolo_smoothed - INFO - Epoch 2, Train Loss: 0.03741580091416836
# 2026-02-01 21:59:55,859 - yolo_smoothed - INFO - Epoch 3, Train Loss: 0.026079013049602508
# 2026-02-01 21:59:56,762 - yolo_smoothed - INFO - Epoch 4, Train Loss: 0.031898975539952516
# 2026-02-01 21:59:57,659 - yolo_smoothed - INFO - Epoch 5, Train Loss: 0.023281005055954058
# 2026-02-01 21:59:58,621 - yolo_smoothed - INFO - Epoch 6, Train Loss: 0.025189239444832007
# 2026-02-01 21:59:59,605 - yolo_smoothed - INFO - Epoch 7, Train Loss: 0.027171666199962297
# 2026-02-01 22:00:00,557 - yolo_smoothed - INFO - Epoch 8, Train Loss: 0.02421982688208421
# 2026-02-01 22:00:01,427 - yolo_smoothed - INFO - Epoch 9, Train Loss: 0.018841602504253388
# 2026-02-01 22:00:02,298 - yolo_smoothed - INFO - Epoch 10, Train Loss: 0.01587750551601251
# 2026-02-01 22:00:02,845 - yolo_smoothed - INFO - Accuracy: 0.9903846153846154
# 2026-02-01 22:00:02,846 - yolo_smoothed - INFO - Precision: 0.9863760217983651
# 2026-02-01 22:00:02,847 - yolo_smoothed - INFO - Recall: 0.9945054945054945
# 2026-02-01 22:00:02,850 - yolo_smoothed - INFO - Confusion matrix:
#         True  False
# True    362      2
# False     5    359
# 2026-02-01 22:00:03,082 - yolo_smoothed - INFO - [Iteration 4/4]
# 2026-02-01 22:00:03,116 - yolo_smoothed - INFO - Train dataset size: 2676
# 2026-02-01 22:00:03,117 - yolo_smoothed - INFO - Test dataset size: 436
# 2026-02-01 22:00:04,225 - yolo_smoothed - INFO - Epoch 1, Train Loss: 0.5694122883668613
# 2026-02-01 22:00:05,285 - yolo_smoothed - INFO - Epoch 2, Train Loss: 0.041349608229384535
# 2026-02-01 22:00:06,359 - yolo_smoothed - INFO - Epoch 3, Train Loss: 0.04307349480777269
# 2026-02-01 22:00:07,398 - yolo_smoothed - INFO - Epoch 4, Train Loss: 0.026579055181216626
# 2026-02-01 22:00:08,452 - yolo_smoothed - INFO - Epoch 5, Train Loss: 0.02560786075801367
# 2026-02-01 22:00:09,514 - yolo_smoothed - INFO - Epoch 6, Train Loss: 0.023537410633815897
# 2026-02-01 22:00:10,528 - yolo_smoothed - INFO - Epoch 7, Train Loss: 0.026802772090637257
# 2026-02-01 22:00:11,534 - yolo_smoothed - INFO - Epoch 8, Train Loss: 0.01940481964543107
# 2026-02-01 22:00:12,593 - yolo_smoothed - INFO - Epoch 9, Train Loss: 0.0310531733945633
# 2026-02-01 22:00:13,657 - yolo_smoothed - INFO - Epoch 10, Train Loss: 0.026158222629289542
# 2026-02-01 22:00:13,995 - yolo_smoothed - INFO - Accuracy: 0.9954128440366973
# 2026-02-01 22:00:13,997 - yolo_smoothed - INFO - Precision: 0.990909090909091
# 2026-02-01 22:00:13,997 - yolo_smoothed - INFO - Recall: 1.0
# 2026-02-01 22:00:14,000 - yolo_smoothed - INFO - Confusion matrix:
#         True  False
# True    218      0
# False     2    216
# 2026-02-01 22:00:14,221 - yolo_smoothed - INFO - Results will be saved to WindowsPath('results/predictions_cv/yolo_cycles_smoothed_conv1d.csv')
# 2026-02-01 22:00:14,230 - yolo_smoothed - INFO -
#
# 2026-02-01 22:00:14,231 - yolo_smoothed - INFO - Combined evaluation
# 2026-02-01 22:00:14,232 - yolo_smoothed - INFO - **************************************************
# 2026-02-01 22:00:14,485 - yolo_smoothed - INFO - Area under ROC curve: 0.9982908849399621
# 2026-02-01 22:00:14,497 - yolo_smoothed - INFO - Accuracy: 0.977827763496144
# 2026-02-01 22:00:14,498 - yolo_smoothed - INFO - Precision: 0.9661442006269593
# 2026-02-01 22:00:14,498 - yolo_smoothed - INFO - Recall: 0.9903598971722365
# 2026-02-01 22:00:14,502 - yolo_smoothed - INFO - Confusion matrix:
#         True  False
# True   1541     15
# False    54   1502
# 2026-02-01 22:00:14,724 - yolo_smoothed - INFO - & accuracy & precision &  recall  &   auroc
# 2026-02-01 22:00:14,725 - yolo_smoothed - INFO - & 97.78    & 96.61     & 99.04     & 99.83
# (0.977827763496144, 0.9661442006269593, 0.9903598971722365, 0.9982908849399621)

# %%
cv = CrossValidationSiameseRaw(
    sequence_cycles=yolo_cycles_smoothed, 
    coordinates_idx=CoordinatesIdx(0, 1, 2), 
    log_level=logging.INFO,
    logger_name = 'yolo_smoothed',
)
cv.count_participants_samples()
cv.perform_training(
    n_folds = 4,
    siamese_nn_type = "lstm",
    learning_rate = 1e-4,
    batch_size = 32,
    n_epochs = 15,
    threshold = 0.5,
    show_plot = True, 
    csv_file_path = Path('results/predictions_cv/yolo_cycles_smoothed_lstm.csv'),
)
# Out:
# 2026-02-01 23:02:19,701 - yolo_smoothed - INFO - Preparing cycles and participant labels...
# 2026-02-01 23:02:39,879 - yolo_smoothed - INFO - [Iteration 1/4]
# 2026-02-01 23:02:39,947 - yolo_smoothed - INFO - Train dataset size: 1642
# 2026-02-01 23:02:39,949 - yolo_smoothed - INFO - Test dataset size: 1470
# 2026-02-01 23:02:41,346 - yolo_smoothed - INFO - Epoch 1, Train Loss: 0.3191534455579061
# 2026-02-01 23:02:42,667 - yolo_smoothed - INFO - Epoch 2, Train Loss: 0.2540585324168205
# 2026-02-01 23:02:44,058 - yolo_smoothed - INFO - Epoch 3, Train Loss: 0.1940851230174303
# 2026-02-01 23:02:45,314 - yolo_smoothed - INFO - Epoch 4, Train Loss: 0.1519480532465073
# 2026-02-01 23:02:46,467 - yolo_smoothed - INFO - Epoch 5, Train Loss: 0.12007495001531564
# 2026-02-01 23:02:47,328 - yolo_smoothed - INFO - Epoch 6, Train Loss: 0.10164508653374818
# 2026-02-01 23:02:48,160 - yolo_smoothed - INFO - Epoch 7, Train Loss: 0.0863556507974863
# 2026-02-01 23:02:49,454 - yolo_smoothed - INFO - Epoch 8, Train Loss: 0.07249620599815479
# 2026-02-01 23:02:50,767 - yolo_smoothed - INFO - Epoch 9, Train Loss: 0.06477897023209013
# 2026-02-01 23:02:51,953 - yolo_smoothed - INFO - Epoch 10, Train Loss: 0.06558556188471042
# 2026-02-01 23:02:53,160 - yolo_smoothed - INFO - Epoch 11, Train Loss: 0.05190379305097919
# 2026-02-01 23:02:54,386 - yolo_smoothed - INFO - Epoch 12, Train Loss: 0.04754050477192952
# 2026-02-01 23:02:55,806 - yolo_smoothed - INFO - Epoch 13, Train Loss: 0.04794158308336941
# 2026-02-01 23:02:57,070 - yolo_smoothed - INFO - Epoch 14, Train Loss: 0.0384277926507191
# 2026-02-01 23:02:58,397 - yolo_smoothed - INFO - Epoch 15, Train Loss: 0.04424940065767329
# 2026-02-01 23:03:02,408 - yolo_smoothed - INFO - Accuracy: 0.926530612244898
# 2026-02-01 23:03:02,410 - yolo_smoothed - INFO - Precision: 0.8718861209964412
# 2026-02-01 23:03:02,411 - yolo_smoothed - INFO - Recall: 1.0
# 2026-02-01 23:03:02,417 - yolo_smoothed - INFO - Confusion matrix:
#         True  False
# True    735      0
# False   108    627
# 2026-02-01 23:03:02,813 - yolo_smoothed - INFO - [Iteration 2/4]
# 2026-02-01 23:03:02,889 - yolo_smoothed - INFO - Train dataset size: 2634
# 2026-02-01 23:03:02,890 - yolo_smoothed - INFO - Test dataset size: 478
# 2026-02-01 23:03:06,093 - yolo_smoothed - INFO - Epoch 1, Train Loss: 0.3029828524015036
# 2026-02-01 23:03:09,508 - yolo_smoothed - INFO - Epoch 2, Train Loss: 0.19058355136987676
# 2026-02-01 23:03:15,098 - yolo_smoothed - INFO - Epoch 3, Train Loss: 0.1101891003459333
# 2026-02-01 23:03:21,196 - yolo_smoothed - INFO - Epoch 4, Train Loss: 0.07673366477780313
# 2026-02-01 23:03:27,301 - yolo_smoothed - INFO - Epoch 5, Train Loss: 0.05441933013049953
# 2026-02-01 23:03:33,759 - yolo_smoothed - INFO - Epoch 6, Train Loss: 0.04359106013708445
# 2026-02-01 23:03:39,781 - yolo_smoothed - INFO - Epoch 7, Train Loss: 0.032988722054624414
# 2026-02-01 23:03:45,001 - yolo_smoothed - INFO - Epoch 8, Train Loss: 0.033319539637360944
# 2026-02-01 23:03:47,570 - yolo_smoothed - INFO - Epoch 9, Train Loss: 0.029978614945682776
# 2026-02-01 23:03:49,744 - yolo_smoothed - INFO - Epoch 10, Train Loss: 0.02771009784191847
# 2026-02-01 23:03:51,096 - yolo_smoothed - INFO - Epoch 11, Train Loss: 0.026624050305550356
# 2026-02-01 23:03:52,931 - yolo_smoothed - INFO - Epoch 12, Train Loss: 0.03068569991513189
# 2026-02-01 23:03:55,034 - yolo_smoothed - INFO - Epoch 13, Train Loss: 0.02427308336573552
# 2026-02-01 23:03:57,169 - yolo_smoothed - INFO - Epoch 14, Train Loss: 0.02610576130360006
# 2026-02-01 23:03:59,196 - yolo_smoothed - INFO - Epoch 15, Train Loss: 0.02162096211798938
# 2026-02-01 23:04:00,640 - yolo_smoothed - INFO - Accuracy: 0.8849372384937239
# 2026-02-01 23:04:00,642 - yolo_smoothed - INFO - Precision: 0.8129251700680272
# 2026-02-01 23:04:00,643 - yolo_smoothed - INFO - Recall: 1.0
# 2026-02-01 23:04:00,647 - yolo_smoothed - INFO - Confusion matrix:
#         True  False
# True    239      0
# False    55    184
# 2026-02-01 23:04:00,964 - yolo_smoothed - INFO - [Iteration 3/4]
# 2026-02-01 23:04:01,013 - yolo_smoothed - INFO - Train dataset size: 2384
# 2026-02-01 23:04:01,014 - yolo_smoothed - INFO - Test dataset size: 728
# 2026-02-01 23:04:02,856 - yolo_smoothed - INFO - Epoch 1, Train Loss: 0.2756746327877045
# 2026-02-01 23:04:04,638 - yolo_smoothed - INFO - Epoch 2, Train Loss: 0.14649014582236608
# 2026-02-01 23:04:06,655 - yolo_smoothed - INFO - Epoch 3, Train Loss: 0.09638432259360949
# 2026-02-01 23:04:08,467 - yolo_smoothed - INFO - Epoch 4, Train Loss: 0.08182366649309794
# 2026-02-01 23:04:10,494 - yolo_smoothed - INFO - Epoch 5, Train Loss: 0.06316049069166184
# 2026-02-01 23:04:13,805 - yolo_smoothed - INFO - Epoch 6, Train Loss: 0.05652479618787765
# 2026-02-01 23:04:16,821 - yolo_smoothed - INFO - Epoch 7, Train Loss: 0.05206229880452156
# 2026-02-01 23:04:20,005 - yolo_smoothed - INFO - Epoch 8, Train Loss: 0.04407645876829823
# 2026-02-01 23:04:23,121 - yolo_smoothed - INFO - Epoch 9, Train Loss: 0.045970003455877304
# 2026-02-01 23:04:26,042 - yolo_smoothed - INFO - Epoch 10, Train Loss: 0.0393608004723986
# 2026-02-01 23:04:29,122 - yolo_smoothed - INFO - Epoch 11, Train Loss: 0.03684155286600192
# 2026-02-01 23:04:32,276 - yolo_smoothed - INFO - Epoch 12, Train Loss: 0.04398317376772563
# 2026-02-01 23:04:35,238 - yolo_smoothed - INFO - Epoch 13, Train Loss: 0.037993864088008804
# 2026-02-01 23:04:38,330 - yolo_smoothed - INFO - Epoch 14, Train Loss: 0.035300863807400065
# 2026-02-01 23:04:40,794 - yolo_smoothed - INFO - Epoch 15, Train Loss: 0.035358483915527664
# 2026-02-01 23:04:42,566 - yolo_smoothed - INFO - Accuracy: 0.9381868131868132
# 2026-02-01 23:04:42,567 - yolo_smoothed - INFO - Precision: 0.8899755501222494
# 2026-02-01 23:04:42,569 - yolo_smoothed - INFO - Recall: 1.0
# 2026-02-01 23:04:42,574 - yolo_smoothed - INFO - Confusion matrix:
#         True  False
# True    364      0
# False    45    319
# 2026-02-01 23:04:42,952 - yolo_smoothed - INFO - [Iteration 4/4]
# 2026-02-01 23:04:43,024 - yolo_smoothed - INFO - Train dataset size: 2676
# 2026-02-01 23:04:43,026 - yolo_smoothed - INFO - Test dataset size: 436
# 2026-02-01 23:04:46,248 - yolo_smoothed - INFO - Epoch 1, Train Loss: 0.29276335807073683
# 2026-02-01 23:04:49,828 - yolo_smoothed - INFO - Epoch 2, Train Loss: 0.18289912367860475
# 2026-02-01 23:04:53,167 - yolo_smoothed - INFO - Epoch 3, Train Loss: 0.12811481526919774
# 2026-02-01 23:04:55,479 - yolo_smoothed - INFO - Epoch 4, Train Loss: 0.08230469318195469
# 2026-02-01 23:04:58,682 - yolo_smoothed - INFO - Epoch 5, Train Loss: 0.06735586556827738
# 2026-02-01 23:05:02,171 - yolo_smoothed - INFO - Epoch 6, Train Loss: 0.053583508146749365
# 2026-02-01 23:05:05,832 - yolo_smoothed - INFO - Epoch 7, Train Loss: 0.04676044517241064
# 2026-02-01 23:05:09,652 - yolo_smoothed - INFO - Epoch 8, Train Loss: 0.04114773847340118
# 2026-02-01 23:05:13,171 - yolo_smoothed - INFO - Epoch 9, Train Loss: 0.03912525994348384
# 2026-02-01 23:05:16,696 - yolo_smoothed - INFO - Epoch 10, Train Loss: 0.028294755578307167
# 2026-02-01 23:05:20,561 - yolo_smoothed - INFO - Epoch 11, Train Loss: 0.03230819728092423
# 2026-02-01 23:05:23,946 - yolo_smoothed - INFO - Epoch 12, Train Loss: 0.030138030243549673
# 2026-02-01 23:05:27,663 - yolo_smoothed - INFO - Epoch 13, Train Loss: 0.03385844575573823
# 2026-02-01 23:05:30,785 - yolo_smoothed - INFO - Epoch 14, Train Loss: 0.028836544420170997
# 2026-02-01 23:05:34,290 - yolo_smoothed - INFO - Epoch 15, Train Loss: 0.024946331459518876
# 2026-02-01 23:05:36,812 - yolo_smoothed - INFO - Accuracy: 0.9472477064220184
# 2026-02-01 23:05:36,814 - yolo_smoothed - INFO - Precision: 0.9045643153526971
# 2026-02-01 23:05:36,815 - yolo_smoothed - INFO - Recall: 1.0
# 2026-02-01 23:05:36,820 - yolo_smoothed - INFO - Confusion matrix:
#         True  False
# True    218      0
# False    23    195
# 2026-02-01 23:05:37,233 - yolo_smoothed - INFO - Results will be saved to WindowsPath('results/predictions_cv/yolo_cycles_smoothed_lstm.csv')
# 2026-02-01 23:05:37,253 - yolo_smoothed - INFO -
#
# 2026-02-01 23:05:37,254 - yolo_smoothed - INFO - Combined evaluation
# 2026-02-01 23:05:37,256 - yolo_smoothed - INFO - **************************************************
# 2026-02-01 23:05:37,731 - yolo_smoothed - INFO - Area under ROC curve: 0.9860594365620106
# 2026-02-01 23:05:37,757 - yolo_smoothed - INFO - Accuracy: 0.925771208226221
# 2026-02-01 23:05:37,758 - yolo_smoothed - INFO - Precision: 0.8707330721880246
# 2026-02-01 23:05:37,759 - yolo_smoothed - INFO - Recall: 1.0
# 2026-02-01 23:05:37,767 - yolo_smoothed - INFO - Confusion matrix:
#         True  False
# True   1556      0
# False   231   1325
# 2026-02-01 23:05:38,177 - yolo_smoothed - INFO - & accuracy & precision &  recall  &   auroc
# 2026-02-01 23:05:38,178 - yolo_smoothed - INFO - & 92.58    & 87.07     & 100.00     & 98.61
# (0.925771208226221, 0.8707330721880246, 1.0, 0.9860594365620106)

# %%
cv = CrossValidationSiameseRaw(
    sequence_cycles=yolo_best_cams_cycles_smoothed, 
    coordinates_idx=CoordinatesIdx(0, 1, 2), 
    log_level=logging.INFO,
    logger_name = 'yolo_best_cameras_smoothed',
)
cv.count_participants_samples()
cv.perform_training(
    n_folds = 4,
    siamese_nn_type = "conv1d",
    learning_rate = 1e-3,
    batch_size = 32,
    n_epochs = 10,
    threshold = 0.5,
    show_plot = True, 
    csv_file_path = Path('results/predictions_cv/yolo_best_cams_cycles_smoothed_conv1d.csv'),
)
# Out:
# 2026-02-01 22:01:32,919 - yolo_best_cameras_smoothed - INFO - Preparing cycles and participant labels...
# 2026-02-01 22:01:43,205 - yolo_best_cameras_smoothed - INFO - [Iteration 1/4]
# 2026-02-01 22:01:43,237 - yolo_best_cameras_smoothed - INFO - Train dataset size: 1826
# 2026-02-01 22:01:43,238 - yolo_best_cameras_smoothed - INFO - Test dataset size: 1352
# 2026-02-01 22:01:43,925 - yolo_best_cameras_smoothed - INFO - Epoch 1, Train Loss: 0.43556212794421045
# 2026-02-01 22:01:44,618 - yolo_best_cameras_smoothed - INFO - Epoch 2, Train Loss: 0.02888030046597123
# 2026-02-01 22:01:45,404 - yolo_best_cameras_smoothed - INFO - Epoch 3, Train Loss: 0.03623506349736247
# 2026-02-01 22:01:46,184 - yolo_best_cameras_smoothed - INFO - Epoch 4, Train Loss: 0.03717818653917518
# 2026-02-01 22:01:46,938 - yolo_best_cameras_smoothed - INFO - Epoch 5, Train Loss: 0.02563439887659303
# 2026-02-01 22:01:47,703 - yolo_best_cameras_smoothed - INFO - Epoch 6, Train Loss: 0.017584126448692304
# 2026-02-01 22:01:48,395 - yolo_best_cameras_smoothed - INFO - Epoch 7, Train Loss: 0.014290046448626652
# 2026-02-01 22:01:49,115 - yolo_best_cameras_smoothed - INFO - Epoch 8, Train Loss: 0.01651918387506157
# 2026-02-01 22:01:49,818 - yolo_best_cameras_smoothed - INFO - Epoch 9, Train Loss: 0.02097833288656869
# 2026-02-01 22:01:50,560 - yolo_best_cameras_smoothed - INFO - Epoch 10, Train Loss: 0.019123106705153298
# 2026-02-01 22:01:51,576 - yolo_best_cameras_smoothed - INFO - Accuracy: 0.9792899408284024
# 2026-02-01 22:01:51,577 - yolo_best_cameras_smoothed - INFO - Precision: 0.9602272727272727
# 2026-02-01 22:01:51,578 - yolo_best_cameras_smoothed - INFO - Recall: 1.0
# 2026-02-01 22:01:51,581 - yolo_best_cameras_smoothed - INFO - Confusion matrix:
#         True  False
# True    676      0
# False    28    648
# 2026-02-01 22:01:51,812 - yolo_best_cameras_smoothed - INFO - [Iteration 2/4]
# 2026-02-01 22:01:51,847 - yolo_best_cameras_smoothed - INFO - Train dataset size: 2650
# 2026-02-01 22:01:51,848 - yolo_best_cameras_smoothed - INFO - Test dataset size: 528
# 2026-02-01 22:01:52,889 - yolo_best_cameras_smoothed - INFO - Epoch 1, Train Loss: 0.6632101018520364
# 2026-02-01 22:01:53,956 - yolo_best_cameras_smoothed - INFO - Epoch 2, Train Loss: 0.03396894450647285
# 2026-02-01 22:01:55,000 - yolo_best_cameras_smoothed - INFO - Epoch 3, Train Loss: 0.02945161909313805
# 2026-02-01 22:01:56,041 - yolo_best_cameras_smoothed - INFO - Epoch 4, Train Loss: 0.026569510417350804
# 2026-02-01 22:01:57,160 - yolo_best_cameras_smoothed - INFO - Epoch 5, Train Loss: 0.03656944946711322
# 2026-02-01 22:01:58,216 - yolo_best_cameras_smoothed - INFO - Epoch 6, Train Loss: 0.03250105998826673
# 2026-02-01 22:01:59,192 - yolo_best_cameras_smoothed - INFO - Epoch 7, Train Loss: 0.026245287529765123
# 2026-02-01 22:02:00,319 - yolo_best_cameras_smoothed - INFO - Epoch 8, Train Loss: 0.022732787356005018
# 2026-02-01 22:02:01,319 - yolo_best_cameras_smoothed - INFO - Epoch 9, Train Loss: 0.0209042657368693
# 2026-02-01 22:02:02,397 - yolo_best_cameras_smoothed - INFO - Epoch 10, Train Loss: 0.019038667520844793
# 2026-02-01 22:02:02,936 - yolo_best_cameras_smoothed - INFO - Accuracy: 0.9867424242424242
# 2026-02-01 22:02:02,937 - yolo_best_cameras_smoothed - INFO - Precision: 0.974169741697417
# 2026-02-01 22:02:02,938 - yolo_best_cameras_smoothed - INFO - Recall: 1.0
# 2026-02-01 22:02:02,941 - yolo_best_cameras_smoothed - INFO - Confusion matrix:
#         True  False
# True    264      0
# False     7    257
# 2026-02-01 22:02:03,176 - yolo_best_cameras_smoothed - INFO - [Iteration 3/4]
# 2026-02-01 22:02:03,210 - yolo_best_cameras_smoothed - INFO - Train dataset size: 2372
# 2026-02-01 22:02:03,211 - yolo_best_cameras_smoothed - INFO - Test dataset size: 806
# 2026-02-01 22:02:04,184 - yolo_best_cameras_smoothed - INFO - Epoch 1, Train Loss: 0.4690396430095037
# 2026-02-01 22:02:05,187 - yolo_best_cameras_smoothed - INFO - Epoch 2, Train Loss: 0.030497027548650902
# 2026-02-01 22:02:06,059 - yolo_best_cameras_smoothed - INFO - Epoch 3, Train Loss: 0.027622659541666508
# 2026-02-01 22:02:06,895 - yolo_best_cameras_smoothed - INFO - Epoch 4, Train Loss: 0.02450970271602273
# 2026-02-01 22:02:07,833 - yolo_best_cameras_smoothed - INFO - Epoch 5, Train Loss: 0.02550718616694212
# 2026-02-01 22:02:08,798 - yolo_best_cameras_smoothed - INFO - Epoch 6, Train Loss: 0.025748614594340323
# 2026-02-01 22:02:09,708 - yolo_best_cameras_smoothed - INFO - Epoch 7, Train Loss: 0.03266431746383508
# 2026-02-01 22:02:10,566 - yolo_best_cameras_smoothed - INFO - Epoch 8, Train Loss: 0.021703871510302026
# 2026-02-01 22:02:11,473 - yolo_best_cameras_smoothed - INFO - Epoch 9, Train Loss: 0.019249124421427646
# 2026-02-01 22:02:12,387 - yolo_best_cameras_smoothed - INFO - Epoch 10, Train Loss: 0.01995532535016537
# 2026-02-01 22:02:12,922 - yolo_best_cameras_smoothed - INFO - Accuracy: 0.9875930521091811
# 2026-02-01 22:02:12,923 - yolo_best_cameras_smoothed - INFO - Precision: 0.980440097799511
# 2026-02-01 22:02:12,924 - yolo_best_cameras_smoothed - INFO - Recall: 0.9950372208436724
# 2026-02-01 22:02:12,927 - yolo_best_cameras_smoothed - INFO - Confusion matrix:
#         True  False
# True    401      2
# False     8    395
# 2026-02-01 22:02:13,189 - yolo_best_cameras_smoothed - INFO - [Iteration 4/4]
# 2026-02-01 22:02:13,225 - yolo_best_cameras_smoothed - INFO - Train dataset size: 2686
# 2026-02-01 22:02:13,226 - yolo_best_cameras_smoothed - INFO - Test dataset size: 492
# 2026-02-01 22:02:14,231 - yolo_best_cameras_smoothed - INFO - Epoch 1, Train Loss: 0.44882439342992647
# 2026-02-01 22:02:15,240 - yolo_best_cameras_smoothed - INFO - Epoch 2, Train Loss: 0.046835247826363356
# 2026-02-01 22:02:16,190 - yolo_best_cameras_smoothed - INFO - Epoch 3, Train Loss: 0.045874043922161774
# 2026-02-01 22:02:17,206 - yolo_best_cameras_smoothed - INFO - Epoch 4, Train Loss: 0.03886817168400046
# 2026-02-01 22:02:18,212 - yolo_best_cameras_smoothed - INFO - Epoch 5, Train Loss: 0.02870080707639101
# 2026-02-01 22:02:19,274 - yolo_best_cameras_smoothed - INFO - Epoch 6, Train Loss: 0.030146585378263677
# 2026-02-01 22:02:20,307 - yolo_best_cameras_smoothed - INFO - Epoch 7, Train Loss: 0.031148942442433464
# 2026-02-01 22:02:21,318 - yolo_best_cameras_smoothed - INFO - Epoch 8, Train Loss: 0.02556885845427002
# 2026-02-01 22:02:22,362 - yolo_best_cameras_smoothed - INFO - Epoch 9, Train Loss: 0.020150922798729015
# 2026-02-01 22:02:23,333 - yolo_best_cameras_smoothed - INFO - Epoch 10, Train Loss: 0.018613742348471924
# 2026-02-01 22:02:23,726 - yolo_best_cameras_smoothed - INFO - Accuracy: 0.9878048780487805
# 2026-02-01 22:02:23,727 - yolo_best_cameras_smoothed - INFO - Precision: 0.9761904761904762
# 2026-02-01 22:02:23,728 - yolo_best_cameras_smoothed - INFO - Recall: 1.0
# 2026-02-01 22:02:23,731 - yolo_best_cameras_smoothed - INFO - Confusion matrix:
#         True  False
# True    246      0
# False     6    240
# 2026-02-01 22:02:23,940 - yolo_best_cameras_smoothed - INFO - Results will be saved to WindowsPath('results/predictions_cv/yolo_best_cams_cycles_smoothed_conv1d.csv')
# 2026-02-01 22:02:23,948 - yolo_best_cameras_smoothed - INFO -
#
# 2026-02-01 22:02:23,949 - yolo_best_cameras_smoothed - INFO - Combined evaluation
# 2026-02-01 22:02:23,950 - yolo_best_cameras_smoothed - INFO - **************************************************
# 2026-02-01 22:02:24,458 - yolo_best_cameras_smoothed - INFO - Area under ROC curve: 0.999077198850974
# 2026-02-01 22:02:24,470 - yolo_best_cameras_smoothed - INFO - Accuracy: 0.9839521711768408
# 2026-02-01 22:02:24,471 - yolo_best_cameras_smoothed - INFO - Precision: 0.9700488997555012
# 2026-02-01 22:02:24,472 - yolo_best_cameras_smoothed - INFO - Recall: 0.9987413467589679
# 2026-02-01 22:02:24,476 - yolo_best_cameras_smoothed - INFO - Confusion matrix:
#         True  False
# True   1587      2
# False    49   1540
# 2026-02-01 22:02:24,695 - yolo_best_cameras_smoothed - INFO - & accuracy & precision &  recall  &   auroc
# 2026-02-01 22:02:24,695 - yolo_best_cameras_smoothed - INFO - & 98.40    & 97.00     & 99.87     & 99.91
# (0.9839521711768408, 0.9700488997555012, 0.9987413467589679, 0.999077198850974)

# %%
cv = CrossValidationSiameseRaw(
    sequence_cycles=yolo_best_cams_cycles_smoothed, 
    coordinates_idx=CoordinatesIdx(0, 1, 2), 
    log_level=logging.INFO,
    logger_name = 'yolo_best_cameras_smoothed',
)
cv.count_participants_samples()
cv.perform_training(
    n_folds = 4,
    siamese_nn_type = "lstm",
    learning_rate = 1e-4,
    batch_size = 32,
    n_epochs = 15,
    threshold = 0.5,
    show_plot = True, 
    csv_file_path = Path('results/predictions_cv/yolo_best_cams_cycles_smoothed_lstm.csv'),
)
# Out:
# 2026-02-01 22:57:43,984 - yolo_best_cameras_smoothed - INFO - Preparing cycles and participant labels...
# 2026-02-01 22:58:05,312 - yolo_best_cameras_smoothed - INFO - [Iteration 1/4]
# 2026-02-01 22:58:05,382 - yolo_best_cameras_smoothed - INFO - Train dataset size: 1826
# 2026-02-01 22:58:05,384 - yolo_best_cameras_smoothed - INFO - Test dataset size: 1352
# 2026-02-01 22:58:08,049 - yolo_best_cameras_smoothed - INFO - Epoch 1, Train Loss: 0.33830544146998176
# 2026-02-01 22:58:10,777 - yolo_best_cameras_smoothed - INFO - Epoch 2, Train Loss: 0.24052691099972562
# 2026-02-01 22:58:13,615 - yolo_best_cameras_smoothed - INFO - Epoch 3, Train Loss: 0.1432103780579978
# 2026-02-01 22:58:16,504 - yolo_best_cameras_smoothed - INFO - Epoch 4, Train Loss: 0.08509120319424004
# 2026-02-01 22:58:18,887 - yolo_best_cameras_smoothed - INFO - Epoch 5, Train Loss: 0.06337902934194126
# 2026-02-01 22:58:21,431 - yolo_best_cameras_smoothed - INFO - Epoch 6, Train Loss: 0.055246084543137716
# 2026-02-01 22:58:24,801 - yolo_best_cameras_smoothed - INFO - Epoch 7, Train Loss: 0.0471248216445333
# 2026-02-01 22:58:29,588 - yolo_best_cameras_smoothed - INFO - Epoch 8, Train Loss: 0.03465962299177873
# 2026-02-01 22:58:33,081 - yolo_best_cameras_smoothed - INFO - Epoch 9, Train Loss: 0.03661420068639363
# 2026-02-01 22:58:37,012 - yolo_best_cameras_smoothed - INFO - Epoch 10, Train Loss: 0.038451161982234694
# 2026-02-01 22:58:40,984 - yolo_best_cameras_smoothed - INFO - Epoch 11, Train Loss: 0.030561997113620926
# 2026-02-01 22:58:44,481 - yolo_best_cameras_smoothed - INFO - Epoch 12, Train Loss: 0.03668367718185844
# 2026-02-01 22:58:48,286 - yolo_best_cameras_smoothed - INFO - Epoch 13, Train Loss: 0.02303424508888917
# 2026-02-01 22:58:51,049 - yolo_best_cameras_smoothed - INFO - Epoch 14, Train Loss: 0.021853034055374306
# 2026-02-01 22:58:54,817 - yolo_best_cameras_smoothed - INFO - Epoch 15, Train Loss: 0.020410554455432654
# 2026-02-01 22:59:05,941 - yolo_best_cameras_smoothed - INFO - Accuracy: 0.9445266272189349
# 2026-02-01 22:59:05,943 - yolo_best_cameras_smoothed - INFO - Precision: 0.9001331557922769
# 2026-02-01 22:59:05,943 - yolo_best_cameras_smoothed - INFO - Recall: 1.0
# 2026-02-01 22:59:05,950 - yolo_best_cameras_smoothed - INFO - Confusion matrix:
#         True  False
# True    676      0
# False    75    601
# 2026-02-01 22:59:06,339 - yolo_best_cameras_smoothed - INFO - [Iteration 2/4]
# 2026-02-01 22:59:06,421 - yolo_best_cameras_smoothed - INFO - Train dataset size: 2650
# 2026-02-01 22:59:06,423 - yolo_best_cameras_smoothed - INFO - Test dataset size: 528
# 2026-02-01 22:59:11,730 - yolo_best_cameras_smoothed - INFO - Epoch 1, Train Loss: 0.31027193547013293
# 2026-02-01 22:59:16,548 - yolo_best_cameras_smoothed - INFO - Epoch 2, Train Loss: 0.17755989124437413
# 2026-02-01 22:59:21,829 - yolo_best_cameras_smoothed - INFO - Epoch 3, Train Loss: 0.11692722487341926
# 2026-02-01 22:59:26,959 - yolo_best_cameras_smoothed - INFO - Epoch 4, Train Loss: 0.09038576501679707
# 2026-02-01 22:59:32,301 - yolo_best_cameras_smoothed - INFO - Epoch 5, Train Loss: 0.0796728101390672
# 2026-02-01 22:59:37,331 - yolo_best_cameras_smoothed - INFO - Epoch 6, Train Loss: 0.06757998623582254
# 2026-02-01 22:59:43,065 - yolo_best_cameras_smoothed - INFO - Epoch 7, Train Loss: 0.06011767256780561
# 2026-02-01 22:59:49,389 - yolo_best_cameras_smoothed - INFO - Epoch 8, Train Loss: 0.055826382318803346
# 2026-02-01 22:59:55,701 - yolo_best_cameras_smoothed - INFO - Epoch 9, Train Loss: 0.048715707049312364
# 2026-02-01 23:00:01,603 - yolo_best_cameras_smoothed - INFO - Epoch 10, Train Loss: 0.03700716223522841
# 2026-02-01 23:00:07,288 - yolo_best_cameras_smoothed - INFO - Epoch 11, Train Loss: 0.04000540001385183
# 2026-02-01 23:00:12,948 - yolo_best_cameras_smoothed - INFO - Epoch 12, Train Loss: 0.03200631752520441
# 2026-02-01 23:00:16,937 - yolo_best_cameras_smoothed - INFO - Epoch 13, Train Loss: 0.030330488211419208
# 2026-02-01 23:00:20,640 - yolo_best_cameras_smoothed - INFO - Epoch 14, Train Loss: 0.027265424088361752
# 2026-02-01 23:00:24,304 - yolo_best_cameras_smoothed - INFO - Epoch 15, Train Loss: 0.025137786478567195
# 2026-02-01 23:00:27,904 - yolo_best_cameras_smoothed - INFO - Accuracy: 0.9223484848484849
# 2026-02-01 23:00:27,906 - yolo_best_cameras_smoothed - INFO - Precision: 0.8655737704918033
# 2026-02-01 23:00:27,907 - yolo_best_cameras_smoothed - INFO - Recall: 1.0
# 2026-02-01 23:00:27,911 - yolo_best_cameras_smoothed - INFO - Confusion matrix:
#         True  False
# True    264      0
# False    41    223
# 2026-02-01 23:00:28,302 - yolo_best_cameras_smoothed - INFO - [Iteration 3/4]
# 2026-02-01 23:00:28,374 - yolo_best_cameras_smoothed - INFO - Train dataset size: 2372
# 2026-02-01 23:00:28,375 - yolo_best_cameras_smoothed - INFO - Test dataset size: 806
# 2026-02-01 23:00:31,835 - yolo_best_cameras_smoothed - INFO - Epoch 1, Train Loss: 0.3100315065185229
# 2026-02-01 23:00:35,313 - yolo_best_cameras_smoothed - INFO - Epoch 2, Train Loss: 0.21118558953205743
# 2026-02-01 23:00:39,803 - yolo_best_cameras_smoothed - INFO - Epoch 3, Train Loss: 0.13486654977003734
# 2026-02-01 23:00:44,250 - yolo_best_cameras_smoothed - INFO - Epoch 4, Train Loss: 0.08576545278231303
# 2026-02-01 23:00:48,060 - yolo_best_cameras_smoothed - INFO - Epoch 5, Train Loss: 0.05998405146102111
# 2026-02-01 23:00:50,974 - yolo_best_cameras_smoothed - INFO - Epoch 6, Train Loss: 0.051169119377930956
# 2026-02-01 23:00:53,767 - yolo_best_cameras_smoothed - INFO - Epoch 7, Train Loss: 0.044811837996045746
# 2026-02-01 23:00:56,054 - yolo_best_cameras_smoothed - INFO - Epoch 8, Train Loss: 0.038348666330178575
# 2026-02-01 23:00:59,625 - yolo_best_cameras_smoothed - INFO - Epoch 9, Train Loss: 0.03787666915605466
# 2026-02-01 23:01:02,635 - yolo_best_cameras_smoothed - INFO - Epoch 10, Train Loss: 0.045617193641761936
# 2026-02-01 23:01:05,859 - yolo_best_cameras_smoothed - INFO - Epoch 11, Train Loss: 0.031458109881108004
# 2026-02-01 23:01:09,017 - yolo_best_cameras_smoothed - INFO - Epoch 12, Train Loss: 0.03617303596809506
# 2026-02-01 23:01:12,330 - yolo_best_cameras_smoothed - INFO - Epoch 13, Train Loss: 0.029761969471971194
# 2026-02-01 23:01:14,413 - yolo_best_cameras_smoothed - INFO - Epoch 14, Train Loss: 0.024665143347034853
# 2026-02-01 23:01:17,314 - yolo_best_cameras_smoothed - INFO - Epoch 15, Train Loss: 0.026033228157709042
# 2026-02-01 23:01:21,600 - yolo_best_cameras_smoothed - INFO - Accuracy: 0.9627791563275434
# 2026-02-01 23:01:21,602 - yolo_best_cameras_smoothed - INFO - Precision: 0.930715935334873
# 2026-02-01 23:01:21,603 - yolo_best_cameras_smoothed - INFO - Recall: 1.0
# 2026-02-01 23:01:21,608 - yolo_best_cameras_smoothed - INFO - Confusion matrix:
#         True  False
# True    403      0
# False    30    373
# 2026-02-01 23:01:22,009 - yolo_best_cameras_smoothed - INFO - [Iteration 4/4]
# 2026-02-01 23:01:22,091 - yolo_best_cameras_smoothed - INFO - Train dataset size: 2686
# 2026-02-01 23:01:22,093 - yolo_best_cameras_smoothed - INFO - Test dataset size: 492
# 2026-02-01 23:01:25,535 - yolo_best_cameras_smoothed - INFO - Epoch 1, Train Loss: 0.29451102461843265
# 2026-02-01 23:01:29,371 - yolo_best_cameras_smoothed - INFO - Epoch 2, Train Loss: 0.1695518230221101
# 2026-02-01 23:01:33,020 - yolo_best_cameras_smoothed - INFO - Epoch 3, Train Loss: 0.0840026482806674
# 2026-02-01 23:01:36,408 - yolo_best_cameras_smoothed - INFO - Epoch 4, Train Loss: 0.06246997296277966
# 2026-02-01 23:01:40,579 - yolo_best_cameras_smoothed - INFO - Epoch 5, Train Loss: 0.047477702355189694
# 2026-02-01 23:01:44,029 - yolo_best_cameras_smoothed - INFO - Epoch 6, Train Loss: 0.042512645723209494
# 2026-02-01 23:01:46,460 - yolo_best_cameras_smoothed - INFO - Epoch 7, Train Loss: 0.03622128835524477
# 2026-02-01 23:01:50,313 - yolo_best_cameras_smoothed - INFO - Epoch 8, Train Loss: 0.03289630421481672
# 2026-02-01 23:01:54,176 - yolo_best_cameras_smoothed - INFO - Epoch 9, Train Loss: 0.033971520096418406
# 2026-02-01 23:01:58,100 - yolo_best_cameras_smoothed - INFO - Epoch 10, Train Loss: 0.024195738469383547
# 2026-02-01 23:02:02,070 - yolo_best_cameras_smoothed - INFO - Epoch 11, Train Loss: 0.022873170518626768
# 2026-02-01 23:02:05,797 - yolo_best_cameras_smoothed - INFO - Epoch 12, Train Loss: 0.020860564479205226
# 2026-02-01 23:02:09,450 - yolo_best_cameras_smoothed - INFO - Epoch 13, Train Loss: 0.021756470912978762
# 2026-02-01 23:02:12,029 - yolo_best_cameras_smoothed - INFO - Epoch 14, Train Loss: 0.019838510702053707
# 2026-02-01 23:02:15,605 - yolo_best_cameras_smoothed - INFO - Epoch 15, Train Loss: 0.018587250622831994
# 2026-02-01 23:02:18,311 - yolo_best_cameras_smoothed - INFO - Accuracy: 0.991869918699187
# 2026-02-01 23:02:18,313 - yolo_best_cameras_smoothed - INFO - Precision: 0.984
# 2026-02-01 23:02:18,313 - yolo_best_cameras_smoothed - INFO - Recall: 1.0
# 2026-02-01 23:02:18,318 - yolo_best_cameras_smoothed - INFO - Confusion matrix:
#         True  False
# True    246      0
# False     4    242
# 2026-02-01 23:02:18,694 - yolo_best_cameras_smoothed - INFO - Results will be saved to WindowsPath('results/predictions_cv/yolo_best_cams_cycles_smoothed_lstm.csv')
# 2026-02-01 23:02:18,714 - yolo_best_cameras_smoothed - INFO -
#
# 2026-02-01 23:02:18,716 - yolo_best_cameras_smoothed - INFO - Combined evaluation
# 2026-02-01 23:02:18,718 - yolo_best_cameras_smoothed - INFO - **************************************************
# 2026-02-01 23:02:19,194 - yolo_best_cameras_smoothed - INFO - Area under ROC curve: 0.9948493438012518
# 2026-02-01 23:02:19,218 - yolo_best_cameras_smoothed - INFO - Accuracy: 0.9528005034612964
# 2026-02-01 23:02:19,219 - yolo_best_cameras_smoothed - INFO - Precision: 0.9137435307648074
# 2026-02-01 23:02:19,220 - yolo_best_cameras_smoothed - INFO - Recall: 1.0
# 2026-02-01 23:02:19,228 - yolo_best_cameras_smoothed - INFO - Confusion matrix:
#         True  False
# True   1589      0
# False   150   1439
# 2026-02-01 23:02:19,671 - yolo_best_cameras_smoothed - INFO - & accuracy & precision &  recall  &   auroc
# 2026-02-01 23:02:19,672 - yolo_best_cameras_smoothed - INFO - & 95.28    & 91.37     & 100.00     & 99.48
# (0.9528005034612964, 0.9137435307648074, 1.0, 0.9948493438012518)
