# %%
import json
import logging
from pathlib import Path
from utils.gait_parameters_extractor_raw_2d import CoordinatesIdx2D, GaitParametersExtractorRaw2D
from utils.cross_validation_siamese_raw_2d import CrossValidationSiameseRaw2D

with open("./datasets/yolo/sequences_2d/steps_yolo26_camera_1.json", "r") as file:
    steps_camera_1 = json.load(file)

with open("./datasets/yolo/sequences_2d/steps_yolo26_camera_3.json", "r") as file:
    steps_camera_3 = json.load(file)

with open("./datasets/yolo/sequences_2d/steps_yolo26_camera_1_butterworth.json", "r") as file:
    steps_camera_1_butterworth = json.load(file)

with open("./datasets/yolo/sequences_2d/steps_yolo26_camera_3_butterworth.json", "r") as file:
    steps_camera_3_butterworth = json.load(file)

with open("./datasets/yolo/selected_joint_names_v2.json", "r") as file:
    selected_joint_names = json.load(file)

# %%
cv = CrossValidationSiameseRaw2D(
    sequence_cycles=steps_camera_3, 
    selected_joints=selected_joint_names,
    log_level=logging.INFO,
    logger_name = 'steps_camera_3',
    involve_hands_parameters=False,
)
cv.count_participants_samples()

for emb_size in [10, 20, 50, 100, 200, 500]:
    cv.perform_training(
        n_folds = 4,
        siamese_nn_type = "conv1d",
        learning_rate = 1e-5,
        embedding_size = emb_size,
        batch_size = 32,
        n_epochs = 20,
        threshold = 0.5,
        show_plot = False, 
    )
    print(f"^^^^^^^^^ {emb_size} ^^^^^^^^^")
# Out:
# 2026-04-07 07:53:13,383 - steps_camera_3 - INFO - Preparing cycles and participant labels...
# 2026-04-07 07:53:13,536 - steps_camera_3 - INFO - [Iteration 1/4]
# 2026-04-07 07:53:13,548 - steps_camera_3 - INFO - Train dataset size: 560
# 2026-04-07 07:53:13,550 - steps_camera_3 - INFO - Test dataset size: 398
# 2026-04-07 07:53:17,000 - steps_camera_3 - INFO - Epoch 1, Train Loss: 0.2772354690565003
# 2026-04-07 07:53:17,253 - steps_camera_3 - INFO - Epoch 2, Train Loss: 0.24931145624981987
# 2026-04-07 07:53:17,504 - steps_camera_3 - INFO - Epoch 3, Train Loss: 0.21507329907682207
# 2026-04-07 07:53:17,756 - steps_camera_3 - INFO - Epoch 4, Train Loss: 0.1990051054292255
# 2026-04-07 07:53:18,005 - steps_camera_3 - INFO - Epoch 5, Train Loss: 0.18510867489708793
# 2026-04-07 07:53:18,244 - steps_camera_3 - INFO - Epoch 6, Train Loss: 0.1823017100493113
# 2026-04-07 07:53:18,485 - steps_camera_3 - INFO - Epoch 7, Train Loss: 0.16540742417176565
# ...

# %%
for emb_size in [10, 20, 50, 100, 200, 500]:
    cv.perform_training_with_rank_classification(
        n_folds = 4,
        siamese_nn_type = "conv1d",
        learning_rate = 1e-5,
        embedding_size = emb_size,
        batch_size = 32,
        n_epochs = 20,
        tsne_perplexity = 20,
        show_plot = False, 
    )
    print(f"^^^^^^^^^ {emb_size} ^^^^^^^^^")
# Out:
# 2026-04-07 07:55:57,568 - steps_camera_3 - INFO - [Iteration 1/4]
# 2026-04-07 07:55:57,579 - steps_camera_3 - INFO - Train dataset size: 560
# 2026-04-07 07:55:57,829 - steps_camera_3 - INFO - Epoch 1, Train Loss: 0.2667674190468258
# 2026-04-07 07:55:58,057 - steps_camera_3 - INFO - Epoch 2, Train Loss: 0.23751716978020138
# 2026-04-07 07:55:58,288 - steps_camera_3 - INFO - Epoch 3, Train Loss: 0.21301360262764824
# 2026-04-07 07:55:58,542 - steps_camera_3 - INFO - Epoch 4, Train Loss: 0.19948850158188078
# 2026-04-07 07:55:58,782 - steps_camera_3 - INFO - Epoch 5, Train Loss: 0.1808416015572018
# 2026-04-07 07:55:59,029 - steps_camera_3 - INFO - Epoch 6, Train Loss: 0.18746687057945463
# 2026-04-07 07:55:59,274 - steps_camera_3 - INFO - Epoch 7, Train Loss: 0.16762706140677133
# 2026-04-07 07:55:59,516 - steps_camera_3 - INFO - Epoch 8, Train Loss: 0.15068359797199568
# 2026-04-07 07:55:59,762 - steps_camera_3 - INFO - Epoch 9, Train Loss: 0.15208905438582102
# ...

# %%
for emb_size in [10, 20, 50, 100, 200, 500]:
    cv.perform_training(
        n_folds = 4,
        siamese_nn_type = "lstm",
        learning_rate = 1e-4,
        embedding_size = emb_size,
        batch_size = 32,
        n_epochs = 20,
        threshold = 0.5,
        show_plot = False, 
    )
    print(f"^^^^^^^^^ {emb_size} ^^^^^^^^^")
# Out:
# 2026-04-07 08:02:02,832 - steps_camera_3 - INFO - [Iteration 1/4]
# 2026-04-07 08:02:02,842 - steps_camera_3 - INFO - Train dataset size: 560
# 2026-04-07 08:02:02,844 - steps_camera_3 - INFO - Test dataset size: 398
# 2026-04-07 08:02:03,187 - steps_camera_3 - INFO - Epoch 1, Train Loss: 0.38583213256465065
# 2026-04-07 08:02:03,491 - steps_camera_3 - INFO - Epoch 2, Train Loss: 0.3663942598634296
# 2026-04-07 08:02:03,774 - steps_camera_3 - INFO - Epoch 3, Train Loss: 0.3516058027744293
# 2026-04-07 08:02:04,064 - steps_camera_3 - INFO - Epoch 4, Train Loss: 0.34010450210836196
# 2026-04-07 08:02:04,349 - steps_camera_3 - INFO - Epoch 5, Train Loss: 0.31662608765893513
# 2026-04-07 08:02:04,614 - steps_camera_3 - INFO - Epoch 6, Train Loss: 0.2916552664505111
# 2026-04-07 08:02:04,894 - steps_camera_3 - INFO - Epoch 7, Train Loss: 0.25822105010350543
# 2026-04-07 08:02:05,165 - steps_camera_3 - INFO - Epoch 8, Train Loss: 0.23639048470391166
# ...

# %%
for emb_size in [10, 20, 50, 100, 200, 500]:
    cv.perform_training_with_rank_classification(
        n_folds = 4,
        siamese_nn_type = "lstm",
        learning_rate = 1e-4,
        embedding_size = emb_size,
        batch_size = 32,
        n_epochs = 20,
        tsne_perplexity = 20,
        show_plot = False, 
    )
    print(f"^^^^^^^^^ {emb_size} ^^^^^^^^^")
# Out:
# 2026-04-07 08:05:13,157 - steps_camera_3 - INFO - [Iteration 1/4]
# 2026-04-07 08:05:13,168 - steps_camera_3 - INFO - Train dataset size: 560
# 2026-04-07 08:05:13,478 - steps_camera_3 - INFO - Epoch 1, Train Loss: 0.3855261587434345
# 2026-04-07 08:05:13,793 - steps_camera_3 - INFO - Epoch 2, Train Loss: 0.3646670745478736
# 2026-04-07 08:05:14,082 - steps_camera_3 - INFO - Epoch 3, Train Loss: 0.3591981563303206
# 2026-04-07 08:05:14,385 - steps_camera_3 - INFO - Epoch 4, Train Loss: 0.34238606443007785
# 2026-04-07 08:05:14,686 - steps_camera_3 - INFO - Epoch 5, Train Loss: 0.32641077372762894
# 2026-04-07 08:05:14,989 - steps_camera_3 - INFO - Epoch 6, Train Loss: 0.31244661824570763
# 2026-04-07 08:05:15,287 - steps_camera_3 - INFO - Epoch 7, Train Loss: 0.31106559849447674
# 2026-04-07 08:05:15,621 - steps_camera_3 - INFO - Epoch 8, Train Loss: 0.2850417908695009
# 2026-04-07 08:05:15,916 - steps_camera_3 - INFO - Epoch 9, Train Loss: 0.26529045154651004
# ...

# %%
cv = CrossValidationSiameseRaw2D(
    sequence_cycles=steps_camera_3_butterworth, 
    selected_joints=selected_joint_names,
    log_level=logging.INFO,
    logger_name = 'steps_camera_3_butterworth',
    involve_hands_parameters=False,
)
cv.count_participants_samples()

for emb_size in [10, 20, 50, 100, 200, 500]:
    cv.perform_training(
        n_folds = 4,
        siamese_nn_type = "conv1d",
        learning_rate = 1e-5,
        embedding_size = emb_size,
        batch_size = 32,
        n_epochs = 20,
        threshold = 0.5,
        show_plot = False, 
    )
    print(f"^^^^^^^^^ {emb_size} ^^^^^^^^^")
# Out:
# 2026-04-07 08:11:42,794 - steps_camera_3_butterworth - INFO - Preparing cycles and participant labels...
# 2026-04-07 08:11:42,979 - steps_camera_3_butterworth - INFO - [Iteration 1/4]
# 2026-04-07 08:11:43,005 - steps_camera_3_butterworth - INFO - Train dataset size: 792
# 2026-04-07 08:11:43,007 - steps_camera_3_butterworth - INFO - Test dataset size: 630
# 2026-04-07 08:11:43,367 - steps_camera_3_butterworth - INFO - Epoch 1, Train Loss: 0.2756877988576889
# 2026-04-07 08:11:43,720 - steps_camera_3_butterworth - INFO - Epoch 2, Train Loss: 0.24741500973701477
# 2026-04-07 08:11:44,060 - steps_camera_3_butterworth - INFO - Epoch 3, Train Loss: 0.21862164318561553
# 2026-04-07 08:11:44,420 - steps_camera_3_butterworth - INFO - Epoch 4, Train Loss: 0.21297604262828826
# 2026-04-07 08:11:44,751 - steps_camera_3_butterworth - INFO - Epoch 5, Train Loss: 0.20016536355018616
# 2026-04-07 08:11:45,108 - steps_camera_3_butterworth - INFO - Epoch 6, Train Loss: 0.19715731859207153
# ...

# %%
for emb_size in [10, 20, 50, 100, 200, 500]:
    cv.perform_training_with_rank_classification(
        n_folds = 4,
        siamese_nn_type = "conv1d",
        learning_rate = 1e-5,
        embedding_size = emb_size,
        batch_size = 32,
        n_epochs = 20,
        tsne_perplexity = 20,
        show_plot = False, 
    )
    print(f"^^^^^^^^^ {emb_size} ^^^^^^^^^")
# Out:
# 2026-04-07 08:15:30,327 - steps_camera_3_butterworth - INFO - [Iteration 1/4]
# 2026-04-07 08:15:30,337 - steps_camera_3_butterworth - INFO - Train dataset size: 792
# 2026-04-07 08:15:30,683 - steps_camera_3_butterworth - INFO - Epoch 1, Train Loss: 0.2848063725233078
# 2026-04-07 08:15:30,996 - steps_camera_3_butterworth - INFO - Epoch 2, Train Loss: 0.24146899044513703
# 2026-04-07 08:15:31,316 - steps_camera_3_butterworth - INFO - Epoch 3, Train Loss: 0.22652286231517793
# 2026-04-07 08:15:31,655 - steps_camera_3_butterworth - INFO - Epoch 4, Train Loss: 0.21004506945610046
# 2026-04-07 08:15:31,969 - steps_camera_3_butterworth - INFO - Epoch 5, Train Loss: 0.19634766221046449
# 2026-04-07 08:15:32,274 - steps_camera_3_butterworth - INFO - Epoch 6, Train Loss: 0.1913295465707779
# 2026-04-07 08:15:32,591 - steps_camera_3_butterworth - INFO - Epoch 7, Train Loss: 0.17896928936243056
# ...

# %%
for emb_size in [10, 20, 50, 100, 200, 500]:
    cv.perform_training(
        n_folds = 4,
        siamese_nn_type = "lstm",
        learning_rate = 1e-4,
        embedding_size = emb_size,
        batch_size = 32,
        n_epochs = 20,
        threshold = 0.5,
        show_plot = False, 
    )
    print(f"^^^^^^^^^ {emb_size} ^^^^^^^^^")
# Out:
# 2026-04-07 08:23:15,924 - steps_camera_3_butterworth - INFO - [Iteration 1/4]
# 2026-04-07 08:23:15,940 - steps_camera_3_butterworth - INFO - Train dataset size: 792
# 2026-04-07 08:23:15,942 - steps_camera_3_butterworth - INFO - Test dataset size: 630
# 2026-04-07 08:23:16,455 - steps_camera_3_butterworth - INFO - Epoch 1, Train Loss: 0.39437417685985565
# 2026-04-07 08:23:16,983 - steps_camera_3_butterworth - INFO - Epoch 2, Train Loss: 0.37658260464668275
# 2026-04-07 08:23:17,495 - steps_camera_3_butterworth - INFO - Epoch 3, Train Loss: 0.3538623797893524
# 2026-04-07 08:23:18,189 - steps_camera_3_butterworth - INFO - Epoch 4, Train Loss: 0.3297906070947647
# 2026-04-07 08:23:18,847 - steps_camera_3_butterworth - INFO - Epoch 5, Train Loss: 0.3003458768129349
# 2026-04-07 08:23:19,407 - steps_camera_3_butterworth - INFO - Epoch 6, Train Loss: 0.28781971633434295
# 2026-04-07 08:23:19,892 - steps_camera_3_butterworth - INFO - Epoch 7, Train Loss: 0.26087302327156064
# ...

# %%
for emb_size in [10, 20, 50, 100, 200, 500]:
    cv.perform_training_with_rank_classification(
        n_folds = 4,
        siamese_nn_type = "lstm",
        learning_rate = 1e-4,
        embedding_size = emb_size,
        batch_size = 32,
        n_epochs = 20,
        tsne_perplexity = 20,
        show_plot = False, 
    )
    print(f"^^^^^^^^^ {emb_size} ^^^^^^^^^")
