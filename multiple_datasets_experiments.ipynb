# %%
import logging
from utils.cross_validation_siamese_raw_multiple_datasets import CrossValidationSiameseMultipleDs
from utils.cross_validation_siamese_raw import TrainingProcedureParameters, TrainingParameters

tpp = TrainingProcedureParameters(
    tp_conv1d = TrainingParameters(
        learning_rate = 1e-6,
        batch_size = 32,
        n_epochs = 100,
        # n_epochs = 20,
    ),
    tp_lstm = TrainingParameters(
        learning_rate = 1e-5,
        batch_size = 32,
        n_epochs = 150,
    )
)

tpp
# Out:
# TrainingProcedureParameters(tp_conv1d=TrainingParameters(learning_rate=1e-06, batch_size=32, n_epochs=100), tp_lstm=TrainingParameters(learning_rate=1e-05, batch_size=32, n_epochs=150), n_folds=4)

# %%
import logging

cv = CrossValidationSiameseMultipleDs(
    log_level = logging.INFO,
    logger_name = 'multiple_datasets_first_training',
)

cv.perform_training_with_rank_classification_and_multiple_datasets(
    n_folds = tpp.n_folds,
    selected_datasets = None, # to use all available
    diff_dataset_usage = "DATASET_TYPE",
    siamese_nn_type = "conv1d",
    learning_rate = tpp.tp_conv1d.learning_rate,
    batch_size = tpp.tp_conv1d.batch_size,
    n_epochs = tpp.tp_conv1d.n_epochs,
    embedding_size = 10,
    tsne_perplexity = 20,
    show_plot = True, 
)
# Out:
# 2026-03-02 11:31:10,392 - multiple_datasets_first_training - INFO - [Iteration 1/4]
# 2026-03-02 11:31:14,662 - multiple_datasets_first_training - INFO - Train dataset size: 34878
# 2026-03-02 11:31:14,664 - multiple_datasets_first_training - INFO - Test dataset size: 2240
# 2026-03-02 11:31:14,665 - multiple_datasets_first_training - INFO - Using device: cuda
# 2026-03-02 11:31:23,183 - multiple_datasets_first_training - INFO - Epoch 1, Train Loss: 870142.1524253248
# 2026-03-02 11:31:31,815 - multiple_datasets_first_training - INFO - Epoch 2, Train Loss: 331023.0078795863
# 2026-03-02 11:31:40,347 - multiple_datasets_first_training - INFO - Epoch 3, Train Loss: 97845.70717968525
# 2026-03-02 11:31:49,071 - multiple_datasets_first_training - INFO - Epoch 4, Train Loss: 21999.403650537763
# 2026-03-02 11:31:57,610 - multiple_datasets_first_training - INFO - Epoch 5, Train Loss: 8072.469153669996
# ...

# %%
cv = CrossValidationSiameseMultipleDs(
    log_level = logging.INFO,
    logger_name = 'multiple_datasets_playbook',
)

cv.perform_training_with_rank_classification_and_multiple_datasets(
    n_folds = tpp.n_folds,
    selected_datasets = 'yolo_v26', 
    diff_dataset_usage = "DATASET_TYPE",
    siamese_nn_type = "conv1d",
    learning_rate = tpp.tp_conv1d.learning_rate,
    batch_size = tpp.tp_conv1d.batch_size,
    n_epochs = tpp.tp_conv1d.n_epochs,
    embedding_size = 10,
    tsne_perplexity = 20,
    show_plot = True, 
)
# Out:
# 2026-03-02 12:47:46,891 - multiple_datasets_playbook - INFO - [Iteration 1/4]
# 2026-03-02 12:47:50,741 - multiple_datasets_playbook - INFO - Train dataset size: 3046
# 2026-03-02 12:47:50,743 - multiple_datasets_playbook - INFO - Test dataset size: 2240
# 2026-03-02 12:47:50,743 - multiple_datasets_playbook - INFO - Using device: cuda
# 2026-03-02 12:47:51,505 - multiple_datasets_playbook - INFO - Epoch 1, Train Loss: 5.425579957664013
# 2026-03-02 12:47:52,246 - multiple_datasets_playbook - INFO - Epoch 2, Train Loss: 3.5338019157449403
# 2026-03-02 12:47:52,996 - multiple_datasets_playbook - INFO - Epoch 3, Train Loss: 2.4682429373885193
# 2026-03-02 12:47:53,734 - multiple_datasets_playbook - INFO - Epoch 4, Train Loss: 1.8158684230099122
# 2026-03-02 12:47:54,478 - multiple_datasets_playbook - INFO - Epoch 5, Train Loss: 1.4023504309977095
# 2026-03-02 12:47:55,245 - multiple_datasets_playbook - INFO - Epoch 6, Train Loss: 1.1160131441429257
# ...

# %%
cv = CrossValidationSiameseMultipleDs(
    log_level = logging.INFO,
    logger_name = 'multiple_datasets_playbook',
)

cv.perform_training_with_rank_classification_and_multiple_datasets(
    n_folds = tpp.n_folds,
    selected_datasets = ['yolo_v26', 'mocap'], 
    diff_dataset_usage = "DATASET_TYPE",
    siamese_nn_type = "conv1d",
    learning_rate = tpp.tp_conv1d.learning_rate,
    batch_size = tpp.tp_conv1d.batch_size,
    n_epochs = tpp.tp_conv1d.n_epochs,
    embedding_size = 10,
    tsne_perplexity = 20,
    show_plot = True, 
)
# Out:
# 2026-03-02 12:55:15,215 - multiple_datasets_playbook - INFO - [Iteration 1/4]
# 2026-03-02 12:55:19,168 - multiple_datasets_playbook - INFO - Train dataset size: 6088
# 2026-03-02 12:55:19,169 - multiple_datasets_playbook - INFO - Test dataset size: 2240
# 2026-03-02 12:55:19,170 - multiple_datasets_playbook - INFO - Using device: cuda
# 2026-03-02 12:55:20,685 - multiple_datasets_playbook - INFO - Epoch 1, Train Loss: 7.612790133940612
# 2026-03-02 12:55:22,215 - multiple_datasets_playbook - INFO - Epoch 2, Train Loss: 3.6942823707121204
# 2026-03-02 12:55:23,741 - multiple_datasets_playbook - INFO - Epoch 3, Train Loss: 1.9271426280443582
# 2026-03-02 12:55:25,219 - multiple_datasets_playbook - INFO - Epoch 4, Train Loss: 1.2128860054839967
# 2026-03-02 12:55:26,719 - multiple_datasets_playbook - INFO - Epoch 5, Train Loss: 0.8737903817785972
# 2026-03-02 12:55:28,250 - multiple_datasets_playbook - INFO - Epoch 6, Train Loss: 0.6673854761878858
# ...

# %%
cv = CrossValidationSiameseMultipleDs(
    log_level = logging.INFO,
    logger_name = 'multiple_datasets_playbook',
)

cv.perform_training_with_rank_classification_and_multiple_datasets(
    n_folds = tpp.n_folds,
    selected_datasets = ['yolo_v26', 'mocap'], 
    diff_dataset_usage = "MIX_ALL",
    siamese_nn_type = "conv1d",
    learning_rate = tpp.tp_conv1d.learning_rate,
    batch_size = tpp.tp_conv1d.batch_size,
    n_epochs = tpp.tp_conv1d.n_epochs,
    embedding_size = 10,
    tsne_perplexity = 20,
    show_plot = True, 
)
# Out:
# 2026-03-02 13:09:05,463 - multiple_datasets_playbook - INFO - [Iteration 1/4]
# 2026-03-02 13:09:09,479 - multiple_datasets_playbook - INFO - Train dataset size: 12712
# 2026-03-02 13:09:09,481 - multiple_datasets_playbook - INFO - Test dataset size: 2240
# 2026-03-02 13:09:09,482 - multiple_datasets_playbook - INFO - Using device: cuda
# 2026-03-02 13:09:12,595 - multiple_datasets_playbook - INFO - Epoch 1, Train Loss: 3.3188772409705063
# 2026-03-02 13:09:15,776 - multiple_datasets_playbook - INFO - Epoch 2, Train Loss: 1.648608525082394
# 2026-03-02 13:09:18,857 - multiple_datasets_playbook - INFO - Epoch 3, Train Loss: 1.0123834926728628
# 2026-03-02 13:09:21,904 - multiple_datasets_playbook - INFO - Epoch 4, Train Loss: 0.6837984431890687
# 2026-03-02 13:09:25,027 - multiple_datasets_playbook - INFO - Epoch 5, Train Loss: 0.5002655818983538
# 2026-03-02 13:09:28,165 - multiple_datasets_playbook - INFO - Epoch 6, Train Loss: 0.3849830538053159
# ...

# %%
cv = CrossValidationSiameseMultipleDs(
    log_level = logging.INFO,
    logger_name = 'multiple_datasets_playbook',
)

cv.perform_training_with_rank_classification_and_multiple_datasets(
    n_folds = tpp.n_folds,
    selected_datasets = 'yolo_v26', 
    diff_dataset_usage = "DATASET_TYPE",
    siamese_nn_type = "conv1d",
    optimizer_type = "adamw",
    learning_rate = 1e-5,
    batch_size = 32,
    n_epochs = 200,
    embedding_size = 10,
    tsne_perplexity = 20,
    show_plot = True, 
)
# Out:
# 2026-03-01 23:00:59,918 - multiple_datasets_playbook - INFO - [Iteration 1/4]
# 2026-03-01 23:01:03,827 - multiple_datasets_playbook - INFO - Train dataset size: 3046
# 2026-03-01 23:01:03,828 - multiple_datasets_playbook - INFO - Test dataset size: 2240
# 2026-03-01 23:01:03,829 - multiple_datasets_playbook - INFO - Using device: cuda
# 2026-03-01 23:01:04,510 - multiple_datasets_playbook - INFO - Epoch 1, Train Loss: 1.5508669546494882
# 2026-03-01 23:01:05,176 - multiple_datasets_playbook - INFO - Epoch 2, Train Loss: 0.25162940348188084
# 2026-03-01 23:01:05,786 - multiple_datasets_playbook - INFO - Epoch 3, Train Loss: 0.14601131800251702
# 2026-03-01 23:01:06,372 - multiple_datasets_playbook - INFO - Epoch 4, Train Loss: 0.12515919116170457
# 2026-03-01 23:01:06,932 - multiple_datasets_playbook - INFO - Epoch 5, Train Loss: 0.11537879363944133
# 2026-03-01 23:01:07,490 - multiple_datasets_playbook - INFO - Epoch 6, Train Loss: 0.10694133680469046
# ...

# %%
cv = CrossValidationSiameseMultipleDs(
    log_level = logging.INFO,
    logger_name = 'multiple_datasets_playbook',
)

cv.perform_training_with_rank_classification_and_multiple_datasets(
    n_folds = tpp.n_folds,
    selected_datasets = 'yolo_v26', 
    diff_dataset_usage = "DATASET_TYPE",
    siamese_nn_type = "conv1dbn",
    optimizer_type = "adamw",
    learning_rate = 1e-6,
    batch_size = 32,
    n_epochs = 100,
    embedding_size = 10,
    tsne_perplexity = 20,
    show_plot = True, 
)
# Out:
# 2026-03-01 23:14:09,809 - multiple_datasets_playbook - INFO - [Iteration 1/4]
# 2026-03-01 23:14:13,604 - multiple_datasets_playbook - INFO - Train dataset size: 3046
# 2026-03-01 23:14:13,605 - multiple_datasets_playbook - INFO - Test dataset size: 2240
# 2026-03-01 23:14:13,605 - multiple_datasets_playbook - INFO - Using device: cuda
# 2026-03-01 23:14:14,367 - multiple_datasets_playbook - INFO - Epoch 1, Train Loss: 10.043862164020538
# 2026-03-01 23:14:14,939 - multiple_datasets_playbook - INFO - Epoch 2, Train Loss: 6.144057599206765
# 2026-03-01 23:14:15,507 - multiple_datasets_playbook - INFO - Epoch 3, Train Loss: 3.7913184873759747
# 2026-03-01 23:14:16,078 - multiple_datasets_playbook - INFO - Epoch 4, Train Loss: 2.411494817584753
# 2026-03-01 23:14:16,643 - multiple_datasets_playbook - INFO - Epoch 5, Train Loss: 1.6643059362346928
# 2026-03-01 23:14:17,210 - multiple_datasets_playbook - INFO - Epoch 6, Train Loss: 1.259288962930441
# ...

# %%
# NEW

cv = CrossValidationSiameseMultipleDs(
    log_level = logging.INFO,
    logger_name = 'multiple_datasets_playbook',
)

cv.perform_training_with_rank_classification_and_multiple_datasets(
    n_folds = tpp.n_folds,
    selected_datasets = ['yolo_v26', 'mocap'], 
    diff_dataset_usage = "DATASET_TYPE",
    siamese_nn_type = "conv1dbn",
    optimizer_type = "adamw",
    learning_rate = 1e-6,
    batch_size = 32,
    n_epochs = 100,
    embedding_size = 10,
    tsne_perplexity = 20,
    show_plot = True, 
)
# Out:
# 2026-03-01 23:32:24,208 - multiple_datasets_playbook - INFO - [Iteration 1/4]
# 2026-03-01 23:32:27,833 - multiple_datasets_playbook - INFO - Train dataset size: 6088
# 2026-03-01 23:32:27,834 - multiple_datasets_playbook - INFO - Test dataset size: 2240
# 2026-03-01 23:32:27,835 - multiple_datasets_playbook - INFO - Using device: cuda
# 2026-03-01 23:32:29,165 - multiple_datasets_playbook - INFO - Epoch 1, Train Loss: 7.400254204635221
# 2026-03-01 23:32:30,304 - multiple_datasets_playbook - INFO - Epoch 2, Train Loss: 3.0392268711983847
# 2026-03-01 23:32:31,439 - multiple_datasets_playbook - INFO - Epoch 3, Train Loss: 1.5584073719709957
# 2026-03-01 23:32:32,569 - multiple_datasets_playbook - INFO - Epoch 4, Train Loss: 1.0480365001094278
# 2026-03-01 23:32:33,701 - multiple_datasets_playbook - INFO - Epoch 5, Train Loss: 0.7980785366752385
# 2026-03-01 23:32:34,841 - multiple_datasets_playbook - INFO - Epoch 6, Train Loss: 0.6254391149856657
# ...

# %%
# NEW

cv = CrossValidationSiameseMultipleDs(
    log_level = logging.INFO,
    logger_name = 'multiple_datasets_playbook',
)

cv.perform_training_with_rank_classification_and_multiple_datasets(
    n_folds = tpp.n_folds,
    selected_datasets = ['yolo_v26', 'mocap'], 
    diff_dataset_usage = "MIX_ALL",
    siamese_nn_type = "conv1dbn",
    optimizer_type = "adamw",
    learning_rate = 1e-6,
    batch_size = 32,
    n_epochs = 100,
    embedding_size = 10,
    tsne_perplexity = 20,
    show_plot = True, 
)
# Out:
# 2026-03-01 23:43:06,367 - multiple_datasets_playbook - INFO - [Iteration 1/4]
# 2026-03-01 23:43:10,289 - multiple_datasets_playbook - INFO - Train dataset size: 12712
# 2026-03-01 23:43:10,291 - multiple_datasets_playbook - INFO - Test dataset size: 2240
# 2026-03-01 23:43:10,292 - multiple_datasets_playbook - INFO - Using device: cuda
# 2026-03-01 23:43:12,752 - multiple_datasets_playbook - INFO - Epoch 1, Train Loss: 3.8345825297748624
# 2026-03-01 23:43:15,071 - multiple_datasets_playbook - INFO - Epoch 2, Train Loss: 1.0554282180028944
# 2026-03-01 23:43:17,412 - multiple_datasets_playbook - INFO - Epoch 3, Train Loss: 0.4667452669248509
# 2026-03-01 23:43:19,749 - multiple_datasets_playbook - INFO - Epoch 4, Train Loss: 0.27898916229605675
# 2026-03-01 23:43:22,343 - multiple_datasets_playbook - INFO - Epoch 5, Train Loss: 0.2071199756508796
# 2026-03-01 23:43:24,681 - multiple_datasets_playbook - INFO - Epoch 6, Train Loss: 0.17579738788269272
# ...

# %%
cv = CrossValidationSiameseMultipleDs(
    log_level = logging.INFO,
    logger_name = 'multiple_datasets_playbook',
)

cv.perform_training_with_rank_classification_and_multiple_datasets(
    n_folds = tpp.n_folds,
    selected_datasets = 'mocap', 
    test_dataset_type = 'yolo_v26',
    diff_dataset_usage = "DATASET_TYPE",
    siamese_nn_type = "conv1d",
    learning_rate = tpp.tp_conv1d.learning_rate,
    batch_size = tpp.tp_conv1d.batch_size,
    n_epochs = 50,
    embedding_size = 10,
    tsne_perplexity = 20,
    show_plot = True, 
)
# Out:
# 2026-03-01 20:52:37,706 - multiple_datasets_playbook - INFO - [Iteration 1/4]
# 2026-03-01 20:52:41,357 - multiple_datasets_playbook - INFO - Train dataset size: 3042
# 2026-03-01 20:52:41,359 - multiple_datasets_playbook - INFO - Test dataset size: 2240
# 2026-03-01 20:52:41,360 - multiple_datasets_playbook - INFO - Using device: cuda
# 2026-03-01 20:52:42,065 - multiple_datasets_playbook - INFO - Epoch 1, Train Loss: 2.72077884649237
# 2026-03-01 20:52:42,635 - multiple_datasets_playbook - INFO - Epoch 2, Train Loss: 1.8023828243215878
# 2026-03-01 20:52:43,205 - multiple_datasets_playbook - INFO - Epoch 3, Train Loss: 1.2988768604894478
# 2026-03-01 20:52:43,773 - multiple_datasets_playbook - INFO - Epoch 4, Train Loss: 0.9501293820018569
# 2026-03-01 20:52:44,342 - multiple_datasets_playbook - INFO - Epoch 5, Train Loss: 0.7439564606174827
# 2026-03-01 20:52:44,911 - multiple_datasets_playbook - INFO - Epoch 6, Train Loss: 0.6125427557465931
# ...

# %%
cv = CrossValidationSiameseMultipleDs(
    log_level = logging.INFO,
    logger_name = 'multiple_datasets_playbook',
)

cv.perform_training_with_rank_classification_and_multiple_datasets(
    n_folds = tpp.n_folds,
    selected_datasets = ['mocap', 'yolo_v26', 'vitpose', 'hrnet', 'rtmpose'],
    test_dataset_type = 'yolo_v26',
    diff_dataset_usage = "DATASET_TYPE",
    siamese_nn_type = "conv1d",
    learning_rate = tpp.tp_conv1d.learning_rate,
    batch_size = tpp.tp_conv1d.batch_size,
    n_epochs = 50,
    embedding_size = 10,
    tsne_perplexity = 20,
    show_plot = True, 
)
# Out:
# 2026-03-01 20:57:55,845 - multiple_datasets_playbook - INFO - [Iteration 1/4]
# 2026-03-01 20:57:59,524 - multiple_datasets_playbook - INFO - Train dataset size: 17154
# 2026-03-01 20:57:59,525 - multiple_datasets_playbook - INFO - Test dataset size: 2240
# 2026-03-01 20:57:59,526 - multiple_datasets_playbook - INFO - Using device: cuda
# 2026-03-01 20:58:02,823 - multiple_datasets_playbook - INFO - Epoch 1, Train Loss: 204.72558022433375
# 2026-03-01 20:58:05,998 - multiple_datasets_playbook - INFO - Epoch 2, Train Loss: 145.20298404045388
# 2026-03-01 20:58:09,499 - multiple_datasets_playbook - INFO - Epoch 3, Train Loss: 99.12719517602157
# 2026-03-01 20:58:13,015 - multiple_datasets_playbook - INFO - Epoch 4, Train Loss: 64.98288780245478
# 2026-03-01 20:58:16,754 - multiple_datasets_playbook - INFO - Epoch 5, Train Loss: 40.49914249750045
# 2026-03-01 20:58:20,160 - multiple_datasets_playbook - INFO - Epoch 6, Train Loss: 23.5635401170902
# ...

# %%
cv = CrossValidationSiameseMultipleDs(
    log_level = logging.INFO,
    logger_name = 'multiple_datasets_playbook',
)

cv.perform_training_with_rank_classification_and_multiple_datasets(
    n_folds = tpp.n_folds,
    selected_datasets = ['mocap', 'yolo_v26', 'vitpose', 'hrnet', 'rtmpose'],
    test_dataset_type = 'yolo_v26',
    diff_dataset_usage = "SKELETON_TYPE",
    siamese_nn_type = "conv1d",
    learning_rate = tpp.tp_conv1d.learning_rate,
    batch_size = tpp.tp_conv1d.batch_size,
    n_epochs = 20,
    embedding_size = 10,
    tsne_perplexity = 20,
    show_plot = True, 
)
# Out:
# 2026-03-01 21:16:28,217 - multiple_datasets_playbook - INFO - [Iteration 1/4]
# 2026-03-01 21:16:32,808 - multiple_datasets_playbook - INFO - Train dataset size: 62522
# 2026-03-01 21:16:32,810 - multiple_datasets_playbook - INFO - Test dataset size: 2240
# 2026-03-01 21:16:32,841 - multiple_datasets_playbook - INFO - Using device: cuda
# 2026-03-01 21:16:47,657 - multiple_datasets_playbook - INFO - Epoch 1, Train Loss: 47.55450014178255
# 2026-03-01 21:16:59,138 - multiple_datasets_playbook - INFO - Epoch 2, Train Loss: 4.212760897118793
# 2026-03-01 21:17:10,312 - multiple_datasets_playbook - INFO - Epoch 3, Train Loss: 0.29778927542505634
# 2026-03-01 21:17:21,791 - multiple_datasets_playbook - INFO - Epoch 4, Train Loss: 0.185854552111597
# 2026-03-01 21:17:33,148 - multiple_datasets_playbook - INFO - Epoch 5, Train Loss: 0.1440742085482868
# 2026-03-01 21:17:44,684 - multiple_datasets_playbook - INFO - Epoch 6, Train Loss: 0.12403146704676024
# ...

# %%
cv = CrossValidationSiameseMultipleDs(
    log_level = logging.INFO,
    logger_name = 'multiple_datasets_playbook',
)

cv.perform_training_with_rank_classification_and_multiple_datasets(
    n_folds = tpp.n_folds,
    selected_datasets = ['mocap', 'yolo_v26', 'vitpose', 'openpose'],
    test_dataset_type = 'yolo_v26',
    diff_dataset_usage = "MIX_ALL",
    siamese_nn_type = "conv1d",
    learning_rate = tpp.tp_conv1d.learning_rate,
    batch_size = tpp.tp_conv1d.batch_size,
    n_epochs = 20,
    embedding_size = 10,
    tsne_perplexity = 20,
    show_plot = True, 
)
# Out:
# 2026-03-01 21:39:19,212 - multiple_datasets_playbook - INFO - [Iteration 1/4]
# 2026-03-01 21:39:23,274 - multiple_datasets_playbook - INFO - Train dataset size: 56576
# 2026-03-01 21:39:23,276 - multiple_datasets_playbook - INFO - Test dataset size: 2240
# 2026-03-01 21:39:23,277 - multiple_datasets_playbook - INFO - Using device: cuda
# 2026-03-01 21:39:35,235 - multiple_datasets_playbook - INFO - Epoch 1, Train Loss: 71.79029985085737
# 2026-03-01 21:39:46,889 - multiple_datasets_playbook - INFO - Epoch 2, Train Loss: 8.89736683091056
# 2026-03-01 21:39:57,741 - multiple_datasets_playbook - INFO - Epoch 3, Train Loss: 0.5960541000648726
# 2026-03-01 21:40:08,586 - multiple_datasets_playbook - INFO - Epoch 4, Train Loss: 0.2842234534156673
# 2026-03-01 21:40:19,382 - multiple_datasets_playbook - INFO - Epoch 5, Train Loss: 0.2035507469846787
# 2026-03-01 21:40:30,100 - multiple_datasets_playbook - INFO - Epoch 6, Train Loss: 0.16810876782140716
# ...

# %%
# NEW

cv = CrossValidationSiameseMultipleDs(
    log_level = logging.INFO,
    logger_name = 'multiple_datasets_playbook',
)

cv.perform_training_with_rank_classification_and_multiple_datasets(
    n_folds = tpp.n_folds,
    selected_datasets = ['mocap', 'yolo_v26', 'vitpose', 'openpose'],
    test_dataset_type = 'yolo_v26',
    diff_dataset_usage = "MIX_ALL",
    siamese_nn_type = "conv1dbn",
    optimizer_type = "adamw",
    learning_rate = 1e-6,
    batch_size = 32,
    n_epochs = 100,
    embedding_size = 10,
    tsne_perplexity = 20,
    show_plot = True, 
)
# Out:
# 2026-03-02 00:04:36,203 - multiple_datasets_playbook - INFO - [Iteration 1/4]
# 2026-03-02 00:04:40,611 - multiple_datasets_playbook - INFO - Train dataset size: 56576
# 2026-03-02 00:04:40,612 - multiple_datasets_playbook - INFO - Test dataset size: 2240
# 2026-03-02 00:04:40,613 - multiple_datasets_playbook - INFO - Using device: cuda
# 2026-03-02 00:04:51,393 - multiple_datasets_playbook - INFO - Epoch 1, Train Loss: 38.84105094097453
# 2026-03-02 00:05:02,209 - multiple_datasets_playbook - INFO - Epoch 2, Train Loss: 2.511700183886411
# 2026-03-02 00:05:12,911 - multiple_datasets_playbook - INFO - Epoch 3, Train Loss: 0.3671078484893115
# 2026-03-02 00:05:23,745 - multiple_datasets_playbook - INFO - Epoch 4, Train Loss: 0.23444187528205135
# 2026-03-02 00:05:34,341 - multiple_datasets_playbook - INFO - Epoch 5, Train Loss: 0.18245249558493024
# 2026-03-02 00:05:45,224 - multiple_datasets_playbook - INFO - Epoch 6, Train Loss: 0.1581395480558445
# ...

# %%
# NEW

cv = CrossValidationSiameseMultipleDs(
    log_level = logging.INFO,
    logger_name = 'multiple_datasets_playbook',
)

cv.perform_training_with_rank_classification_and_multiple_datasets(
    n_folds = tpp.n_folds,
    selected_datasets = ['yolo_v26', 'vitpose', 'hrnet', 'rtmpose'],
    test_dataset_type = 'yolo_v26',
    diff_dataset_usage = "MIX_ALL",
    siamese_nn_type = "conv1dbn",
    optimizer_type = "adamw",
    learning_rate = 1e-6,
    batch_size = 32,
    n_epochs = 100,
    embedding_size = 10,
    tsne_perplexity = 20,
    show_plot = True, 
)

# %%
# NEW

cv = CrossValidationSiameseMultipleDs(
    log_level = logging.INFO,
    logger_name = 'multiple_datasets_playbook',
)

cv.perform_training_with_rank_classification_and_multiple_datasets(
    n_folds = tpp.n_folds,
    selected_datasets = ['mocap', 'yolo_v26', 'vitpose', 'openpose'],
    test_dataset_type = 'yolo_v26',
    diff_dataset_usage = "SKELETON_TYPE",
    siamese_nn_type = "conv1dbn",
    optimizer_type = "adamw",
    learning_rate = 1e-6,
    batch_size = 32,
    n_epochs = 100,
    embedding_size = 10,
    tsne_perplexity = 20,
    show_plot = True, 
)
# Out:
# 2026-03-02 07:19:56,201 - multiple_datasets_playbook - INFO - [Iteration 1/4]
# 2026-03-02 07:19:59,901 - multiple_datasets_playbook - INFO - Train dataset size: 20582
# 2026-03-02 07:19:59,903 - multiple_datasets_playbook - INFO - Test dataset size: 2240
# 2026-03-02 07:19:59,903 - multiple_datasets_playbook - INFO - Using device: cuda
# 2026-03-02 07:20:03,890 - multiple_datasets_playbook - INFO - Epoch 1, Train Loss: 108.28963438999949
# 2026-03-02 07:20:07,736 - multiple_datasets_playbook - INFO - Epoch 2, Train Loss: 54.621428331695725
# 2026-03-02 07:20:11,874 - multiple_datasets_playbook - INFO - Epoch 3, Train Loss: 23.728163474279903
# 2026-03-02 07:20:15,706 - multiple_datasets_playbook - INFO - Epoch 4, Train Loss: 8.727311830180957
# 2026-03-02 07:20:19,616 - multiple_datasets_playbook - INFO - Epoch 5, Train Loss: 2.71983551426056
# 2026-03-02 07:20:23,511 - multiple_datasets_playbook - INFO - Epoch 6, Train Loss: 0.9306323065058045
# ...

# %%
# NEW

cv = CrossValidationSiameseMultipleDs(
    log_level = logging.INFO,
    logger_name = 'multiple_datasets_playbook',
)

cv.perform_training_with_rank_classification_and_multiple_datasets(
    n_folds = tpp.n_folds,
    selected_datasets = ['mocap', 'yolo_v26', 'vitpose', 'openpose'],
    test_dataset_type = 'yolo_v26',
    diff_dataset_usage = "DATASET_TYPE",
    siamese_nn_type = "conv1dbn",
    optimizer_type = "adamw",
    learning_rate = 1e-6,
    batch_size = 32,
    n_epochs = 100,
    embedding_size = 10,
    tsne_perplexity = 20,
    show_plot = True, 
)
# Out:
# 2026-03-02 07:56:54,181 - multiple_datasets_playbook - INFO - [Iteration 1/4]
# 2026-03-02 07:56:57,809 - multiple_datasets_playbook - INFO - Train dataset size: 13420
# 2026-03-02 07:56:57,810 - multiple_datasets_playbook - INFO - Test dataset size: 2240
# 2026-03-02 07:56:57,811 - multiple_datasets_playbook - INFO - Using device: cuda
# 2026-03-02 07:57:00,505 - multiple_datasets_playbook - INFO - Epoch 1, Train Loss: 101.68984753234047
# 2026-03-02 07:57:03,058 - multiple_datasets_playbook - INFO - Epoch 2, Train Loss: 63.72211621829442
# 2026-03-02 07:57:05,622 - multiple_datasets_playbook - INFO - Epoch 3, Train Loss: 38.60479837755362
# 2026-03-02 07:57:08,177 - multiple_datasets_playbook - INFO - Epoch 4, Train Loss: 21.611119717217626
# 2026-03-02 07:57:10,709 - multiple_datasets_playbook - INFO - Epoch 5, Train Loss: 11.228275793294111
# 2026-03-02 07:57:13,492 - multiple_datasets_playbook - INFO - Epoch 6, Train Loss: 5.211470184013957
# ...

# %%
cv = CrossValidationSiameseMultipleDs(
    log_level = logging.INFO,
    logger_name = 'multiple_datasets_playbook',
)

cv.perform_training_with_rank_classification_and_multiple_datasets(
    n_folds = tpp.n_folds,
    selected_datasets = ['mocap', 'yolo_v26', 'vitpose', 'openpose'],
    test_dataset_type = 'yolo_v26',
    diff_dataset_usage = "MIX_ALL",
    siamese_nn_type = "lstm",
    learning_rate = tpp.tp_lstm.learning_rate,
    batch_size = tpp.tp_lstm.batch_size,
    n_epochs = 20,
    embedding_size = 10,
    tsne_perplexity = 20,
    show_plot = True, 
)
# Out:
# 2026-03-01 22:02:11,771 - multiple_datasets_playbook - INFO - [Iteration 1/4]
# 2026-03-01 22:02:15,488 - multiple_datasets_playbook - INFO - Train dataset size: 56576
# 2026-03-01 22:02:15,490 - multiple_datasets_playbook - INFO - Test dataset size: 2240
# 2026-03-01 22:02:15,490 - multiple_datasets_playbook - INFO - Using device: cuda
# 2026-03-01 22:02:28,622 - multiple_datasets_playbook - INFO - Epoch 1, Train Loss: 0.2967562688877005
# 2026-03-01 22:02:41,271 - multiple_datasets_playbook - INFO - Epoch 2, Train Loss: 0.21289549477196118
# 2026-03-01 22:02:53,754 - multiple_datasets_playbook - INFO - Epoch 3, Train Loss: 0.1647357431733433
# 2026-03-01 22:03:06,156 - multiple_datasets_playbook - INFO - Epoch 4, Train Loss: 0.14774622646375343
# 2026-03-01 22:03:18,820 - multiple_datasets_playbook - INFO - Epoch 5, Train Loss: 0.14032392909674488
# 2026-03-01 22:03:31,760 - multiple_datasets_playbook - INFO - Epoch 6, Train Loss: 0.13295883859815372
# ...

# %%
cv = CrossValidationSiameseMultipleDs(
    log_level = logging.INFO,
    logger_name = 'multiple_datasets_playbook',
)

cv.perform_training_with_rank_classification_and_multiple_datasets(
    n_folds = tpp.n_folds,
    selected_datasets = 'yolo_v26', # ['mocap', 'yolo_v26', 'vitpose', 'openpose'],
    test_dataset_type = 'yolo_v26',
    diff_dataset_usage = "MIX_ALL",
    siamese_nn_type = "transformer",
    learning_rate = 1e-4,
    batch_size = 32,
    n_epochs = 50,
    embedding_size = 10,
    tsne_perplexity = 20,
    show_plot = True, 
)
# Out:
# 2026-03-01 22:35:33,079 - multiple_datasets_playbook - INFO - [Iteration 1/4]
# 2026-03-01 22:35:36,780 - multiple_datasets_playbook - INFO - Train dataset size: 3046
# 2026-03-01 22:35:36,781 - multiple_datasets_playbook - INFO - Test dataset size: 2240
# 2026-03-01 22:35:36,782 - multiple_datasets_playbook - INFO - Using device: cuda
# 2026-03-01 22:35:38,133 - multiple_datasets_playbook - INFO - Epoch 1, Train Loss: 0.2673530128474037
# 2026-03-01 22:35:39,332 - multiple_datasets_playbook - INFO - Epoch 2, Train Loss: 0.2505252788153787
# 2026-03-01 22:35:40,681 - multiple_datasets_playbook - INFO - Epoch 3, Train Loss: 0.23811358151336512
# 2026-03-01 22:35:41,938 - multiple_datasets_playbook - INFO - Epoch 4, Train Loss: 0.22910096201424798
# 2026-03-01 22:35:43,196 - multiple_datasets_playbook - INFO - Epoch 5, Train Loss: 0.21709043175602952
# 2026-03-01 22:35:44,424 - multiple_datasets_playbook - INFO - Epoch 6, Train Loss: 0.20490841971089443
# ...

# %%
# NEW

cv = CrossValidationSiameseMultipleDs(
    log_level = logging.INFO,
    logger_name = 'multiple_datasets_playbook',
)

cv.perform_training_with_rank_classification_and_multiple_datasets(
    n_folds = tpp.n_folds,
    selected_datasets = 'yolo_v26', # ['mocap', 'yolo_v26', 'vitpose', 'openpose'],
    test_dataset_type = 'yolo_v26',
    diff_dataset_usage = "MIX_ALL",
    siamese_nn_type = "transformer",
    optimizer_type = "adamw",
    learning_rate = 1e-4,
    batch_size = 32,
    n_epochs = 20,
    embedding_size = 10,
    tsne_perplexity = 20,
    show_plot = True, 
)
# Out:
# 2026-03-02 10:44:23,783 - multiple_datasets_playbook - INFO - [Iteration 1/4]
# 2026-03-02 10:44:26,705 - multiple_datasets_playbook - INFO - Train dataset size: 3046
# 2026-03-02 10:44:26,706 - multiple_datasets_playbook - INFO - Test dataset size: 2240
# 2026-03-02 10:44:26,707 - multiple_datasets_playbook - INFO - Using device: cuda
# 2026-03-02 10:44:27,976 - multiple_datasets_playbook - INFO - Epoch 1, Train Loss: 0.275675217465808
# 2026-03-02 10:44:29,311 - multiple_datasets_playbook - INFO - Epoch 2, Train Loss: 0.2599422351146738
# 2026-03-02 10:44:30,662 - multiple_datasets_playbook - INFO - Epoch 3, Train Loss: 0.23891216175009808
# 2026-03-02 10:44:31,836 - multiple_datasets_playbook - INFO - Epoch 4, Train Loss: 0.22177371801808476
# 2026-03-02 10:44:32,840 - multiple_datasets_playbook - INFO - Epoch 5, Train Loss: 0.20704133373995623
# 2026-03-02 10:44:33,899 - multiple_datasets_playbook - INFO - Epoch 6, Train Loss: 0.18501705738405386
# ...

# %%
# new

cv = CrossValidationSiameseMultipleDs(
    log_level = logging.INFO,
    logger_name = 'multiple_datasets_playbook',
)

cv.perform_training_with_rank_classification_and_multiple_datasets(
    n_folds = tpp.n_folds,
    selected_datasets = 'mocap', # ['mocap', 'yolo_v26', 'vitpose', 'openpose'],
    test_dataset_type = 'mocap',
    diff_dataset_usage = "MIX_ALL",
    siamese_nn_type = "transformer",
    optimizer_type = "adamw",
    learning_rate = 1e-4,
    batch_size = 32,
    n_epochs = 20,
    embedding_size = 10,
    tsne_perplexity = 20,
    show_plot = True, 
)
# Out:
# 2026-03-02 10:47:41,995 - multiple_datasets_playbook - INFO - [Iteration 1/4]
# 2026-03-02 10:47:45,501 - multiple_datasets_playbook - INFO - Train dataset size: 3042
# 2026-03-02 10:47:45,502 - multiple_datasets_playbook - INFO - Test dataset size: 2206
# 2026-03-02 10:47:45,503 - multiple_datasets_playbook - INFO - Using device: cuda
# 2026-03-02 10:47:47,037 - multiple_datasets_playbook - INFO - Epoch 1, Train Loss: 0.25996378048633534
# 2026-03-02 10:47:48,429 - multiple_datasets_playbook - INFO - Epoch 2, Train Loss: 0.22806976657981673
# 2026-03-02 10:47:49,903 - multiple_datasets_playbook - INFO - Epoch 3, Train Loss: 0.20685357445230088
# 2026-03-02 10:47:51,368 - multiple_datasets_playbook - INFO - Epoch 4, Train Loss: 0.18726391882713264
# 2026-03-02 10:47:52,810 - multiple_datasets_playbook - INFO - Epoch 5, Train Loss: 0.17345280976345143
# 2026-03-02 10:47:54,174 - multiple_datasets_playbook - INFO - Epoch 6, Train Loss: 0.15194229378054538
# ...

# %%
# new

cv = CrossValidationSiameseMultipleDs(
    log_level = logging.INFO,
    logger_name = 'multiple_datasets_playbook',
)

cv.perform_training_with_rank_classification_and_multiple_datasets(
    n_folds = tpp.n_folds,
    selected_datasets = 'vitpose', # ['mocap', 'yolo_v26', 'vitpose', 'openpose'],
    test_dataset_type = 'vitpose',
    diff_dataset_usage = "MIX_ALL",
    siamese_nn_type = "transformer",
    optimizer_type = "adamw",
    learning_rate = 1e-4,
    batch_size = 32,
    n_epochs = 20,
    embedding_size = 10,
    tsne_perplexity = 20,
    show_plot = True, 
)
# Out:
# 2026-03-02 10:59:33,725 - multiple_datasets_playbook - INFO - [Iteration 1/4]
# 2026-03-02 10:59:36,662 - multiple_datasets_playbook - INFO - Train dataset size: 3668
# 2026-03-02 10:59:36,663 - multiple_datasets_playbook - INFO - Test dataset size: 3458
# 2026-03-02 10:59:36,663 - multiple_datasets_playbook - INFO - Using device: cuda
# 2026-03-02 10:59:38,315 - multiple_datasets_playbook - INFO - Epoch 1, Train Loss: 0.2690158521351607
# 2026-03-02 10:59:40,039 - multiple_datasets_playbook - INFO - Epoch 2, Train Loss: 0.23082675363706506
# 2026-03-02 10:59:41,671 - multiple_datasets_playbook - INFO - Epoch 3, Train Loss: 0.2051032983738443
# 2026-03-02 10:59:43,333 - multiple_datasets_playbook - INFO - Epoch 4, Train Loss: 0.19666406032831774
# 2026-03-02 10:59:44,886 - multiple_datasets_playbook - INFO - Epoch 5, Train Loss: 0.18362494208242583
# 2026-03-02 10:59:46,551 - multiple_datasets_playbook - INFO - Epoch 6, Train Loss: 0.17209755687609962
# ...

# %%
cv = CrossValidationSiameseMultipleDs(
    log_level = logging.INFO,
    logger_name = 'multiple_datasets_playbook',
)

cv.perform_training_with_rank_classification_and_multiple_datasets(
    n_folds = tpp.n_folds,
    selected_datasets =  ['mocap', 'yolo_v26', 'vitpose', 'openpose'],
    test_dataset_type = 'yolo_v26',
    diff_dataset_usage = "MIX_ALL",
    siamese_nn_type = "transformer",
    optimizer_type = "adamw",
    learning_rate = 1e-4,
    batch_size = 32,
    n_epochs = 25,
    embedding_size = 10,
    tsne_perplexity = 20,
    show_plot = True, 
)
# Out:
# 2026-03-02 08:30:23,164 - multiple_datasets_playbook - INFO - [Iteration 1/4]
# 2026-03-02 08:30:27,252 - multiple_datasets_playbook - INFO - Train dataset size: 56576
# 2026-03-02 08:30:27,253 - multiple_datasets_playbook - INFO - Test dataset size: 2240
# 2026-03-02 08:30:27,253 - multiple_datasets_playbook - INFO - Using device: cuda
# 2026-03-02 08:30:49,754 - multiple_datasets_playbook - INFO - Epoch 1, Train Loss: 0.1952104514498449
# 2026-03-02 08:31:11,824 - multiple_datasets_playbook - INFO - Epoch 2, Train Loss: 0.14155926138828445
# 2026-03-02 08:31:34,156 - multiple_datasets_playbook - INFO - Epoch 3, Train Loss: 0.12447198955300032
# 2026-03-02 08:31:56,410 - multiple_datasets_playbook - INFO - Epoch 4, Train Loss: 0.11422111216629117
# 2026-03-02 08:32:19,304 - multiple_datasets_playbook - INFO - Epoch 5, Train Loss: 0.10763268665372651
# 2026-03-02 08:32:42,114 - multiple_datasets_playbook - INFO - Epoch 6, Train Loss: 0.10281791700033378
# ...

# %%
# NEW

cv = CrossValidationSiameseMultipleDs(
    log_level = logging.INFO,
    logger_name = 'multiple_datasets_playbook',
)

cv.perform_training_with_rank_classification_and_multiple_datasets(
    n_folds = tpp.n_folds,
    selected_datasets =  ['yolo_v26', 'vitpose', 'hrnet', 'rtmpose'],
    test_dataset_type = 'yolo_v26',
    diff_dataset_usage = "MIX_ALL",
    siamese_nn_type = "transformer",
    optimizer_type = "rmsprop",
    learning_rate = 1e-4,
    batch_size = 128,
    n_epochs = 10,
    embedding_size = 10,
    tsne_perplexity = 20,
    show_plot = True, 
)
# Out:
# 2026-03-02 09:08:05,936 - multiple_datasets_playbook - INFO - [Iteration 1/4]
# 2026-03-02 09:08:09,457 - multiple_datasets_playbook - INFO - Train dataset size: 59480
# 2026-03-02 09:08:09,458 - multiple_datasets_playbook - INFO - Test dataset size: 2240
# 2026-03-02 09:08:09,459 - multiple_datasets_playbook - INFO - Using device: cuda
# 2026-03-02 09:08:18,324 - multiple_datasets_playbook - INFO - Epoch 1, Train Loss: nan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 8
#       1 # NEW
#       3 cv = CrossValidationSiameseMultipleDs(
#       4     log_level = logging.INFO,
#       5     logger_name = 'multiple_datasets_playbook',
#       6 )
# ----> 8 cv.perform_training_with_rank_classification_and_multiple_datasets(
#       9     n_folds = tpp.n_folds,
#      10     selected_datasets =  ['yolo_v26', 'vitpose', 'hrnet', 'rtmpose'],
# ...

# %%
cv = CrossValidationSiameseMultipleDs(
    log_level = logging.INFO,
    logger_name = 'multiple_datasets_playbook',
)

cv.perform_training_with_rank_classification_and_multiple_datasets(
    n_folds = tpp.n_folds,
    selected_datasets =  ['mocap', 'yolo_v26', 'hrnet', 'rtmpose', 'vitpose', 'openpose', 'mediapipe'],
    test_dataset_type = 'yolo_v26',
    diff_dataset_usage = "DATASET_TYPE",
    siamese_nn_type = "transformer",
    optimizer_type = "adam",
    learning_rate = 1e-5,
    batch_size = 32,
    n_epochs = 25,
    embedding_size = 10,
    tsne_perplexity = 20,
    show_plot = True, 
)
# Out:
# 2026-03-02 09:10:22,988 - multiple_datasets_playbook - INFO - [Iteration 1/4]
# 2026-03-02 09:10:27,000 - multiple_datasets_playbook - INFO - Train dataset size: 24348
# 2026-03-02 09:10:27,002 - multiple_datasets_playbook - INFO - Test dataset size: 2240
# 2026-03-02 09:10:27,002 - multiple_datasets_playbook - INFO - Using device: cuda
# 2026-03-02 09:10:36,615 - multiple_datasets_playbook - INFO - Epoch 1, Train Loss: 0.28036102652549744
# 2026-03-02 09:10:46,144 - multiple_datasets_playbook - INFO - Epoch 2, Train Loss: 0.2636479644910108
# 2026-03-02 09:10:55,686 - multiple_datasets_playbook - INFO - Epoch 3, Train Loss: 0.2535240699716999
# 2026-03-02 09:11:05,393 - multiple_datasets_playbook - INFO - Epoch 4, Train Loss: 0.24474065489430621
# 2026-03-02 09:11:14,800 - multiple_datasets_playbook - INFO - Epoch 5, Train Loss: 0.2363288677083365
# 2026-03-02 09:11:24,249 - multiple_datasets_playbook - INFO - Epoch 6, Train Loss: 0.22805754530993774
# ...

# %%
# n_folds: int = 4,
# selected_datasets: Sequence[str] | str | None = None,
# test_dataset_type: str = 'yolo_v26',
# diff_dataset_usage: Literal["MIX_ALL", "SKELETON_TYPE", "DATASET_TYPE"]
# siamese_nn_type: Literal["conv1d", "lstm", "transformer", "conv1dbn"] = "conv1d",
# optimizer_type: Literal["adam", "adamw", "rmsprop"] = "adam",
# learning_rate: float = 1e-4,
# batch_size: int = 32,
# n_epochs: int = 10,
# embedding_size: int = 10,
# tsne_perplexity: int = 10,
# show_plot: bool = True,
# threshold: float = 0.5,
# csv_file_path: Path | str | None = None,
