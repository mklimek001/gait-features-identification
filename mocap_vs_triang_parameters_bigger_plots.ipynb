# %%
import pandas as pd

mocap_df = pd.read_csv('./datasets/gait_features.csv').drop(columns=['participant'])
mocap_stats = mocap_df.describe().T
mocap_stats['cv'] = mocap_stats['std'] / mocap_stats['mean'] * 100
mocap_stats
# Out:
#                                 count         mean         std          min  \
# l_mean_stride_time              152.0     1.173509    0.130922     0.946667
# r_mean_stride_time              152.0     1.176031    0.135992     0.940000
# total_mean_stride_time          152.0     1.175301    0.131941     0.960000
# l_mean_stride_dist              152.0  1400.133140  156.448341  1018.948789
# r_mean_stride_dist              152.0  1413.747790  149.816462  1070.896634
# total_mean_stride_dist          152.0  1403.732863  148.001177  1101.507206
# l_r_mean_step_times             152.0     0.601816    0.065522     0.466667
# r_l_mean_step_times             152.0     0.578443    0.081448     0.440000
# total_mean_step_times           152.0     0.591007    0.066480     0.480000
# l_r_mean_step_dist              152.0   710.085574   79.079638   489.157589
# r_l_mean_step_dist              152.0   674.549943   90.006044   471.592581
# total_mean_step_distance        152.0   690.798321   77.257705   514.947385
# l_r_mean_step_width             152.0   138.054683   83.399163    40.829947
# r_l_mean_step_width             152.0   138.414498   80.837624    33.974180
# total_mean_step_width           152.0   138.268990   81.058537    36.259436
# l_mean_max_hip_angle_diff       152.0    27.233002    5.133044    16.728521
# r_mean_max_hip_angle_diff       152.0    27.179127    4.488559    17.498564
# total_mean_max_hip_angle_diff   152.0    27.226529    4.384377    18.517060
# l_mean_max_knee_angle_diff      152.0    67.000244    6.094550    45.878611
# r_mean_max_knee_angle_diff      152.0    67.475626    5.922360    49.347294
# total_mean_max_knee_angle_diff  152.0    67.210973    4.821620    52.988749
# l_r_mean_step_l_angle           152.0    39.436288    9.787021    18.097304
# r_l_mean_step_l_angle           152.0    42.007960    9.554524    22.713661
# total_mean_step_l_angle         152.0    40.716939    8.923430    21.542897
#
#                                         25%          50%          75%  \
# l_mean_stride_time                 1.066667     1.140000     1.243333
# r_mean_stride_time                 1.080000     1.140000     1.243333
# total_mean_stride_time             1.073000     1.144000     1.240000
# l_mean_stride_dist              1299.005208  1398.389587  1486.201502
# r_mean_stride_dist              1316.573449  1424.600781  1498.970634
# total_mean_stride_dist          1302.114814  1404.788706  1483.108147
# l_r_mean_step_times                0.556667     0.600000     0.640000
# r_l_mean_step_times                0.520000     0.560000     0.630000
# total_mean_step_times              0.542143     0.576000     0.632000
# l_r_mean_step_dist               656.457642   707.239895   759.578544
# r_l_mean_step_dist               610.178935   673.310940   726.267109
# total_mean_step_distance         637.152362   689.149307   733.227745
# l_r_mean_step_width               99.678186   122.847777   148.905000
# r_l_mean_step_width               99.962704   119.142407   157.135061
# total_mean_step_width            103.198842   120.753267   152.199774
# l_mean_max_hip_angle_diff         23.307694    26.800143    29.979669
# r_mean_max_hip_angle_diff         24.037959    27.228877    29.892871
# total_mean_max_hip_angle_diff     24.630733    26.632828    29.859998
# l_mean_max_knee_angle_diff        64.299815    67.523195    70.860668
# r_mean_max_knee_angle_diff        63.805099    67.533385    72.005419
# total_mean_max_knee_angle_diff    64.677287    67.220752    70.473358
# l_r_mean_step_l_angle             31.781377    39.873197    45.424924
# r_l_mean_step_l_angle             34.798693    41.619165    48.668222
# total_mean_step_l_angle           33.735534    41.238938    46.598182
#
#                                         max         cv
# l_mean_stride_time                 1.573333  11.156486
# r_mean_stride_time                 1.613333  11.563607
# total_mean_stride_time             1.568000  11.226181
# l_mean_stride_dist              1879.577304  11.173819
# r_mean_stride_dist              1925.379027  10.597114
# total_mean_stride_dist          1910.111786  10.543400
# l_r_mean_step_times                0.800000  10.887409
# r_l_mean_step_times                0.810000  14.080621
# total_mean_step_times              0.786667  11.248640
# l_r_mean_step_dist               964.169659  11.136635
# r_l_mean_step_dist               961.209369  13.343125
# total_mean_step_distance         962.689514  11.183829
# l_r_mean_step_width              788.225474  60.410238
# r_l_mean_step_width              766.275550  58.402570
# total_mean_step_width            777.250512  58.623800
# l_mean_max_hip_angle_diff         39.993741  18.848616
# r_mean_max_hip_angle_diff         36.941140  16.514727
# total_mean_max_hip_angle_diff     38.516039  16.103328
# l_mean_max_knee_angle_diff        79.208011   9.096310
# r_mean_max_knee_angle_diff        78.899804   8.777036
# total_mean_max_knee_angle_diff    77.962278   7.173858
# l_r_mean_step_l_angle             62.207938  24.817299
# r_l_mean_step_l_angle             63.911591  22.744556
# total_mean_step_l_angle           62.582657  21.915767

# %%
triang_df = pd.read_csv('./datasets/triangulation_gait_features.csv').drop(columns=['participant'])
triang_stats = triang_df.describe().T
triang_stats['cv'] = triang_stats['std'] / triang_stats['mean'] * 100
triang_stats
# Out:
#                                 count         mean         std          min  \
# l_mean_stride_time              150.0     1.132356    0.140676     0.800000
# r_mean_stride_time              150.0     1.115067    0.169439     0.680000
# total_mean_stride_time          150.0     1.124174    0.143338     0.820000
# l_mean_stride_dist              150.0  1402.515302  166.409646   977.693739
# r_mean_stride_dist              150.0  1410.978283  154.769674  1042.761954
# total_mean_stride_dist          150.0  1403.417293  156.454225  1071.382089
# l_r_mean_step_times             150.0     0.596333    0.142839     0.213333
# r_l_mean_step_times             150.0     0.529956    0.127842     0.240000
# total_mean_step_times           150.0     0.565694    0.074979     0.413333
# l_r_mean_step_dist              150.0   692.724245   81.583642   487.619308
# r_l_mean_step_dist              150.0   691.760375   85.342479   485.321015
# total_mean_step_distance        150.0   690.990565   80.054285   511.942590
# l_r_mean_step_width             150.0   137.664356   88.111062    16.119532
# r_l_mean_step_width             150.0   137.760205   89.556318    44.586515
# total_mean_step_width           150.0   137.232071   85.443213    46.130655
# l_mean_max_hip_angle_diff       150.0    18.852402    2.477463    14.106125
# r_mean_max_hip_angle_diff       150.0    19.584865    3.030220    13.263213
# total_mean_max_hip_angle_diff   150.0    19.197140    2.545405    14.357377
# l_mean_max_knee_angle_diff      150.0    53.673945    4.784783    43.531619
# r_mean_max_knee_angle_diff      150.0    53.831880    4.684332    44.707091
# total_mean_max_knee_angle_diff  150.0    53.715243    4.044870    45.070311
# l_r_mean_step_l_angle           150.0    19.468365    6.593001     2.978736
# r_l_mean_step_l_angle           150.0    27.393966    5.969676     7.026837
# total_mean_step_l_angle         150.0    23.409835    4.342843    13.494645
#
#                                         25%          50%          75%  \
# l_mean_stride_time                 1.040000     1.100000     1.225000
# r_mean_stride_time                 1.000000     1.080000     1.225000
# total_mean_stride_time             1.027500     1.100000     1.215333
# l_mean_stride_dist              1299.172865  1392.533801  1499.013797
# r_mean_stride_dist              1303.231904  1411.909094  1493.487657
# total_mean_stride_dist          1307.687944  1401.870815  1499.382765
# l_r_mean_step_times                0.500000     0.586667     0.680000
# r_l_mean_step_times                0.440000     0.526667     0.607500
# total_mean_step_times              0.520000     0.550000     0.606667
# l_r_mean_step_dist               639.846558   694.958162   739.305775
# r_l_mean_step_dist               631.946441   693.282804   741.068273
# total_mean_step_distance         638.680092   691.700178   739.314635
# l_r_mean_step_width               95.656591   122.986745   147.766061
# r_l_mean_step_width               99.346901   120.481321   146.923823
# total_mean_step_width             99.846546   122.279024   146.612359
# l_mean_max_hip_angle_diff         17.102673    18.797620    20.580774
# r_mean_max_hip_angle_diff         17.584722    19.497320    21.899336
# total_mean_max_hip_angle_diff     17.474385    19.172820    21.120786
# l_mean_max_knee_angle_diff        50.452224    53.455942    56.152083
# r_mean_max_knee_angle_diff        50.140173    53.294566    57.078932
# total_mean_max_knee_angle_diff    51.052656    53.512839    56.151808
# l_r_mean_step_l_angle             15.475151    19.136753    23.873131
# r_l_mean_step_l_angle             23.566583    27.232799    31.470872
# total_mean_step_l_angle           20.177494    23.325881    26.274517
#
#                                         max         cv
# l_mean_stride_time                 1.560000  12.423276
# r_mean_stride_time                 1.680000  15.195415
# total_mean_stride_time             1.620000  12.750520
# l_mean_stride_dist              1920.981704  11.865086
# r_mean_stride_dist              1903.704899  10.968962
# total_mean_stride_dist          1900.943491  11.148090
# l_r_mean_step_times                0.920000  23.952946
# r_l_mean_step_times                0.910000  24.123188
# total_mean_step_times              0.820000  13.254409
# l_r_mean_step_dist               970.634601  11.777218
# r_l_mean_step_dist               942.999775  12.337000
# total_mean_step_distance         945.462192  11.585438
# l_r_mean_step_width              736.483710  64.004267
# r_l_mean_step_width              919.033564  65.008845
# total_mean_step_width            809.503652  62.261841
# l_mean_max_hip_angle_diff         26.174424  13.141366
# r_mean_max_hip_angle_diff         26.530026  15.472253
# total_mean_max_hip_angle_diff     26.124015  13.259294
# l_mean_max_knee_angle_diff        70.090100   8.914536
# r_mean_max_knee_angle_diff        67.375511   8.701781
# total_mean_max_knee_angle_diff    68.382464   7.530210
# l_r_mean_step_l_angle             36.575253  33.865199
# r_l_mean_step_l_angle             43.459315  21.791936
# total_mean_step_l_angle           34.816954  18.551360

# %%
triang_stats.loc['total_mean_step_l_angle']['mean']
# Out:
# 23.409834630917146

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import numpy as np

titles = [
    "Time based features mean value comparison (seconds)", 
    "Distance based features mean value comparison (millimeters)", 
    "Angle based features mean value comparison (degrees)", 
]

categories = [['Mean stride time\nacross sequences (s)', 'Mean step time\nacross sequences (s)'],
              ['Mean stride length\nacross sequences (mm)', 'Mean step length\nacross sequences (mm)', 'Mean step width\nacross sequences (mm)'],
              ['Mean maximum\nknee angle difference\nduring step\nacross sequences (deg)', 
               'Mean maximum\nhip angle difference\nduring step\nacross sequences (deg)', 
               'Mean maximum\nleg angle observed\nduring step\nacross sequences (deg)']]

mocap_val = [
   [mocap_stats.loc['total_mean_stride_time']['mean'],
   mocap_stats.loc['total_mean_step_times']['mean']],

   [mocap_stats.loc['total_mean_stride_dist']['mean'],
   mocap_stats.loc['total_mean_step_distance']['mean'],
   mocap_stats.loc['total_mean_step_width']['mean']],

   [mocap_stats.loc['total_mean_max_knee_angle_diff']['mean'],
   mocap_stats.loc['total_mean_max_hip_angle_diff']['mean'],
   mocap_stats.loc['total_mean_step_l_angle']['mean']],
  ]

triang_val = [
   [triang_stats.loc['total_mean_stride_time']['mean'],
   triang_stats.loc['total_mean_step_times']['mean']],

   [triang_stats.loc['total_mean_stride_dist']['mean'],
   triang_stats.loc['total_mean_step_distance']['mean'],
   triang_stats.loc['total_mean_step_width']['mean']],

   [triang_stats.loc['total_mean_max_knee_angle_diff']['mean'],
   triang_stats.loc['total_mean_max_hip_angle_diff']['mean'],
   triang_stats.loc['total_mean_step_l_angle']['mean']],
  ]

n_subplots = 3
bar_height = 0.35

fig = plt.figure(figsize=(7, 10))
gs = gridspec.GridSpec(n_subplots, 1, height_ratios=[2, 3, 3]) 
axs = [fig.add_subplot(gs[i]) for i in range(3)]

    
for i in range(n_subplots):
    ax = axs[i]
    index = np.arange(len(categories[i]))
    ax.set_xlim(0, 1.25 * max(mocap_val[i]))
    
    bars1 = ax.barh(index + bar_height/2, mocap_val[i], height=bar_height, label='Motion capture', color='sienna')
    bars2 = ax.barh(index - bar_height/2, triang_val[i], height=bar_height, label='Triangulation', color='olivedrab')

    ax.grid(True, axis='x', linestyle='--', alpha=0.6)
    ax.set_yticks(index)
    ax.set_yticklabels(categories[i])

    for bar in bars1:
        width = bar.get_width()
        ax.text(width + 0.01 * max(mocap_val[i]), bar.get_y() + bar.get_height()/2, f'{width:.2f}', va='center', fontsize=12)
    for bar in bars2:
        width = bar.get_width()
        ax.text(width +  0.01 * max(mocap_val[i]), bar.get_y() + bar.get_height()/2, f'{width:.2f}', va='center', fontsize=12)


    ax.set_title(titles[i])
    ax.legend()

plt.tight_layout()
plt.savefig('./plots/gait_features_mean_2.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import numpy as np

titles = [
    "Time based features coefficient of variation comparison (%)           ", 
    "Distance based features coefficient of variation comparison (%)                ", 
    "Angle based features coefficient of variation comparison (%)            ", 
]

categories = [['Coefficient of variation\nof mean stride time\nacross sequences (%)', 
               'Coefficient of variation\nof mean step time\nacross sequences (%)'],
              
              ['Coefficient of variation\nof mean stride length\nacross sequences (%)', 
               'Coefficient of variation\nof mean step length\nacross sequences (%)',
               'Coefficient of variation\nof mean step width\nacross sequences (%)'],
              
              ['Coefficient of variation\nof mean maximum knee angle\ndifference during step\nacross sequences (%)',
               'Coefficient of variation\nof mean maximum hip angle\ndifference during step\nacross sequences (%)',
               'Coefficient of variation\nof mean maximum leg angle\nobserved during step\nacross sequences (%)']]


mocap_val = [
    [mocap_stats.loc['total_mean_stride_time']['cv'],
    mocap_stats.loc['total_mean_step_times']['cv']],
    
    [mocap_stats.loc['total_mean_stride_dist']['cv'],
    mocap_stats.loc['total_mean_step_distance']['cv'],
    mocap_stats.loc['total_mean_step_width']['cv']],
    
    [mocap_stats.loc['total_mean_max_knee_angle_diff']['cv'],
    mocap_stats.loc['total_mean_max_hip_angle_diff']['cv'],
    mocap_stats.loc['total_mean_step_l_angle']['cv']],
    ]

triang_val = [
    [triang_stats.loc['total_mean_stride_time']['cv'],
    triang_stats.loc['total_mean_step_times']['cv']],
    
    [triang_stats.loc['total_mean_stride_dist']['cv'],
    triang_stats.loc['total_mean_step_distance']['cv'],
    triang_stats.loc['total_mean_step_width']['cv']],
    
    [triang_stats.loc['total_mean_max_knee_angle_diff']['cv'],
    triang_stats.loc['total_mean_max_hip_angle_diff']['cv'],
    triang_stats.loc['total_mean_step_l_angle']['cv']],
    ]

n_subplots = 3
bar_height = 0.35

fig = plt.figure(figsize=(7, 10))
gs = gridspec.GridSpec(n_subplots, 1, height_ratios=[2, 3, 3]) 
axs = [fig.add_subplot(gs[i]) for i in range(3)]

    
for i in range(n_subplots):
    ax = axs[i]
    index = np.arange(len(categories[i]))
    ax.set_xlim(0, 71)
    
    bars1 = ax.barh(index + bar_height/2, mocap_val[i], height=bar_height, label='Motion capture', color='sienna')
    bars2 = ax.barh(index - bar_height/2, triang_val[i], height=bar_height, label='Triangulation', color='olivedrab')

    ax.grid(True, axis='x', linestyle='--', alpha=0.6)
    ax.set_yticks(index)
    ax.set_yticklabels(categories[i])

    for bar in bars1:
        width = bar.get_width()
        ax.text(width + 0.01 * max(mocap_val[i]), bar.get_y() + bar.get_height()/2, f'{width:.2f}', va='center', fontsize=12)
    for bar in bars2:
        width = bar.get_width()
        ax.text(width +  0.01 * max(mocap_val[i]), bar.get_y() + bar.get_height()/2, f'{width:.2f}', va='center', fontsize=12)


    ax.set_title(titles[i])
    ax.legend()

plt.tight_layout()
plt.savefig('./plots/gait_features_cv_2.png')
plt.show()
