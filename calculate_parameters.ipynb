# %%
import json
from utils.gait_parameters_extractor_raw import (
    GaitParametersExtractorRaw,
    CoordinatesIdx,
)

datasets = {
    "mocap": "datasets/mocap/dataset_v3.json",
    
    "openpose": "datasets/openpose/dataset_openpose_triangulated_v2.json",
    
    "mediapipe" : "datasets/mediapipe/dataset_v4_triangulated.json",
    
    "hrnet": "datasets/mmpose/dataset_hrnet_triangulated.json",
    "rtmpose": "datasets/mmpose/dataset_rtmpose_triangulated.json",
    "vitpose": "datasets/mmpose/dataset_vitpose_triangulated.json",
    
    "movenet_lightning": "datasets/movenet/dataset_lightning_triangulated.json",
    "movenet_thunder": "datasets/movenet/dataset_thunder_triangulated.json",

    "yolo_v26": "datasets/yolo/dataset_v3_yolo26.json",
    # "yolo_v11": "datasets/yolo/dataset_v2.json",
    "yolo_v11": "datasets/yolo/dataset_v2_triangulated_v3.json",
}

def calculate_parameters_for_estimator(dataset_name: str):
    with open(datasets[dataset_name], 'r') as file:
        dataset_triang = json.load(file)
        
    combined_estimator_parameters = {}

    if dataset_name != "mocap":
        coordinates_idx=CoordinatesIdx()
    else:
        coordinates_idx=CoordinatesIdx(2, 0, 1)
    
    for sequence_key, sequence_joint_positions in dataset_triang.items():
        if sequence_joint_positions:
            print(f"| {sequence_key}", end = " ")
            gpe_raw = GaitParametersExtractorRaw(
                sequence_joint_positions, coordinates_idx=coordinates_idx
            )
            parameters_value = gpe_raw.get_gait_parameters()
            parameters_names = gpe_raw.get_gait_parameters_names()
        
            combined_estimator_parameters[sequence_key] = {name: values.tolist() for name, values in zip(parameters_names, parameters_value)}

    destination_file = datasets[dataset_name].replace('dataset_', 'calculated_parameters_')
    with open(destination_file, 'w') as f:
        json.dump(combined_estimator_parameters, f, indent=4)

# %%
for dataset in datasets.keys():
    print(dataset)
    calculate_parameters_for_estimator(dataset)
# Out:
# mocap
# | p1s1 | p1s2 | p1s3 | p1s4 | p2s1 | p2s2 | p2s3 | p2s4 | p3s1 | p3s2 | p3s3 | p3s4 | p4s1 | p4s2 | p4s3 | p4s4 | p5s1 | p5s2 | p5s3 | p5s4 | p6s1 | p6s2 | p6s3 | p6s4 | p7s1 | p7s2 | p7s3 | p7s4 | p8s1 | p8s2 | p8s3 | p8s4 | p9s1 | p9s2 | p9s3 | p9s4 | p10s1 | p10s2 | p10s3 | p10s4 | p11s1 | p11s2 | p11s3 | p11s4 | p12s1 | p12s2 | p12s3 | p12s4 | p13s1 | p13s2 | p13s3 | p13s4 | p14s1 | p14s2 | p14s3 | p14s4 | p15s1 | p15s2 | p15s3 | p15s4 | p16s1 | p16s2 | p16s3 | p16s4 | p17s1 | p17s2 | p17s3 | p17s4 | p18s1 | p18s2 | p18s3 | p18s4 | p19s1 | p19s2 | p19s3 | p19s4 | p20s1 | p20s2 | p20s3 | p20s4 | p21s1 | p21s2 | p21s3 | p21s4 | p22s1 | p22s2 | p22s3 | p22s4 | p23s1 | p23s2 | p23s3 | p23s4
26s8 | p27s1 | p27s2 | p27s3 | p27s4 | p27s5 | p27s6 | p27s7 | p27s8 | p28s1 | p28s2 | p28s3 | p28s4 | p28s5 | p28s6 | p28s7 | p28s8 | p29s1 | p29s2 | p29s3 | p29s4 | p29s5 | p29s6 | p29s7 | p29s8 | p30s1 | p30s2 | p30s3 | p30s4 | p30s5 | p30s6 | p30s7 | p30s8 | p31s1 | p31s2 | p31s3 | p31s4 | p31s5 | p31s6 | p31s7 | p31s8 | p32s1 | p32s2 | p32s3 | p32s4

# %%
calculate_parameters_for_estimator("mediapipe")
# Out:
# | p1s1 | p1s2 | p1s3 | p1s4 | p2s1 | p2s2 | p2s3 | p2s4 | p3s1 | p3s2 | p3s3 | p3s4 | p4s1 | p4s2 | p4s3 | p4s4 | p5s1 | p5s2 | p5s3 | p5s4 | p6s1 | p6s2 | p6s3 | p6s4 | p7s1 | p7s2 | p7s3 | p7s4 | p8s1 | p8s2 | p8s3 | p8s4 | p9s1 | p9s2 | p9s3 | p9s4 | p10s1 | p10s2 | p10s3 | p10s4 | p11s1 | p11s2 | p11s3 | p11s4 | p12s1 | p12s2 | p12s3 | p12s4 | p13s1 | p13s2 | p13s3 | p13s4 | p14s1 | p14s2 | p14s3 | p14s4 | p15s1 | p15s2 | p15s3 | p15s4 | p16s1 | p16s2 | p16s3 | p16s4 | p17s1 | p17s2 | p17s3 | p17s4 | p18s1 | p18s2 | p18s3 | p18s4 | p19s1 | p19s2 | p19s3 | p19s4 | p20s1 | p20s2 | p20s3 | p20s4 | p21s1 | p21s2 | p21s3 | p21s4 | p22s1 | p22s2 | p22s3 | p22s4 | p23s1 | p23s2 | p23s3 | p23s4 | p24s1 | p24s2 | p24s3 | p24s4 | p25s1 | p25s2 | p25s3 | p25s4 | p26s1 | p26s2 | p26s3 | p26s4 | p26s5 | p26s6 | p26s7 | p26s8 | p26s9 | p26s10 | p27s1 | p27s2 | p27s3 | p27s4 | p27s5 | p27s6 | p27s7 | p27s8 | p27s9 | p27s10 | p28s1 | p28s2 | p28s3 | p28s4 | p28s5 | p28s6 | p28s7 | p28s8 | p28s9 | p28s10 | p29s1 | p29s2 | p29s3 | p29s4 | p29s5 | p29s6 | p29s7 | p29s8 | p29s9 | p29s10 | p30s1 | p30s2 | p30s3 | p30s4 | p30s5 | p30s6 | p30s7 | p30s8 | p30s9 | p30s10 | p31s1 | p31s2 | p31s3 | p31s4 | p31s5 | p31s6 | p31s7 | p31s8 | p31s9 | p31s10 | p32s1 | p32s2 | p32s3 | p32s4 | p32s9 | p32s10

# %%
datasets_parameters = {
 'mocap': 'datasets/mocap/calculated_parameters_v3.json',
    
 'openpose': 'datasets/openpose/calculated_parameters_openpose_triangulated_v2.json',
    
 'mediapipe': 'datasets/mediapipe/calculated_parameters_v4_triangulated.json',
    
 'hrnet': 'datasets/mmpose/calculated_parameters_hrnet_triangulated.json',
 'rtmpose': 'datasets/mmpose/calculated_parameters_rtmpose_triangulated.json',
 'vitpose': 'datasets/mmpose/calculated_parameters_vitpose_triangulated.json',
    
 'movenet_lightning': 'datasets/movenet/calculated_parameters_lightning_triangulated.json',
 'movenet_thunder': 'datasets/movenet/calculated_parameters_thunder_triangulated.json',
    
 'yolo_v26': 'datasets/yolo/calculated_parameters_v3_yolo26.json',
 'yolo_v11': 'datasets/yolo/calculated_parameters_v2_triangulated_v3.json'
}

parameter_names = ['legs_angles', 'left_knee_angles', 'right_knee_angles', 'left_hip_angles', 'right_hip_angles', 
                   'left_humerus_angles', 'right_humerus_angles', 'left_elbow_angles', 'right_elbow_angles', 
                   'ankle_distances', 'knee_distances', 'elbow_distances', 'hand_distances', 
                   'center_of_gravity_height_change', 'lateral_pelvic_tilt', 'pelvis_rotation']

# %%
import json

with open(datasets_parameters['mocap'], 'r') as file:
    mocap_parameters = json.load(file) 

mocap_parameters['p1s1'].keys()
# Out:
# dict_keys(['legs_angles', 'left_knee_angles', 'right_knee_angles', 'left_hip_angles', 'right_hip_angles', 'left_humerus_angles', 'right_humerus_angles', 'left_elbow_angles', 'right_elbow_angles', 'ankle_distances', 'knee_distances', 'elbow_distances', 'hand_distances', 'center_of_gravity_height_change', 'lateral_pelvic_tilt', 'pelvis_rotation'])

# %%
param_ds_to_compare = list(datasets_parameters.keys())[1:]
param_ds_to_compare
# Out:
# ['openpose',
#  'mediapipe',
#  'hrnet',
#  'rtmpose',
#  'vitpose',
#  'movenet_lightning',
#  'movenet_thunder',
#  'yolo_v26',
#  'yolo_v11']

# %%
import numpy as np

errors = {aprox_type: {parameter: np.array([]) for parameter in parameter_names} for aprox_type in param_ds_to_compare}
mean_errors = {aprox_type: {} for aprox_type in param_ds_to_compare}

for aprox_type in param_ds_to_compare:
    print(f"  {aprox_type}")
    with open(datasets_parameters[aprox_type], 'r') as file:
        triang_parameters = json.load(file)

    sequences = [seq_key for seq_key in triang_parameters.keys() if seq_key in mocap_parameters.keys()]
        
    for i, sequence_key in enumerate(sequences):
        for parameter in parameter_names:
            absolute_error = abs(np.array(mocap_parameters[sequence_key][parameter]) - np.array(triang_parameters[sequence_key][parameter]))
            errors[aprox_type][parameter] = np.concatenate((errors[aprox_type][parameter], absolute_error))
            

for aprox_type in param_ds_to_compare:
    for parameter in parameter_names:
        mean_error = np.mean(errors[aprox_type][parameter])
        mean_errors[aprox_type][parameter] = mean_error

mean_errors
# Out:
#   openpose
#   mediapipe
#   hrnet
#   rtmpose
#   vitpose
#   movenet_lightning
#   movenet_thunder
#   yolo_v26
#   yolo_v11
# {'openpose': {'legs_angles': 7.482908398213542,
#   'left_knee_angles': 8.825693478515815,
#   'right_knee_angles': 8.25793754176523,
#   'left_hip_angles': 6.025418641829752,
#   'right_hip_angles': 5.469229112038135,
#   'left_humerus_angles': 6.028431549631182,
#   'right_humerus_angles': 5.817358554326681,
#   'left_elbow_angles': 11.805083760321187,
#   'right_elbow_angles': 11.872740863501118,
#   'ankle_distances': 59.01997615315692,
#   'knee_distances': 62.34441883989168,
#   'elbow_distances': 31.425640562507947,
#   'hand_distances': 66.24210293583185,
#   'center_of_gravity_height_change': 3.8649654695484603,
#   'lateral_pelvic_tilt': 4.208058593445238,
#   'pelvis_rotation': 6.282549412877565},
#  'mediapipe': {'legs_angles': 9.93727123190809,
#   'left_knee_angles': 10.666721398719401,
#   'right_knee_angles': 9.651829636581471,
#   'left_hip_angles': 7.072136490137325,
#   'right_hip_angles': 6.708586077794295,
#   'left_humerus_angles': 5.975547720673452,
#   'right_humerus_angles': 6.80977668143736,
#   'left_elbow_angles': 12.262537874677816,
#   'right_elbow_angles': 13.14565676210102,
#   'ankle_distances': 99.4129366858254,
#   'knee_distances': 91.03805470304992,
#   'elbow_distances': 54.77690485980958,
#   'hand_distances': 69.745357538178,
#   'center_of_gravity_height_change': 4.663936890661315,
#   'lateral_pelvic_tilt': 5.970007409763157,
#   'pelvis_rotation': 8.295084357763567},
#  'hrnet': {'legs_angles': 7.085749961564451,
#   'left_knee_angles': 8.517990909129546,
#   'right_knee_angles': 7.93614572815701,
#   'left_hip_angles': 5.7677799890349695,
#   'right_hip_angles': 5.339572680816426,
#   'left_humerus_angles': 5.974870568916002,
#   'right_humerus_angles': 5.812169223550764,
#   'left_elbow_angles': 11.796216227369538,
#   'right_elbow_angles': 11.753603673658493,
#   'ankle_distances': 57.486562726331,
#   'knee_distances': 59.314238494081685,
#   'elbow_distances': 24.417800203800994,
#   'hand_distances': 52.119921979493505,
#   'center_of_gravity_height_change': 3.953767765220469,
#   'lateral_pelvic_tilt': 4.068907201766258,
#   'pelvis_rotation': 5.3048237014223245},
#  'rtmpose': {'legs_angles': 6.662238644777505,
#   'left_knee_angles': 8.33774912838803,
#   'right_knee_angles': 7.694055095725296,
#   'left_hip_angles': 5.804582700478565,
#   'right_hip_angles': 5.366058707825573,
#   'left_humerus_angles': 5.872998597079543,
#   'right_humerus_angles': 5.784335063689099,
#   'left_elbow_angles': 11.69976900128774,
#   'right_elbow_angles': 11.593776361203052,
#   'ankle_distances': 35.19076331206279,
#   'knee_distances': 54.31344754022294,
#   'elbow_distances': 25.783711665499673,
#   'hand_distances': 58.734161655897765,
#   'center_of_gravity_height_change': 2.653228791561553,
#   'lateral_pelvic_tilt': 4.160564856077867,
#   'pelvis_rotation': 5.969763455350626},
#  'vitpose': {'legs_angles': 6.486919887103442,
#   'left_knee_angles': 8.029738977294974,
#   'right_knee_angles': 7.373087735692782,
#   'left_hip_angles': 5.495918877662661,
#   'right_hip_angles': 5.133568454875923,
#   'left_humerus_angles': 5.924660972193082,
#   'right_humerus_angles': 5.906064398857513,
#   'left_elbow_angles': 11.303970790228862,
#   'right_elbow_angles': 11.384516576386844,
#   'ankle_distances': 47.262720631951815,
#   'knee_distances': 56.070237532645805,
#   'elbow_distances': 25.31445353017896,
#   'hand_distances': 53.00606305757258,
#   'center_of_gravity_height_change': 3.297013751975222,
#   'lateral_pelvic_tilt': 3.8341232235281577,
#   'pelvis_rotation': 5.250980740616536},
#  'movenet_lightning': {'legs_angles': 21.060445530342474,
#   'left_knee_angles': 18.43710344058658,
#   'right_knee_angles': 17.39086544055225,
#   'left_hip_angles': 10.228391018286466,
#   'right_hip_angles': 9.931837147726897,
#   'left_humerus_angles': 10.269687992556152,
#   'right_humerus_angles': 11.090226611233781,
#   'left_elbow_angles': 23.566664785560874,
#   'right_elbow_angles': 25.136852312587674,
#   'ankle_distances': 826.2246439306924,
#   'knee_distances': 642.1045956904678,
#   'elbow_distances': 952.4789744839126,
#   'hand_distances': 2026.4048735596991,
#   'center_of_gravity_height_change': 88.51811479423897,
#   'lateral_pelvic_tilt': 67.12111383354018,
#   'pelvis_rotation': 38.614582943991905},
#  'movenet_thunder': {'legs_angles': 18.0483199316053,
#   'left_knee_angles': 16.671480144744244,
#   'right_knee_angles': 15.775672922943604,
#   'left_hip_angles': 9.234965128891119,
#   'right_hip_angles': 8.967754526817789,
#   'left_humerus_angles': 8.649167059649304,
#   'right_humerus_angles': 8.528832054533662,
#   'left_elbow_angles': 21.72586966999759,
#   'right_elbow_angles': 18.146351612992092,
#   'ankle_distances': 6887.571065089494,
#   'knee_distances': 600.7510374236621,
#   'elbow_distances': 239.50608018689374,
#   'hand_distances': 357.3468413992883,
#   'center_of_gravity_height_change': 31.412729528724167,
#   'lateral_pelvic_tilt': 39.75082334332577,
#   'pelvis_rotation': 31.18034629523011},
#  'yolo_v26': {'legs_angles': 7.131596579930942,
#   'left_knee_angles': 8.846658604694728,
#   'right_knee_angles': 8.169165143901964,
#   'left_hip_angles': 5.882894712544539,
#   'right_hip_angles': 5.406668933449908,
#   'left_humerus_angles': 5.8292408657307595,
#   'right_humerus_angles': 5.9188580531045885,
#   'left_elbow_angles': 11.017115534507983,
#   'right_elbow_angles': 10.662465348719897,
#   'ankle_distances': 36.56344922818295,
#   'knee_distances': 55.439041315717375,
#   'elbow_distances': 27.42953571219475,
#   'hand_distances': 48.168960368362576,
#   'center_of_gravity_height_change': 3.0604953672311033,
#   'lateral_pelvic_tilt': 4.3576446385275975,
#   'pelvis_rotation': 5.0688044492577236},
#  'yolo_v11': {'legs_angles': 9.37433214578509,
#   'left_knee_angles': 10.864775918009775,
#   'right_knee_angles': 10.189684645915351,
#   'left_hip_angles': 6.497506463871885,
#   'right_hip_angles': 5.968211940008227,
#   'left_humerus_angles': 5.3776184509850395,
#   'right_humerus_angles': 4.974998987588615,
#   'left_elbow_angles': 11.164179411422364,
#   'right_elbow_angles': 10.619841366226767,
#   'ankle_distances': 43.37744214728037,
#   'knee_distances': 63.33600554147808,
#   'elbow_distances': 25.99344041483929,
#   'hand_distances': 50.31612309988475,
#   'center_of_gravity_height_change': 3.1384169177420014,
#   'lateral_pelvic_tilt': 4.36672078017018,
#   'pelvis_rotation': 5.231546729238216}}

# %%
for estimator in ['parameter'] + param_ds_to_compare:
    print("\\textbf{", estimator.replace('_', ''), "}", end="  &  ")
print("\\\\")

for parameter in parameter_names:
    print("\\textbf{", parameter.replace('_', ' '), "}", end=" & ")
    for estimator in param_ds_to_compare:
        print(round(mean_errors[estimator][parameter], 2), end="   &   ")
    print("\\\\")
# Out:
# \textbf{ parameter }  &  \textbf{ openpose }  &  \textbf{ mediapipe }  &  \textbf{ hrnet }  &  \textbf{ rtmpose }  &  \textbf{ vitpose }  &  \textbf{ movenetlightning }  &  \textbf{ movenetthunder }  &  \textbf{ yolov26 }  &  \textbf{ yolov11 }  &  \\
# \textbf{ legs angles } & 7.48   &   9.94   &   7.09   &   6.66   &   6.49   &   21.06   &   18.05   &   7.13   &   9.37   &   \\
# \textbf{ left knee angles } & 8.83   &   10.67   &   8.52   &   8.34   &   8.03   &   18.44   &   16.67   &   8.85   &   10.86   &   \\
# \textbf{ right knee angles } & 8.26   &   9.65   &   7.94   &   7.69   &   7.37   &   17.39   &   15.78   &   8.17   &   10.19   &   \\
# \textbf{ left hip angles } & 6.03   &   7.07   &   5.77   &   5.8   &   5.5   &   10.23   &   9.23   &   5.88   &   6.5   &   \\
# \textbf{ right hip angles } & 5.47   &   6.71   &   5.34   &   5.37   &   5.13   &   9.93   &   8.97   &   5.41   &   5.97   &   \\
# \textbf{ left humerus angles } & 6.03   &   5.98   &   5.97   &   5.87   &   5.92   &   10.27   &   8.65   &   5.83   &   5.38   &   \\
# \textbf{ right humerus angles } & 5.82   &   6.81   &   5.81   &   5.78   &   5.91   &   11.09   &   8.53   &   5.92   &   4.97   &   \\
# \textbf{ left elbow angles } & 11.81   &   12.26   &   11.8   &   11.7   &   11.3   &   23.57   &   21.73   &   11.02   &   11.16   &   \\
# \textbf{ right elbow angles } & 11.87   &   13.15   &   11.75   &   11.59   &   11.38   &   25.14   &   18.15   &   10.66   &   10.62   &   \\
# \textbf{ ankle distances } & 59.02   &   99.41   &   57.49   &   35.19   &   47.26   &   826.22   &   6887.57   &   36.56   &   43.38   &   \\
# \textbf{ knee distances } & 62.34   &   91.04   &   59.31   &   54.31   &   56.07   &   642.1   &   600.75   &   55.44   &   63.34   &   \\
# \textbf{ elbow distances } & 31.43   &   54.78   &   24.42   &   25.78   &   25.31   &   952.48   &   239.51   &   27.43   &   25.99   &   \\
# \textbf{ hand distances } & 66.24   &   69.75   &   52.12   &   58.73   &   53.01   &   2026.4   &   357.35   &   48.17   &   50.32   &   \\
# \textbf{ center of gravity height change } & 3.86   &   4.66   &   3.95   &   2.65   &   3.3   &   88.52   &   31.41   &   3.06   &   3.14   &   \\
# \textbf{ lateral pelvic tilt } & 4.21   &   5.97   &   4.07   &   4.16   &   3.83   &   67.12   &   39.75   &   4.36   &   4.37   &   \\
# \textbf{ pelvis rotation } & 6.28   &   8.3   &   5.3   &   5.97   &   5.25   &   38.61   &   31.18   &   5.07   &   5.23   &   \\

# %%
angle_parameters = [parameter for parameter in parameter_names if 'angles' in parameter] + ['pelvis_rotation', 'lateral_pelvic_tilt']

for parameter in angle_parameters:
    print("\\textbf{", parameter.replace('_', ' '), "}", end=" & ")
    for estimator in param_ds_to_compare:
        print(round(mean_errors[estimator][parameter], 2), end="   &   ")
    print("\\\\")
# Out:
# \textbf{ legs angles } & 7.48   &   9.94   &   7.09   &   6.66   &   6.49   &   21.06   &   18.05   &   7.13   &   9.37   &   \\
# \textbf{ left knee angles } & 8.83   &   10.67   &   8.52   &   8.34   &   8.03   &   18.44   &   16.67   &   8.85   &   10.86   &   \\
# \textbf{ right knee angles } & 8.26   &   9.65   &   7.94   &   7.69   &   7.37   &   17.39   &   15.78   &   8.17   &   10.19   &   \\
# \textbf{ left hip angles } & 6.03   &   7.07   &   5.77   &   5.8   &   5.5   &   10.23   &   9.23   &   5.88   &   6.5   &   \\
# \textbf{ right hip angles } & 5.47   &   6.71   &   5.34   &   5.37   &   5.13   &   9.93   &   8.97   &   5.41   &   5.97   &   \\
# \textbf{ left humerus angles } & 6.03   &   5.98   &   5.97   &   5.87   &   5.92   &   10.27   &   8.65   &   5.83   &   5.38   &   \\
# \textbf{ right humerus angles } & 5.82   &   6.81   &   5.81   &   5.78   &   5.91   &   11.09   &   8.53   &   5.92   &   4.97   &   \\
# \textbf{ left elbow angles } & 11.81   &   12.26   &   11.8   &   11.7   &   11.3   &   23.57   &   21.73   &   11.02   &   11.16   &   \\
# \textbf{ right elbow angles } & 11.87   &   13.15   &   11.75   &   11.59   &   11.38   &   25.14   &   18.15   &   10.66   &   10.62   &   \\
# \textbf{ pelvis rotation } & 6.28   &   8.3   &   5.3   &   5.97   &   5.25   &   38.61   &   31.18   &   5.07   &   5.23   &   \\
# \textbf{ lateral pelvic tilt } & 4.21   &   5.97   &   4.07   &   4.16   &   3.83   &   67.12   &   39.75   &   4.36   &   4.37   &   \\

# %%
distance_parameter = [parameter for parameter in parameter_names if parameter not in angle_parameters]

for parameter in distance_parameter:
    print("\\textbf{", parameter.replace('_', ' '), "}", end=" & ")
    for estimator in param_ds_to_compare:
        print(round(mean_errors[estimator][parameter], 2), end="   &   ")
    print("\\\\")
# Out:
# \textbf{ ankle distances } & 59.02   &   99.41   &   57.49   &   35.19   &   47.26   &   826.22   &   6887.57   &   36.56   &   43.38   &   \\
# \textbf{ knee distances } & 62.34   &   91.04   &   59.31   &   54.31   &   56.07   &   642.1   &   600.75   &   55.44   &   63.34   &   \\
# \textbf{ elbow distances } & 31.43   &   54.78   &   24.42   &   25.78   &   25.31   &   952.48   &   239.51   &   27.43   &   25.99   &   \\
# \textbf{ hand distances } & 66.24   &   69.75   &   52.12   &   58.73   &   53.01   &   2026.4   &   357.35   &   48.17   &   50.32   &   \\
# \textbf{ center of gravity height change } & 3.86   &   4.66   &   3.95   &   2.65   &   3.3   &   88.52   &   31.41   &   3.06   &   3.14   &   \\
