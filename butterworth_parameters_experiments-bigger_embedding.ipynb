# %%
import json
import logging
from utils.steps_sepatation import separate_gait_sequences_to_cycles
from utils.gait_parameters_extractor import CoordinatesIdx
from utils.cross_validation_siamese_raw import CrossValidationSiameseRaw

triang_data_file = "./datasets/yolo/dataset_v3_yolo26.json"

with open(triang_data_file, 'r') as file:
    triangulation_data = json.load(file)

# %%
results_base = separate_gait_sequences_to_cycles(triangulation_data, 
                                            window_size=32, 
                                            minima_window_size=10, 
                                            smooth_butterworth=True, 
                                            # butterworth filter parameters
                                            cutoff_frequency = 0.625, 
                                            order = 2,
                                            fs = 25,
                                           )


cv = CrossValidationSiameseRaw(
    sequence_cycles = results_base, 
    coordinates_idx = CoordinatesIdx(0, 1, 2), 
    log_level = logging.INFO,
    logger_name = 'yolo26 results_base',
)

cv.perform_training_with_rank_classification(
    n_folds = 4,
    siamese_nn_type = "conv1d",
    learning_rate = 1e-6,
    batch_size = 32,
    n_epochs = 100,
    embedding_size = 100,
    tsne_perplexity = 20,
    show_plot = True, 
)
# Out:
# p1s1 [L] - [(24, 56), (56, 88)]
# p1s2 [L] - [(25, 57), (56, 88)]
# p1s3 [L] - [(21, 53), (51, 83)]
# p1s4 [L] - [(23, 55), (52, 84)]
# p2s1 [R] - [(23, 55), (54, 86), (94, 126)]
# p2s2 [L] - [(30, 62), (58, 90)]
# p2s3 [R] - [(37, 69), (65, 97)]
# p2s4 [L] - [(37, 69), (62, 94)]
# p3s1 [R] - [(36, 68), (66, 98)]
# p3s2 [L] - [(27, 59), (53, 85)]
# p3s3 [L] - [(21, 53), (53, 85), (85, 117)]
# p3s4 [R] - [(22, 54), (49, 81)]
# p4s1 [L] - [(25, 57), (59, 91)]
# p4s2 [L] - [(23, 55), (54, 86)]
# p4s3 [R] - [(24, 56), (58, 90)]
# p4s4 [R] - [(23, 55), (54, 86)]
# p5s1 [R] - [(25, 57), (57, 89), (90, 122)]
# p5s2 [R] - [(31, 63), (63, 95), (97, 129)]
# p5s3 [R] - [(25, 57), (60, 92), (93, 125)]
# p5s4 [R] - [(28, 60), (62, 94), (94, 126)]
# p6s1 [R] - [(31, 63)]
# p6s2 [R] - [(37, 69), (64, 96)]
# p6s3 [R] - [(17, 49), (47, 79)]
# p6s4 [R] - [(36, 68)]
# p7s1 [R] - [(16, 48), (48, 80)]
# p7s2 [L] - [(30, 62), (59, 91)]
# p7s3 [R] - [(37, 69)]
# p7s4 [L] - [(20, 52), (50, 82)]
# ...

# %%
results_raw = separate_gait_sequences_to_cycles(triangulation_data, 
                                            window_size=32, 
                                            minima_window_size=14, 
                                            smooth_butterworth=False, 
                                            )

cv = CrossValidationSiameseRaw(
    sequence_cycles = results_raw, 
    coordinates_idx = CoordinatesIdx(0, 1, 2), 
    log_level = logging.INFO,
    logger_name = 'yolo26 results_raw',
)

cv.perform_training_with_rank_classification(
    n_folds = 4,
    siamese_nn_type = "conv1d",
    learning_rate = 1e-6,
    batch_size = 32,
    n_epochs = 100,
    embedding_size = 100,
    tsne_perplexity = 20,
    show_plot = True, 
)
# Out:
# p1s1 [L] - [(27, 59), (62, 94)]
# p1s2 [R] - [(17, 49), (44, 76), (69, 101)]
# p1s3 [L] - [(23, 55), (55, 87)]
# p1s4 [L] - [(23, 55), (49, 81)]
# p2s1 [R] - [(25, 57), (58, 90), (86, 118)]
# p2s2 [R] - [(15, 47), (41, 73), (69, 101)]
# p2s3 [L] - [(23, 55), (57, 89)]
# p2s4 [R] - [(24, 56), (46, 78), (72, 104)]
# Failed to find proper step frame keys
# p3s2 [R] - [(16, 48), (38, 70)]
# p3s3 [L] - [(20, 52), (50, 82), (86, 118)]
# p3s4 [R] - [(25, 57), (46, 78)]
# p4s1 [L] - [(34, 66), (64, 96)]
# p4s2 [L] - [(27, 59), (54, 86)]
# p4s3 [R] - [(31, 63), (63, 95)]
# p4s4 [R] - [(26, 58), (57, 89)]
# p5s1 [R] - [(30, 62), (59, 91), (87, 119)]
# p5s2 [L] - [(16, 48), (45, 77), (76, 108)]
# p5s3 [L] - [(16, 48), (45, 77), (71, 103)]
# p5s4 [R] - [(32, 64), (64, 96), (96, 128)]
# p6s1 [L] - [(20, 52)]
# p6s2 [L] - [(25, 57), (47, 79)]
# p6s3 [R] - [(21, 53), (52, 84), (76, 108)]
# p6s4 [L] - [(22, 54), (44, 76)]
# p7s1 [L] - [(14, 46), (41, 73), (68, 100)]
# ...

# %%
results_compare_cf_08 = separate_gait_sequences_to_cycles(triangulation_data, 
                                            window_size=32, 
                                            minima_window_size=14, 
                                            smooth_butterworth=True, 
                                            # butterworth filter parameters
                                            cutoff_frequency = 0.8, 
                                            order = 2,
                                            fs = 25,
                                           )

cv = CrossValidationSiameseRaw(
    sequence_cycles = results_compare_cf_08, 
    coordinates_idx = CoordinatesIdx(0, 1, 2), 
    log_level = logging.INFO,
    logger_name = 'yolo26 results_compare_cf_08',
)

cv.perform_training_with_rank_classification(
    n_folds = 4,
    siamese_nn_type = "conv1d",
    learning_rate = 1e-6,
    batch_size = 32,
    n_epochs = 100,
    embedding_size = 100,
    tsne_perplexity = 20,
    show_plot = True, 
)
# Out:
# p1s1 [L] - [(25, 57), (57, 89)]
# p1s2 [L] - [(26, 58), (57, 89)]
# p1s3 [L] - [(21, 53), (50, 82)]
# p1s4 [L] - [(22, 54), (52, 84)]
# p2s1 [R] - [(24, 56), (55, 87), (88, 120)]
# p2s2 [R] - [(17, 49), (44, 76)]
# p2s3 [L] - [(22, 54), (52, 84)]
# p2s4 [R] - [(22, 54), (49, 81)]
# p3s1 [L] - [(21, 53), (53, 85), (83, 115)]
# p3s2 [L] - [(27, 59), (54, 86)]
# p3s3 [L] - [(22, 54), (53, 85), (85, 117)]
# p3s4 [R] - [(22, 54), (48, 80)]
# p4s1 [L] - [(26, 58), (59, 91)]
# p4s2 [L] - [(24, 56), (55, 87)]
# p4s3 [R] - [(25, 57), (58, 90)]
# p4s4 [R] - [(23, 55), (54, 86)]
# p5s1 [R] - [(25, 57), (57, 89), (90, 122)]
# p5s2 [R] - [(31, 63), (63, 95), (96, 128)]
# p5s3 [R] - [(26, 58), (60, 92), (93, 125)]
# p5s4 [R] - [(29, 61), (61, 93), (94, 126)]
# p6s1 [R] - [(31, 63)]
# p6s2 [L] - [(23, 55), (50, 82)]
# p6s3 [R] - [(17, 49), (47, 79)]
# p6s4 [L] - [(20, 52), (47, 79)]
# p7s1 [R] - [(20, 52), (49, 81)]
# p7s2 [L] - [(30, 62), (59, 91)]
# p7s3 [L] - [(22, 54), (51, 83)]
# ...

# %%
results_compare_cf_07 = separate_gait_sequences_to_cycles(triangulation_data, 
                                            window_size=32, 
                                            minima_window_size=12, 
                                            smooth_butterworth=True, 
                                            # butterworth filter parameters
                                            cutoff_frequency = 0.7, 
                                            order = 2,
                                            fs = 25,
                                           )

cv = CrossValidationSiameseRaw(
    sequence_cycles = results_compare_cf_07, 
    coordinates_idx = CoordinatesIdx(0, 1, 2), 
    log_level = logging.INFO,
    logger_name = 'yolo26 results_compare_cf_07',
)

cv.perform_training_with_rank_classification(
    n_folds = 4,
    siamese_nn_type = "conv1d",
    learning_rate = 1e-6,
    batch_size = 32,
    n_epochs = 100,
    embedding_size = 100,
    tsne_perplexity = 20,
    show_plot = True, 
)
# Out:
# p1s1 [L] - [(25, 57), (56, 88)]
# p1s2 [L] - [(26, 58), (57, 89)]
# p1s3 [L] - [(21, 53), (51, 83)]
# p1s4 [L] - [(23, 55), (53, 85)]
# p2s1 [R] - [(23, 55), (54, 86), (97, 129)]
# p2s2 [R] - [(16, 48), (44, 76)]
# p2s3 [R] - [(37, 69), (65, 97)]
# p2s4 [R] - [(22, 54), (49, 81)]
# p3s1 [R] - [(36, 68), (66, 98)]
# p3s2 [L] - [(27, 59), (53, 85)]
# p3s3 [L] - [(21, 53), (53, 85), (85, 117)]
# p3s4 [R] - [(22, 54), (48, 80)]
# p4s1 [L] - [(26, 58), (59, 91)]
# p4s2 [L] - [(24, 56), (55, 87)]
# p4s3 [R] - [(24, 56), (58, 90)]
# p4s4 [R] - [(23, 55), (54, 86)]
# p5s1 [R] - [(25, 57), (57, 89), (91, 123)]
# p5s2 [R] - [(31, 63), (63, 95), (97, 129)]
# p5s3 [R] - [(26, 58), (60, 92), (93, 125)]
# p5s4 [R] - [(28, 60), (62, 94), (94, 126)]
# p6s1 [R] - [(31, 63)]
# p6s2 [R] - [(38, 70), (65, 97)]
# p6s3 [R] - [(17, 49), (46, 78)]
# p6s4 [L] - [(20, 52), (48, 80)]
# p7s1 [R] - [(18, 50), (49, 81)]
# p7s2 [L] - [(30, 62), (59, 91)]
# p7s3 [R] - [(37, 69)]
# p7s4 [L] - [(20, 52), (50, 82)]
# ...

# %%
results_compare_cf1 = separate_gait_sequences_to_cycles(triangulation_data, 
                                            window_size=32, 
                                            minima_window_size=14, 
                                            smooth_butterworth=True, 
                                            # butterworth filter parameters
                                            cutoff_frequency = 1, 
                                            order = 2,
                                            fs = 25,
                                           )

cv = CrossValidationSiameseRaw(
    sequence_cycles = results_compare_cf1, 
    coordinates_idx = CoordinatesIdx(0, 1, 2), 
    log_level = logging.INFO,
    logger_name = 'yolo26 results_compare_cf1',
)

cv.perform_training_with_rank_classification(
    n_folds = 4,
    siamese_nn_type = "conv1d",
    learning_rate = 1e-6,
    batch_size = 32,
    n_epochs = 100,
    embedding_size = 100,
    tsne_perplexity = 20,
    show_plot = True, 
)
# Out:
# p1s1 [L] - [(25, 57), (57, 89)]
# p1s2 [L] - [(27, 59), (57, 89)]
# p1s3 [L] - [(21, 53), (51, 83)]
# p1s4 [L] - [(23, 55), (52, 84)]
# p2s1 [R] - [(24, 56), (55, 87), (87, 119)]
# p2s2 [R] - [(17, 49), (44, 76)]
# p2s3 [L] - [(22, 54), (51, 83)]
# p2s4 [R] - [(23, 55), (49, 81)]
# p3s1 [L] - [(22, 54), (53, 85), (83, 115)]
# p3s2 [R] - [(13, 45), (40, 72)]
# p3s3 [L] - [(23, 55), (53, 85), (85, 117)]
# p3s4 [R] - [(23, 55), (48, 80)]
# p4s1 [L] - [(28, 60), (59, 91)]
# p4s2 [L] - [(25, 57), (55, 87)]
# p4s3 [R] - [(25, 57), (58, 90)]
# p4s4 [R] - [(24, 56), (54, 86)]
# p5s1 [R] - [(26, 58), (58, 90), (91, 123)]
# p5s2 [R] - [(32, 64), (63, 95), (96, 128)]
# p5s3 [R] - [(26, 58), (60, 92), (93, 125)]
# p5s4 [R] - [(30, 62), (61, 93), (93, 125)]
# p6s1 [L] - [(18, 50), (45, 77)]
# p6s2 [L] - [(23, 55), (50, 82)]
# p6s3 [R] - [(18, 50), (47, 79)]
# p6s4 [L] - [(21, 53), (47, 79)]
# p7s1 [R] - [(21, 53), (49, 81)]
# p7s2 [R] - [(17, 49), (46, 78)]
# p7s3 [L] - [(22, 54), (50, 82)]
# ...

# %%
results_compare_cf2 = separate_gait_sequences_to_cycles(triangulation_data, 
                                            window_size=32, 
                                            minima_window_size=14, 
                                            smooth_butterworth=True, 
                                            # butterworth filter parameters
                                            cutoff_frequency = 2, 
                                            order = 2,
                                            fs = 25,
                                           )

cv = CrossValidationSiameseRaw(
    sequence_cycles = results_compare_cf2, 
    coordinates_idx = CoordinatesIdx(0, 1, 2), 
    log_level = logging.INFO,
    logger_name = 'yolo26 results_compare_cf2',
)

cv.perform_training_with_rank_classification(
    n_folds = 4,
    siamese_nn_type = "conv1d",
    learning_rate = 1e-6,
    batch_size = 32,
    n_epochs = 100,
    embedding_size = 100,
    tsne_perplexity = 20,
    show_plot = True, 
)
# Out:
# p1s1 [L] - [(27, 59), (60, 92)]
# p1s2 [R] - [(16, 48), (47, 79)]
# p1s3 [L] - [(23, 55), (54, 86)]
# p1s4 [L] - [(24, 56), (50, 82)]
# p2s1 [L] - [(14, 46), (45, 77), (76, 108), (102, 134)]
# p2s2 [R] - [(20, 52), (48, 80), (73, 105)]
# p2s3 [L] - [(24, 56), (55, 87)]
# p2s4 [R] - [(25, 57), (52, 84), (76, 108)]
# p3s1 [L] - [(28, 60), (58, 90), (89, 121)]
# p3s2 [R] - [(15, 47), (38, 70)]
# p3s3 [L] - [(28, 60), (54, 86), (86, 118)]
# p3s4 [R] - [(25, 57), (47, 79)]
# p4s1 [R] - [(15, 47), (46, 78)]
# p4s2 [L] - [(26, 58), (53, 85)]
# p4s3 [L] - [(14, 46), (45, 77)]
# p4s4 [R] - [(24, 56), (55, 87)]
# p5s1 [R] - [(31, 63), (63, 95), (96, 128)]
# p5s2 [L] - [(15, 47), (44, 76), (77, 109)]
# p5s3 [L] - [(16, 48), (45, 77), (72, 104)]
# p5s4 [L] - [(12, 44), (42, 74), (74, 106)]
# p6s1 [L] - [(22, 54)]
# p6s2 [L] - [(24, 56), (49, 81)]
# p6s3 [R] - [(20, 52), (50, 82)]
# p6s4 [L] - [(23, 55), (46, 78)]
# p7s1 [L] - [(12, 44), (40, 72), (67, 99)]
# ...

# %%
results_compare_cf3 = separate_gait_sequences_to_cycles(triangulation_data, 
                                            window_size=32, 
                                            minima_window_size=14, 
                                            smooth_butterworth=True, 
                                            # butterworth filter parameters
                                            cutoff_frequency = 3, 
                                            order = 2,
                                            fs = 25,
                                           )

cv = CrossValidationSiameseRaw(
    sequence_cycles = results_compare_cf3, 
    coordinates_idx = CoordinatesIdx(0, 1, 2), 
    log_level = logging.INFO,
    logger_name = 'yolo26 results_compare_cf3',
)

cv.perform_training_with_rank_classification(
    n_folds = 4,
    siamese_nn_type = "conv1d",
    learning_rate = 1e-6,
    batch_size = 32,
    n_epochs = 100,
    embedding_size = 100,
    tsne_perplexity = 20,
    show_plot = True, 
)
# Out:
# p1s1 [L] - [(27, 59), (62, 94)]
# p1s2 [R] - [(16, 48), (48, 80)]
# p1s3 [L] - [(23, 55), (56, 88)]
# p1s4 [R] - [(14, 46), (44, 76)]
# p2s1 [L] - [(15, 47), (45, 77), (77, 109), (103, 135)]
# p2s2 [R] - [(15, 47), (46, 78), (73, 105)]
# p2s3 [L] - [(24, 56), (56, 88)]
# p2s4 [R] - [(27, 59), (54, 86), (76, 108)]
# p3s1 [R] - [(8, 40), (34, 66), (64, 96)]
# p3s2 [R] - [(16, 48), (38, 70)]
# p3s3 [L] - [(29, 61), (54, 86), (86, 118)]
# p3s4 [L] - [(33, 65), (59, 91)]
# p4s1 [R] - [(16, 48), (47, 79)]
# p4s2 [L] - [(27, 59), (53, 85)]
# p4s3 [R] - [(30, 62), (63, 95)]
# p4s4 [L] - [(10, 42), (36, 68), (67, 99)]
# p5s1 [R] - [(33, 65), (59, 91), (92, 124)]
# p5s2 [L] - [(16, 48), (44, 76), (77, 109)]
# p5s3 [L] - [(17, 49), (51, 83), (78, 110)]
# p5s4 [R] - [(32, 64), (64, 96), (99, 131)]
# p6s1 [L] - [(24, 56)]
# p6s2 [L] - [(25, 57), (48, 80)]
# p6s3 [R] - [(21, 53), (52, 84)]
# p6s4 [L] - [(23, 55), (46, 78)]
# p7s1 [L] - [(13, 45), (41, 73), (68, 100)]
# ...

# %%
results_compare_cf4 = separate_gait_sequences_to_cycles(triangulation_data, 
                                            window_size=32, 
                                            minima_window_size=14, 
                                            smooth_butterworth=True, 
                                            # butterworth filter parameters
                                            cutoff_frequency = 4, 
                                            order = 2,
                                            fs = 25,
                                           )

cv = CrossValidationSiameseRaw(
    sequence_cycles = results_compare_cf4, 
    coordinates_idx = CoordinatesIdx(0, 1, 2), 
    log_level = logging.INFO,
    logger_name = 'yolo26 results_compare_cf4',
)

cv.perform_training_with_rank_classification(
    n_folds = 4,
    siamese_nn_type = "conv1d",
    learning_rate = 1e-6,
    batch_size = 32,
    n_epochs = 100,
    embedding_size = 100,
    tsne_perplexity = 20,
    show_plot = True, 
)
# Out:
# p1s1 [L] - [(27, 59), (62, 94)]
# p1s2 [R] - [(16, 48), (48, 80)]
# p1s3 [L] - [(23, 55), (56, 88)]
# p1s4 [L] - [(24, 56), (49, 81)]
# p2s1 [R] - [(22, 54), (56, 88), (86, 118)]
# p2s2 [R] - [(15, 47), (42, 74), (69, 101)]
# p2s3 [L] - [(23, 55), (56, 88)]
# p2s4 [R] - [(24, 56), (47, 79), (73, 105)]
# p3s1 [L] - [(30, 62), (54, 86), (79, 111)]
# p3s2 [R] - [(16, 48), (38, 70)]
# p3s3 [L] - [(20, 52), (50, 82), (85, 117)]
# p3s4 [L] - [(33, 65), (59, 91)]
# p4s1 [R] - [(16, 48), (47, 79)]
# p4s2 [L] - [(27, 59), (52, 84)]
# p4s3 [R] - [(31, 63), (63, 95)]
# p4s4 [R] - [(25, 57), (51, 83)]
# p5s1 [R] - [(33, 65), (59, 91), (92, 124)]
# p5s2 [L] - [(15, 47), (44, 76), (76, 108)]
# Failed to find proper step frame keys
# p5s4 [R] - [(32, 64), (64, 96), (99, 131)]
# p6s1 [L] - [(24, 56)]
# p6s2 [L] - [(22, 54), (48, 80)]
# p6s3 [R] - [(20, 52), (52, 84), (77, 109)]
# p6s4 [L] - [(23, 55), (45, 77)]
# p7s1 [L] - [(14, 46), (41, 73), (69, 101)]
# p7s2 [R] - [(22, 54), (50, 82)]
# ...

# %%
import matplotlib.pyplot as plt

a = {
    'results raw': results_raw,
    'results butterworth (cf=0.625)': results_base,
    'results butterworth (cf=0.7)': results_compare_cf_07,
    'results butterworth (cf=0.8)': results_compare_cf_08,
    'results butterworth (cf=1)': results_compare_cf1,
    'results butterworth (cf=2)': results_compare_cf2,
    'results butterworth (cf=3)': results_compare_cf3, 
    'results butterworth (cf=4)': results_compare_cf4, 
}

plt.figure(figsize=(12, 9))

for i, (name, data) in enumerate(a.items()):
    
    ptcp_key = 'p1s1c1'
    i = 2
    t = range(32)
    
    joint = 'lfoot'
    ptcp_data = data[ptcp_key]
    lfoot = [frame[joint][i] for frame in ptcp_data]
    
    joint = 'rfoot'
    ptcp_data = data[ptcp_key]
    rfoot = [frame[joint][i] for frame in ptcp_data]
    
    # Original signal
    plt.subplot(3, 1, 1)
    plt.plot(t, lfoot, label=name)
    plt.title('Left foot')
    plt.xlabel('Frame')
    plt.ylabel('Height (mm)')
    plt.grid()
    plt.legend()
    
    # Filtered signal
    plt.subplot(3, 1, 2)
    plt.plot(t, rfoot, label=name)
    plt.title('Right foot')
    plt.xlabel('Frame')
    plt.ylabel('Height (mm)')
    plt.grid()
    plt.legend()
    
plt.tight_layout()
plt.show()

# %%
for emb_size in [50, 100, 200]:
    results_compare_cf1 = separate_gait_sequences_to_cycles(triangulation_data, 
                                            window_size=32, 
                                            minima_window_size=14, 
                                            smooth_butterworth=True, 
                                            # butterworth filter parameters
                                            cutoff_frequency = 1, 
                                            order = 2,
                                            fs = 25,
                                           )

    cv = CrossValidationSiameseRaw(
        sequence_cycles = results_compare_cf1, 
        coordinates_idx = CoordinatesIdx(0, 1, 2), 
        log_level = logging.INFO,
        logger_name = f'yolo26 results_compare_cf1 {emb_size}',
    )
    
    cv.perform_training_with_rank_classification(
        n_folds = 4,
        siamese_nn_type = "conv1d",
        learning_rate = 1e-6,
        batch_size = 32,
        n_epochs = 100,
        embedding_size = emb_size,
        tsne_perplexity = 20,
        show_plot = True, 
    )
    
    print(f"^^^^^^^^^ {emb_size} ^^^^^^^^^")
# Out:
# p1s1 [L] - [(25, 57), (57, 89)]
# p1s2 [L] - [(27, 59), (57, 89)]
# p1s3 [L] - [(21, 53), (51, 83)]
# p1s4 [L] - [(23, 55), (52, 84)]
# p2s1 [R] - [(24, 56), (55, 87), (87, 119)]
# p2s2 [R] - [(17, 49), (44, 76)]
# p2s3 [L] - [(22, 54), (51, 83)]
# p2s4 [R] - [(23, 55), (49, 81)]
# p3s1 [L] - [(22, 54), (53, 85), (83, 115)]
# p3s2 [R] - [(13, 45), (40, 72)]
# p3s3 [L] - [(23, 55), (53, 85), (85, 117)]
# p3s4 [R] - [(23, 55), (48, 80)]
# p4s1 [L] - [(28, 60), (59, 91)]
# p4s2 [L] - [(25, 57), (55, 87)]
# p4s3 [R] - [(25, 57), (58, 90)]
# p4s4 [R] - [(24, 56), (54, 86)]
# p5s1 [R] - [(26, 58), (58, 90), (91, 123)]
# p5s2 [R] - [(32, 64), (63, 95), (96, 128)]
# p5s3 [R] - [(26, 58), (60, 92), (93, 125)]
# p5s4 [R] - [(30, 62), (61, 93), (93, 125)]
# p6s1 [L] - [(18, 50), (45, 77)]
# p6s2 [L] - [(23, 55), (50, 82)]
# p6s3 [R] - [(18, 50), (47, 79)]
# p6s4 [L] - [(21, 53), (47, 79)]
# p7s1 [R] - [(21, 53), (49, 81)]
# p7s2 [R] - [(17, 49), (46, 78)]
# p7s3 [L] - [(22, 54), (50, 82)]
# ...

# %%
for emb_size in [50, 100, 200]:
    results_compare_cf1 = separate_gait_sequences_to_cycles(triangulation_data, 
                                            window_size=32, 
                                            minima_window_size=14, 
                                            smooth_butterworth=True, 
                                            # butterworth filter parameters
                                            cutoff_frequency = 1, 
                                            order = 2,
                                            fs = 25,
                                           )

    cv = CrossValidationSiameseRaw(
        sequence_cycles = results_compare_cf1, 
        coordinates_idx = CoordinatesIdx(0, 1, 2), 
        log_level = logging.INFO,
        logger_name = f'yolo26 results_compare_cf1 {emb_size}',
        involve_hands_parameters = False,
    )
    
    cv.perform_training_with_rank_classification(
        n_folds = 4,
        siamese_nn_type = "conv1d",
        learning_rate = 1e-6,
        batch_size = 32,
        n_epochs = 100,
        embedding_size = emb_size,
        tsne_perplexity = 20,
        show_plot = True, 
    )
    
    print(f"^^^^^^^^^ {emb_size} ^^^^^^^^^")
# Out:
# p1s1 [L] - [(25, 57), (57, 89)]
# p1s2 [L] - [(27, 59), (57, 89)]
# p1s3 [L] - [(21, 53), (51, 83)]
# p1s4 [L] - [(23, 55), (52, 84)]
# p2s1 [R] - [(24, 56), (55, 87), (87, 119)]
# p2s2 [R] - [(17, 49), (44, 76)]
# p2s3 [L] - [(22, 54), (51, 83)]
# p2s4 [R] - [(23, 55), (49, 81)]
# p3s1 [L] - [(22, 54), (53, 85), (83, 115)]
# p3s2 [R] - [(13, 45), (40, 72)]
# p3s3 [L] - [(23, 55), (53, 85), (85, 117)]
# p3s4 [R] - [(23, 55), (48, 80)]
# p4s1 [L] - [(28, 60), (59, 91)]
# p4s2 [L] - [(25, 57), (55, 87)]
# p4s3 [R] - [(25, 57), (58, 90)]
# p4s4 [R] - [(24, 56), (54, 86)]
# p5s1 [R] - [(26, 58), (58, 90), (91, 123)]
# p5s2 [R] - [(32, 64), (63, 95), (96, 128)]
# p5s3 [R] - [(26, 58), (60, 92), (93, 125)]
# p5s4 [R] - [(30, 62), (61, 93), (93, 125)]
# p6s1 [L] - [(18, 50), (45, 77)]
# p6s2 [L] - [(23, 55), (50, 82)]
# p6s3 [R] - [(18, 50), (47, 79)]
# p6s4 [L] - [(21, 53), (47, 79)]
# p7s1 [R] - [(21, 53), (49, 81)]
# p7s2 [R] - [(17, 49), (46, 78)]
# p7s3 [L] - [(22, 54), (50, 82)]
# ...

# %%
for emb_size in [50, 100, 200, 500]:
    results_compare_cf1 = separate_gait_sequences_to_cycles(triangulation_data, 
                                            window_size=32, 
                                            minima_window_size=14, 
                                            smooth_butterworth=True, 
                                            # butterworth filter parameters
                                            cutoff_frequency = 1, 
                                            order = 2,
                                            fs = 25,
                                           )

    cv = CrossValidationSiameseRaw(
        sequence_cycles = results_compare_cf1, 
        coordinates_idx = CoordinatesIdx(0, 1, 2), 
        log_level = logging.INFO,
        logger_name = f'yolo26 results_compare_cf1 lstm {emb_size}',
    )
    
    cv.perform_training_with_rank_classification(
        n_folds = 4,
        siamese_nn_type = "lstm",
        learning_rate = 1e-5,
        batch_size = 32,
        n_epochs = 150,
        embedding_size = emb_size,
        tsne_perplexity = 20,
        show_plot = False, 
    )
    
    print(f"^^^^^^^^^ {emb_size} ^^^^^^^^^")
# Out:
# p1s1 [L] - [(25, 57), (57, 89)]
# p1s2 [L] - [(27, 59), (57, 89)]
# p1s3 [L] - [(21, 53), (51, 83)]
# p1s4 [L] - [(23, 55), (52, 84)]
# p2s1 [R] - [(24, 56), (55, 87), (87, 119)]
# p2s2 [R] - [(17, 49), (44, 76)]
# p2s3 [L] - [(22, 54), (51, 83)]
# p2s4 [R] - [(23, 55), (49, 81)]
# p3s1 [L] - [(22, 54), (53, 85), (83, 115)]
# p3s2 [R] - [(13, 45), (40, 72)]
# p3s3 [L] - [(23, 55), (53, 85), (85, 117)]
# p3s4 [R] - [(23, 55), (48, 80)]
# p4s1 [L] - [(28, 60), (59, 91)]
# p4s2 [L] - [(25, 57), (55, 87)]
# p4s3 [R] - [(25, 57), (58, 90)]
# p4s4 [R] - [(24, 56), (54, 86)]
# p5s1 [R] - [(26, 58), (58, 90), (91, 123)]
# p5s2 [R] - [(32, 64), (63, 95), (96, 128)]
# p5s3 [R] - [(26, 58), (60, 92), (93, 125)]
# p5s4 [R] - [(30, 62), (61, 93), (93, 125)]
# p6s1 [L] - [(18, 50), (45, 77)]
# p6s2 [L] - [(23, 55), (50, 82)]
# p6s3 [R] - [(18, 50), (47, 79)]
# p6s4 [L] - [(21, 53), (47, 79)]
# p7s1 [R] - [(21, 53), (49, 81)]
# p7s2 [R] - [(17, 49), (46, 78)]
# p7s3 [L] - [(22, 54), (50, 82)]
# ...

# %%
for emb_size in [50, 100, 200, 500]:
    results_compare_cf1 = separate_gait_sequences_to_cycles(triangulation_data, 
                                            window_size=32, 
                                            minima_window_size=14, 
                                            smooth_butterworth=True, 
                                            # butterworth filter parameters
                                            cutoff_frequency = 1, 
                                            order = 2,
                                            fs = 25,
                                           )

    cv = CrossValidationSiameseRaw(
        sequence_cycles = results_compare_cf1, 
        coordinates_idx = CoordinatesIdx(0, 1, 2), 
        log_level = logging.INFO,
        logger_name = f'yolo26 results_compare_cf1 lstm nohands {emb_size}',
        involve_hands_parameters = False,
    )
    
    cv.perform_training_with_rank_classification(
        n_folds = 4,
        siamese_nn_type = "lstm",
        learning_rate = 1e-5,
        batch_size = 32,
        n_epochs = 150,
        embedding_size = emb_size,
        tsne_perplexity = 20,
        show_plot = False, 
    )
    
    print(f"^^^^^^^^^ {emb_size} ^^^^^^^^^")

# %%
for emb_size in [5, 10, 20, 50, 100, 200, 500]:
    results_compare_cf1 = separate_gait_sequences_to_cycles(triangulation_data, 
                                            window_size=32, 
                                            minima_window_size=14, 
                                            smooth_butterworth=True, 
                                            # butterworth filter parameters
                                            cutoff_frequency = 1, 
                                            order = 2,
                                            fs = 25,
                                           )

    cv = CrossValidationSiameseRaw(
        sequence_cycles = results_compare_cf1, 
        coordinates_idx = CoordinatesIdx(0, 1, 2), 
        log_level = logging.INFO,
        logger_name = f'yolo26 results_compare_cf1 conv1d nohands {emb_size}',
        involve_hands_parameters = False,
    )
    
    cv.perform_training(
        n_folds = 4,
        siamese_nn_type = "conv1d",
        learning_rate = 1e-6,
        batch_size = 32,
        n_epochs = 200,
        embedding_size = emb_size,
        threshold = 0.5,
        show_plot = False, 
    )
    
    print(f"^^^^^^^^^ {emb_size} ^^^^^^^^^")
# Out:
# p1s1 [L] - [(25, 57), (57, 89)]
# p1s2 [L] - [(27, 59), (57, 89)]
# p1s3 [L] - [(21, 53), (51, 83)]
# p1s4 [L] - [(23, 55), (52, 84)]
# p2s1 [R] - [(24, 56), (55, 87), (87, 119)]
# p2s2 [R] - [(17, 49), (44, 76)]
# p2s3 [L] - [(22, 54), (51, 83)]
# p2s4 [R] - [(23, 55), (49, 81)]
# p3s1 [L] - [(22, 54), (53, 85), (83, 115)]
# p3s2 [R] - [(13, 45), (40, 72)]
# p3s3 [L] - [(23, 55), (53, 85), (85, 117)]
# p3s4 [R] - [(23, 55), (48, 80)]
# p4s1 [L] - [(28, 60), (59, 91)]
# p4s2 [L] - [(25, 57), (55, 87)]
# p4s3 [R] - [(25, 57), (58, 90)]
# p4s4 [R] - [(24, 56), (54, 86)]
# p5s1 [R] - [(26, 58), (58, 90), (91, 123)]
# p5s2 [R] - [(32, 64), (63, 95), (96, 128)]
# p5s3 [R] - [(26, 58), (60, 92), (93, 125)]
# p5s4 [R] - [(30, 62), (61, 93), (93, 125)]
# p6s1 [L] - [(18, 50), (45, 77)]
# p6s2 [L] - [(23, 55), (50, 82)]
# p6s3 [R] - [(18, 50), (47, 79)]
# p6s4 [L] - [(21, 53), (47, 79)]
# p7s1 [R] - [(21, 53), (49, 81)]
# p7s2 [R] - [(17, 49), (46, 78)]
# p7s3 [L] - [(22, 54), (50, 82)]
# ...

# %%
for emb_size in [5, 10, 20, 50, 100, 200, 500]:
    results_compare_cf1 = separate_gait_sequences_to_cycles(triangulation_data, 
                                            window_size=32, 
                                            minima_window_size=14, 
                                            smooth_butterworth=True, 
                                            # butterworth filter parameters
                                            cutoff_frequency = 1, 
                                            order = 2,
                                            fs = 25,
                                           )

    cv = CrossValidationSiameseRaw(
        sequence_cycles = results_compare_cf1, 
        coordinates_idx = CoordinatesIdx(0, 1, 2), 
        log_level = logging.INFO,
        logger_name = f'yolo26 results_compare_cf1 conv1d {emb_size}',
        involve_hands_parameters = True,
    )
    
    cv.perform_training(
        n_folds = 4,
        siamese_nn_type = "conv1d",
        learning_rate = 1e-6,
        batch_size = 32,
        n_epochs = 200,
        embedding_size = emb_size,
        threshold = 0.5,
        show_plot = False, 
    )
    
    print(f"^^^^^^^^^ {emb_size} ^^^^^^^^^")
# Out:
# p1s1 [L] - [(25, 57), (57, 89)]
# p1s2 [L] - [(27, 59), (57, 89)]
# p1s3 [L] - [(21, 53), (51, 83)]
# p1s4 [L] - [(23, 55), (52, 84)]
# p2s1 [R] - [(24, 56), (55, 87), (87, 119)]
# p2s2 [R] - [(17, 49), (44, 76)]
# p2s3 [L] - [(22, 54), (51, 83)]
# p2s4 [R] - [(23, 55), (49, 81)]
# p3s1 [L] - [(22, 54), (53, 85), (83, 115)]
# p3s2 [R] - [(13, 45), (40, 72)]
# p3s3 [L] - [(23, 55), (53, 85), (85, 117)]
# p3s4 [R] - [(23, 55), (48, 80)]
# p4s1 [L] - [(28, 60), (59, 91)]
# p4s2 [L] - [(25, 57), (55, 87)]
# p4s3 [R] - [(25, 57), (58, 90)]
# p4s4 [R] - [(24, 56), (54, 86)]
# p5s1 [R] - [(26, 58), (58, 90), (91, 123)]
# p5s2 [R] - [(32, 64), (63, 95), (96, 128)]
# p5s3 [R] - [(26, 58), (60, 92), (93, 125)]
# p5s4 [R] - [(30, 62), (61, 93), (93, 125)]
# p6s1 [L] - [(18, 50), (45, 77)]
# p6s2 [L] - [(23, 55), (50, 82)]
# p6s3 [R] - [(18, 50), (47, 79)]
# p6s4 [L] - [(21, 53), (47, 79)]
# p7s1 [R] - [(21, 53), (49, 81)]
# p7s2 [R] - [(17, 49), (46, 78)]
# p7s3 [L] - [(22, 54), (50, 82)]
# ...
