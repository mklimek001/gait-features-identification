# %%
import pandas as pd
import logging
from utils.cross_validation_siamese import CVTrainer

gait_df = pd.read_csv('./datasets/triangulation_gait_features.csv')
cv_trainer = CVTrainer(gait_df, splits_number=2, log_level=logging.INFO)
result = cv_trainer.run_training_rank_classification(n_epochs=10, learning_rate=0.0001, batch_size=4)
print(result)
# Out:
# 2026-01-07 17:03:40,644 - logger - INFO - Provided selected_features parameter is None - all features from dataset will be used.
# 2026-01-07 17:03:40,646 - logger - INFO - Number of selected features: 24
# 2026-01-07 17:03:40,674 - logger - INFO - Found 26 participants recorded once.
# 2026-01-07 17:03:40,675 - logger - INFO - Found 6 participants recorded twice.
# 2026-01-07 17:03:40,677 - logger - INFO - Training iteration 1/2
# 2026-01-07 17:03:40,816 - logger - INFO - Train and test datasets created successfully
# 2026-01-07 17:03:40,817 - logger - INFO - Train dataset size: 486
# 2026-01-07 17:03:40,817 - logger - INFO - Test dataset size: 150
# 2026-01-07 17:03:40,829 - logger - INFO - Siamese neural network model training started...
# 2026-01-07 17:03:41,059 - logger - INFO - Epoch 1, Train Loss: 0.3046
# 2026-01-07 17:03:41,296 - logger - INFO - Epoch 2, Train Loss: 0.2508
# 2026-01-07 17:03:41,552 - logger - INFO - Epoch 3, Train Loss: 0.2289
# ...
